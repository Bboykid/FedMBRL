# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test_log = np.load("0_test_loss_logs.npy")

# %%
test_log.shape
# Out:
# (20, 3, 3)

# %%
# 创建一个图形窗口
plt.figure(figsize=(10, 6))

# 绘制每个模型在所有数据集上的loss
for model_idx in range(test_log.shape[1]):  # 遍历每个模型
    # 对每个模型，在所有数据集上进行平均
    avg_loss = np.mean(test_log[:, model_idx, :], axis=1)
    plt.plot(avg_loss, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Model Loss Across Rounds')
plt.legend()

# 显示图形
plt.show()

# %%
# 创建一个图形窗口
plt.figure(figsize=(10, 6))

# 绘制每个模型在所有数据集上的loss
for model_idx in range(test_log.shape[1]):  # 遍历每个模型
    # 对每个模型，在所有数据集上进行平均
    avg_loss = np.mean(test_log[:,:, model_idx], axis=1)
    plt.plot(avg_loss, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Model Loss Across Rounds')
plt.legend()

# 显示图形
plt.show()

# %%
test_log[:,2, 1]
# Out:
# array([7.48605674e-02, 8.77534804e-02, 3.47129998e-03, 4.22092348e-04,
#        3.57480475e-02, 1.65720928e-04, 2.54898850e-03, 1.70080826e-02,
#        9.45499503e-03, 4.52861695e-03, 4.38516708e-03, 6.56389678e-05,
#        5.27458921e-03, 9.28049503e-05, 2.20653327e-03, 6.54643568e-05,
#        6.83766144e-05, 1.13865094e-03, 8.50902282e-05, 4.55676790e-03])

# %%
test_log[:,1, 1]
# Out:
# array([7.17966663e-02, 8.87203699e-02, 4.96108361e-03, 2.84073499e-04,
#        3.49470988e-02, 9.49366081e-05, 2.27414291e-03, 1.66677183e-02,
#        4.34214866e-03, 4.55391152e-03, 4.35444101e-03, 3.42451331e-05,
#        4.81024965e-03, 5.05471539e-05, 3.03157644e-03, 6.78194467e-05,
#        5.08068478e-05, 1.10921586e-03, 1.21070443e-04, 4.59798907e-03])

# %%
# 创建一个图形窗口
plt.figure(figsize=(10, 6))

# 绘制每个模型在所有数据集上的loss
for model_idx in range(test_log.shape[1]):  # 遍历每个模型
    # 对每个模型，在所有数据集上进行平均
    avg_loss = test_log[:, 1, model_idx]
    plt.plot(avg_loss, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Model Loss Across Rounds')
plt.legend()

# 显示图形
plt.show()

# %%
log = test_log[:, 0, 0]
plt.plot(log, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Model Loss Across Rounds')
plt.legend()

# %%
log = test_log[:, 1, 0]
plt.plot(log, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Model Loss Across Rounds')
plt.legend()

# %%
log = test_log[:, 2, 0]
plt.plot(log, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Model Loss Across Rounds')
plt.legend()

# %%
# 创建一个图形窗口
plt.figure(figsize=(10, 6))

# 绘制每个模型在所有数据集上的loss
for model_idx in range(test_log.shape[1]):  # 遍历每个模型
    # 对每个模型，在所有数据集上进行平均
    avg_loss = np.mean(test_log[:, model_idx, :], axis=1)
    plt.plot(avg_loss, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Test: Model Loss Across Rounds')
plt.legend()

# 显示图形
plt.show()

train_log = np.load("0_train_loss_logs.npy")
# 创建一个图形窗口
plt.figure(figsize=(10, 6))

# 绘制每个模型在所有数据集上的loss
for model_idx in range(test_log.shape[1]):  # 遍历每个模型
    # 对每个模型，在所有数据集上进行平均
    avg_loss = np.mean(train_log[:, model_idx, :], axis=1)
    plt.plot(avg_loss, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Train: Model Loss Across Rounds')
plt.legend()

# 显示图形
plt.show()

# %%
avg_loss = np.mean(test_log[:, 0, :], axis=1)
avg_loss
# Out:
# array([4.36849837e-02, 4.63321938e-02, 2.90354507e-02, 8.44663049e-04,
#        7.89899091e-02, 1.95424464e-03, 2.38071096e-02, 2.38206311e-02,
#        3.54434323e-03, 2.69343739e-03, 2.67303493e-03, 1.85914571e-03,
#        1.77587950e-03, 2.30924849e-03, 2.11363420e-02, 1.04019426e-03,
#        5.72015990e-05, 3.24166540e-03, 3.19190701e-03, 4.37222161e-03])

# %%
avg_loss = np.mean(test_log[:, 0, :], axis=0)
avg_loss
# Out:
# array([0.02184806, 0.01197978, 0.01062673])

# %%
test_log[:, 0, :]
# Out:
# array([[4.73162524e-02, 7.05466467e-02, 1.31920521e-02],
#        [2.28575197e-03, 8.69154784e-02, 4.97953509e-02],
#        [8.42580500e-02, 1.94637210e-03, 9.01929886e-04],
#        [9.10411564e-04, 7.65428252e-04, 8.58149332e-04],
#        [1.82078721e-01, 3.45614299e-02, 2.03295767e-02],
#        [2.29013648e-03, 1.50320009e-04, 3.42227743e-03],
#        [2.57963574e-02, 2.32283210e-03, 4.33021392e-02],
#        [5.47049918e-02, 1.57109768e-02, 1.04592482e-03],
#        [5.85467665e-03, 4.55741717e-03, 2.20935861e-04],
#        [3.50056821e-03, 4.54967568e-03, 3.00682931e-05],
#        [5.72928071e-05, 4.39446503e-03, 3.56734696e-03],
#        [3.33408436e-03, 6.06369066e-05, 2.18271586e-03],
#        [1.17803608e-04, 5.08860798e-03, 1.21226912e-04],
#        [5.13534965e-03, 3.19808675e-05, 1.76041495e-03],
#        [1.24437038e-03, 2.13420266e-03, 6.00304528e-02],
#        [2.86737527e-03, 4.75354788e-05, 2.05672041e-04],
#        [5.59273941e-05, 5.12804421e-05, 6.43969607e-05],
#        [4.63672949e-03, 1.12697426e-03, 3.96129245e-03],
#        [4.99325714e-03, 4.91226254e-05, 4.53334127e-03],
#        [5.52308736e-03, 4.58417271e-03, 3.00940476e-03]])

# %%
reward_log =np.load("0_reward_logs.npy")

# %%
reward_log.shape
# Out:
# (20, 3)

# %%
exp_id = 0
test_log = np.load(str(exp_id) +"_test_loss_logs.npy")
reward_log =np.load(str(exp_id) +"_reward_logs.npy")



# 创建一个图形窗口
plt.figure(figsize=(10, 6))

# 绘制每个模型在所有数据集上的loss
for model_idx in range(test_log.shape[1]):  # 遍历每个模型
    # 对每个模型，在所有数据集上进行平均
    avg_loss = np.mean(test_log[:, model_idx, :], axis=1)
    plt.plot(avg_loss, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Average Loss')
plt.title('Model Loss Across Rounds')
plt.legend()

# 显示图形
plt.show()

# 创建一个图形窗口
plt.figure(figsize=(10, 6))

# 绘制每个模型在所有数据集上的loss
for model_idx in range(test_log.shape[1]):  # 遍历每个模型
    # 对每个模型，在所有数据集上进行平均
    avg_loss = np.mean(reward_log, axis=1)
    plt.plot(avg_loss, label=f'Model {model_idx}')

# 设置图形的标签和标题
plt.xlabel('Round')
plt.ylabel('Reward')
plt.title('Model Loss Across Rounds')
plt.legend()

# 显示图形
plt.show()
