# %%
from H_Envs.cartpole import CartPoleEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
gravitys = [9.8, 9.8, 9.8]
lengths = [0.5, 0.2, 0.8]


real_envs = []

for i in range(len(gravitys)):
    gravity = gravitys[i]
    length = lengths[i]
    
    env = TimeLimit(CartPoleEnv(length = length, gravity = gravity), max_episode_steps = 200)
    real_envs.append(env)

# %%
from stable_baselines3 import DQN

DQN_model =DQN("MlpPolicy", env = real_envs[0], learning_starts=1000,verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
DQN_model.learn(total_timesteps=100000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.5     |
# |    ep_rew_mean      | 41.5     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 11860    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 11045    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 254      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.8     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 10733    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 322      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 10821    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11001    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 484      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 10944    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 10884    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 653      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11043    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11074    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 897      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11011    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 958      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 6040     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1057     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.512    |
# |    n_updates        | 14       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4472     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1127     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.472    |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3367     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1236     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2729     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.333    |
# |    n_updates        | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1453     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.279    |
# |    n_updates        | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2178     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1604     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.207    |
# |    n_updates        | 150      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1977     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1707     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1888     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1766     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 191      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1786     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1842     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 210      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1545     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1946     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0752   |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1509     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2007     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0679   |
# |    n_updates        | 251      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1465     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2090     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 272      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1440     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 290      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1417     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2227     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 306      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1386     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2293     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 323      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1363     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2381     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 345      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1343     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2476     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1328     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2549     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1311     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 407      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1294     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2704     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00899  |
# |    n_updates        | 425      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1274     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2778     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00873  |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1260     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2896     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00596  |
# |    n_updates        | 473      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1248     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2987     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00856  |
# |    n_updates        | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1238     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3066     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 516      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1222     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 540      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1204     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3264     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 565      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1195     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3323     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00315  |
# |    n_updates        | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1188     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3391     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00366  |
# |    n_updates        | 597      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1171     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3500     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00771  |
# |    n_updates        | 624      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1164     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3557     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00251  |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1157     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3627     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00265  |
# |    n_updates        | 656      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1148     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3683     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00391  |
# |    n_updates        | 670      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1134     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3792     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 697      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1127     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3859     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00421  |
# |    n_updates        | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1116     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3929     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 732      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1106     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4015     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00247  |
# |    n_updates        | 753      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1100     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4072     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00158  |
# |    n_updates        | 767      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1089     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.001    |
# |    n_updates        | 790      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1079     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4242     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0014   |
# |    n_updates        | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1073     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4310     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00055  |
# |    n_updates        | 827      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1068     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4366     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00163  |
# |    n_updates        | 841      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1058     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4458     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 864      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1053     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4540     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00066  |
# |    n_updates        | 884      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1049     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4607     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000921 |
# |    n_updates        | 901      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1043     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4686     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1040     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4762     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0018   |
# |    n_updates        | 940      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1037     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4824     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00133  |
# |    n_updates        | 955      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1033     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4890     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000641 |
# |    n_updates        | 972      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.53     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1031     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4947     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000484 |
# |    n_updates        | 986      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1027     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5009     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000543 |
# |    n_updates        | 1002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1021     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5085     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000317 |
# |    n_updates        | 1021     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1018     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5153     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000323 |
# |    n_updates        | 1038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1016     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5213     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000732 |
# |    n_updates        | 1053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1013     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5286     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000243 |
# |    n_updates        | 1071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1010     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5349     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000815 |
# |    n_updates        | 1087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1006     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5404     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000449 |
# |    n_updates        | 1100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1002     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5462     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00251  |
# |    n_updates        | 1115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 994      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5545     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000828 |
# |    n_updates        | 1136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 984      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5609     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000315 |
# |    n_updates        | 1152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 978      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5679     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000792 |
# |    n_updates        | 1169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 971      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5752     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00203  |
# |    n_updates        | 1187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 968      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5821     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000228 |
# |    n_updates        | 1205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 966      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5894     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000813 |
# |    n_updates        | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.432    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 963      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5978     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000726 |
# |    n_updates        | 1244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 959      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6042     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000146 |
# |    n_updates        | 1260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.42     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 957      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6108     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 1276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 955      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00044  |
# |    n_updates        | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 947      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6231     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000995 |
# |    n_updates        | 1307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 942      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6314     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000597 |
# |    n_updates        | 1328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 939      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6386     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00125  |
# |    n_updates        | 1346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 937      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6455     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000384 |
# |    n_updates        | 1363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 933      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6530     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000443 |
# |    n_updates        | 1382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 925      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6606     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000803 |
# |    n_updates        | 1401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 922      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6690     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000281 |
# |    n_updates        | 1422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 920      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6793     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000111 |
# |    n_updates        | 1448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 908      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6886     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000178 |
# |    n_updates        | 1471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 906      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6964     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000181 |
# |    n_updates        | 1490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 904      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7043     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000604 |
# |    n_updates        | 1510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 897      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7124     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000369 |
# |    n_updates        | 1530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 893      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7201     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00037  |
# |    n_updates        | 1550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 892      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7279     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000742 |
# |    n_updates        | 1569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 887      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7366     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000676 |
# |    n_updates        | 1591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 884      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7444     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 1610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 880      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7553     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000944 |
# |    n_updates        | 1638     |
# ----------------------------------
# ----------------------------------
# ...
# |    time_elapsed     | 125      |
# |    total_timesteps  | 76115    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 18778    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 606      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 76915    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 18978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 605      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 77715    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 19178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 605      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 78500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00584  |
# |    n_updates        | 19374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 603      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 79300    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 19574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 603      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 80100    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0604   |
# |    n_updates        | 19774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 603      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 80883    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00281  |
# |    n_updates        | 19970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 604      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 81683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 20170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 603      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 82475    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00464  |
# |    n_updates        | 20368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 603      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 83269    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 20567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 603      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 84069    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00802  |
# |    n_updates        | 20767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 602      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 84869    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 20967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 602      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 85669    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00708  |
# |    n_updates        | 21167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 602      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 86466    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 21366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 602      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 87266    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00469  |
# |    n_updates        | 21566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 603      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 88058    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.144    |
# |    n_updates        | 21764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 603      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 88847    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00162  |
# |    n_updates        | 21961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 603      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 89647    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 22161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2252     |
# |    fps              | 604      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 90447    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 22361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2256     |
# |    fps              | 603      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 91232    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.19     |
# |    n_updates        | 22557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2260     |
# |    fps              | 603      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 92032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.434    |
# |    n_updates        | 22757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2264     |
# |    fps              | 604      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 92827    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00541  |
# |    n_updates        | 22956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2268     |
# |    fps              | 605      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 93604    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 23150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2272     |
# |    fps              | 605      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 94397    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 23349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2276     |
# |    fps              | 605      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 95195    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00357  |
# |    n_updates        | 23548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2280     |
# |    fps              | 606      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 95966    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00786  |
# |    n_updates        | 23741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2284     |
# |    fps              | 607      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 96761    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00402  |
# |    n_updates        | 23940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2288     |
# |    fps              | 607      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 97516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00519  |
# |    n_updates        | 24128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2292     |
# |    fps              | 607      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 98275    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 24318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2296     |
# |    fps              | 607      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 99057    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00994  |
# |    n_updates        | 24514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2300     |
# |    fps              | 608      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 99852    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.191    |
# |    n_updates        | 24712    |
# ----------------------------------

# %%
DQN_model.save("models/CartPole_DQN_Policy")

# %%
from H_Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
gravitys = [8.0, 10.0, 12.0]

real_envs = []
for i in range(len(gravitys)):
    gravity = gravitys[i]
    
    env = TimeLimit(PendulumEnv( g = gravity), max_episode_steps = 200)
    real_envs.append(env)

# %%
real_envs[1].g
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.g to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.g` for environment variables or `env.get_wrapper_attr('g')` that will search the reminding wrappers.
#   logger.warn(
# 10.0

# %%
from sb3_contrib import TRPO

# %%
TRPO_model = TRPO(policy="MlpPolicy",env=real_envs[1],verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TRPO_model.learn(total_timesteps=200000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.4e+03 |
# | time/              |          |
# |    fps             | 486      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.24e+03 |
# | time/                     |           |
# |    fps                    | 461       |
# |    iterations             | 2         |
# |    time_elapsed           | 8         |
# |    total_timesteps        | 4096      |
# | train/                    |           |
# |    explained_variance     | -0.00432  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00712   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 1         |
# |    policy_objective       | 0.0087    |
# |    std                    | 0.97      |
# |    value_loss             | 1.13e+04  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.19e+03 |
# | time/                     |           |
# |    fps                    | 462       |
# |    iterations             | 3         |
# |    time_elapsed           | 13        |
# |    total_timesteps        | 6144      |
# | train/                    |           |
# |    explained_variance     | 0.161     |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00693   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 2         |
# |    policy_objective       | 0.00914   |
# |    std                    | 0.961     |
# |    value_loss             | 5.98e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.17e+03 |
# | time/                     |           |
# |    fps                    | 464       |
# |    iterations             | 4         |
# |    time_elapsed           | 17        |
# |    total_timesteps        | 8192      |
# | train/                    |           |
# |    explained_variance     | 0.00554   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00861   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 3         |
# |    policy_objective       | 0.00672   |
# |    std                    | 0.931     |
# |    value_loss             | 6.66e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.14e+03 |
# | time/                     |           |
# |    fps                    | 463       |
# |    iterations             | 5         |
# |    time_elapsed           | 22        |
# |    total_timesteps        | 10240     |
# | train/                    |           |
# |    explained_variance     | 0.0024    |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00659   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 4         |
# |    policy_objective       | 0.00837   |
# |    std                    | 0.887     |
# |    value_loss             | 5.89e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.13e+03 |
# | time/                     |           |
# |    fps                    | 456       |
# |    iterations             | 6         |
# |    time_elapsed           | 26        |
# |    total_timesteps        | 12288     |
# | train/                    |           |
# |    explained_variance     | 0.00114   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00775   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 5         |
# |    policy_objective       | 0.00767   |
# |    std                    | 0.959     |
# |    value_loss             | 5.19e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.13e+03 |
# | time/                     |           |
# |    fps                    | 457       |
# |    iterations             | 7         |
# |    time_elapsed           | 31        |
# |    total_timesteps        | 14336     |
# | train/                    |           |
# |    explained_variance     | 0.000898  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00712   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 6         |
# |    policy_objective       | 0.0068    |
# |    std                    | 0.951     |
# |    value_loss             | 5.76e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.13e+03 |
# | time/                     |           |
# |    fps                    | 454       |
# |    iterations             | 8         |
# |    time_elapsed           | 36        |
# |    total_timesteps        | 16384     |
# | train/                    |           |
# |    explained_variance     | 0.000485  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00888   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 7         |
# |    policy_objective       | 0.0099    |
# |    std                    | 0.942     |
# |    value_loss             | 5.44e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.11e+03 |
# | time/                     |           |
# |    fps                    | 450       |
# |    iterations             | 9         |
# |    time_elapsed           | 40        |
# |    total_timesteps        | 18432     |
# | train/                    |           |
# |    explained_variance     | 0.00047   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00747   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 8         |
# |    policy_objective       | 0.00887   |
# |    std                    | 0.917     |
# |    value_loss             | 5.14e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -1.1e+03 |
# | time/                     |          |
# |    fps                    | 453      |
# |    iterations             | 10       |
# |    time_elapsed           | 45       |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 0.000317 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00583  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 9        |
# |    policy_objective       | 0.00775  |
# |    std                    | 0.887    |
# |    value_loss             | 4.01e+03 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.08e+03 |
# | time/                     |           |
# |    fps                    | 454       |
# |    iterations             | 11        |
# |    time_elapsed           | 49        |
# |    total_timesteps        | 22528     |
# | train/                    |           |
# |    explained_variance     | 0.00034   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00574   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 10        |
# |    policy_objective       | 0.00591   |
# |    std                    | 0.921     |
# |    value_loss             | 4.88e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.08e+03 |
# | time/                     |           |
# |    fps                    | 453       |
# |    iterations             | 12        |
# |    time_elapsed           | 54        |
# |    total_timesteps        | 24576     |
# | train/                    |           |
# |    explained_variance     | 0.000224  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00813   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 11        |
# |    policy_objective       | 0.008     |
# |    std                    | 0.922     |
# |    value_loss             | 4.49e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.08e+03 |
# | time/                     |           |
# |    fps                    | 452       |
# |    iterations             | 13        |
# |    time_elapsed           | 58        |
# |    total_timesteps        | 26624     |
# | train/                    |           |
# |    explained_variance     | 0.000133  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00732   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 12        |
# |    policy_objective       | 0.00974   |
# |    std                    | 0.935     |
# |    value_loss             | 3.95e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.07e+03 |
# | time/                     |           |
# |    fps                    | 449       |
# |    iterations             | 14        |
# |    time_elapsed           | 63        |
# |    total_timesteps        | 28672     |
# | train/                    |           |
# |    explained_variance     | 0.000124  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00691   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 13        |
# |    policy_objective       | 0.00961   |
# |    std                    | 0.902     |
# |    value_loss             | 3.73e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.07e+03 |
# | time/                     |           |
# |    fps                    | 446       |
# |    iterations             | 15        |
# |    time_elapsed           | 68        |
# |    total_timesteps        | 30720     |
# | train/                    |           |
# |    explained_variance     | 0.000109  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0079    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 14        |
# |    policy_objective       | 0.00774   |
# |    std                    | 0.914     |
# |    value_loss             | 3.28e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.06e+03 |
# | time/                     |           |
# |    fps                    | 446       |
# |    iterations             | 16        |
# |    time_elapsed           | 73        |
# |    total_timesteps        | 32768     |
# | train/                    |           |
# |    explained_variance     | 9.95e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00639   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 15        |
# |    policy_objective       | 0.00805   |
# |    std                    | 0.88      |
# |    value_loss             | 3.59e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.05e+03 |
# | time/                     |           |
# |    fps                    | 443       |
# |    iterations             | 17        |
# |    time_elapsed           | 78        |
# |    total_timesteps        | 34816     |
# | train/                    |           |
# |    explained_variance     | 0.000101  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00579   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 16        |
# |    policy_objective       | 0.00642   |
# |    std                    | 0.894     |
# |    value_loss             | 3.05e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.05e+03 |
# | time/                     |           |
# |    fps                    | 439       |
# |    iterations             | 18        |
# |    time_elapsed           | 83        |
# |    total_timesteps        | 36864     |
# | train/                    |           |
# |    explained_variance     | 9.13e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00738   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 17        |
# |    policy_objective       | 0.0111    |
# |    std                    | 0.918     |
# |    value_loss             | 3.2e+03   |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.05e+03 |
# | time/                     |           |
# |    fps                    | 431       |
# |    iterations             | 19        |
# |    time_elapsed           | 90        |
# |    total_timesteps        | 38912     |
# | train/                    |           |
# |    explained_variance     | 7.65e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00441   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 18        |
# |    policy_objective       | 0.00795   |
# |    std                    | 0.919     |
# |    value_loss             | 2.48e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.03e+03 |
# | time/                     |           |
# |    fps                    | 425       |
# |    iterations             | 20        |
# |    time_elapsed           | 96        |
# |    total_timesteps        | 40960     |
# | train/                    |           |
# |    explained_variance     | 6.85e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00606   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 19        |
# |    policy_objective       | 0.00687   |
# |    std                    | 0.947     |
# |    value_loss             | 2.62e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.01e+03 |
# | time/                     |           |
# |    fps                    | 419       |
# |    iterations             | 21        |
# |    time_elapsed           | 102       |
# |    total_timesteps        | 43008     |
# | train/                    |           |
# |    explained_variance     | 5.96e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00695   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 20        |
# |    policy_objective       | 0.0114    |
# |    std                    | 0.932     |
# |    value_loss             | 2.39e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -998     |
# | time/                     |          |
# |    fps                    | 413      |
# |    iterations             | 22       |
# |    time_elapsed           | 108      |
# |    total_timesteps        | 45056    |
# | train/                    |          |
# |    explained_variance     | 5.63e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00783  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 21       |
# |    policy_objective       | 0.0115   |
# |    std                    | 0.918    |
# |    value_loss             | 1.75e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -984     |
# | time/                     |          |
# |    fps                    | 410      |
# |    iterations             | 23       |
# |    time_elapsed           | 114      |
# |    total_timesteps        | 47104    |
# | train/                    |          |
# |    explained_variance     | 4.96e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00759  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 22       |
# |    policy_objective       | 0.0102   |
# |    std                    | 0.92     |
# |    value_loss             | 1.62e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -971     |
# | time/                     |          |
# |    fps                    | 405      |
# |    iterations             | 24       |
# |    time_elapsed           | 121      |
# |    total_timesteps        | 49152    |
# | train/                    |          |
# |    explained_variance     | 4.37e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0078   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 23       |
# |    policy_objective       | 0.015    |
# |    std                    | 0.924    |
# |    value_loss             | 1.89e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -954     |
# | time/                     |          |
# |    fps                    | 402      |
# |    iterations             | 25       |
# |    time_elapsed           | 127      |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 4.5e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00926  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 24       |
# |    policy_objective       | 0.0152   |
# |    std                    | 0.909    |
# |    value_loss             | 1.35e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -931     |
# | time/                     |          |
# |    fps                    | 399      |
# |    iterations             | 26       |
# |    time_elapsed           | 133      |
# |    total_timesteps        | 53248    |
# | train/                    |          |
# |    explained_variance     | 4.04e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0086   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 25       |
# |    policy_objective       | 0.0108   |
# |    std                    | 0.874    |
# |    value_loss             | 1.45e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -922     |
# | time/                     |          |
# |    fps                    | 397      |
# |    iterations             | 27       |
# |    time_elapsed           | 138      |
# |    total_timesteps        | 55296    |
# | train/                    |          |
# |    explained_variance     | 4.33e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00799  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 26       |
# |    policy_objective       | 0.0149   |
# |    std                    | 0.849    |
# |    value_loss             | 1.4e+03  |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -909     |
# | time/                     |          |
# |    fps                    | 396      |
# |    iterations             | 28       |
# |    time_elapsed           | 144      |
# |    total_timesteps        | 57344    |
# | train/                    |          |
# |    explained_variance     | 4.08e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00586  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 27       |
# |    policy_objective       | 0.00737  |
# |    std                    | 0.856    |
# |    value_loss             | 1.34e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -895     |
# | time/                     |          |
# |    fps                    | 394      |
# |    iterations             | 29       |
# |    time_elapsed           | 150      |
# |    total_timesteps        | 59392    |
# | train/                    |          |
# |    explained_variance     | 3.86e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00681  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 28       |
# |    policy_objective       | 0.0144   |
# |    std                    | 0.855    |
# |    value_loss             | 1.12e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -888     |
# | time/                     |          |
# |    fps                    | 392      |
# |    iterations             | 30       |
# |    time_elapsed           | 156      |
# |    total_timesteps        | 61440    |
# | train/                    |          |
# |    explained_variance     | 3.95e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00761  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 29       |
# |    policy_objective       | 0.0147   |
# |    std                    | 0.847    |
# |    value_loss             | 1.18e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -880     |
# | time/                     |          |
# |    fps                    | 391      |
# |    iterations             | 31       |
# |    time_elapsed           | 162      |
# |    total_timesteps        | 63488    |
# | train/                    |          |
# |    explained_variance     | 3.6e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00827  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 30       |
# |    policy_objective       | 0.00957  |
# |    std                    | 0.83     |
# |    value_loss             | 1.14e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -875     |
# | time/                     |          |
# |    fps                    | 390      |
# |    iterations             | 32       |
# |    time_elapsed           | 167      |
# |    total_timesteps        | 65536    |
# | train/                    |          |
# |    explained_variance     | 3.36e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0094   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 31       |
# |    policy_objective       | 0.0129   |
# |    std                    | 0.796    |
# |    value_loss             | 846      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -874     |
# | time/                     |          |
# |    fps                    | 389      |
# |    iterations             | 33       |
# |    time_elapsed           | 173      |
# |    total_timesteps        | 67584    |
# | train/                    |          |
# |    explained_variance     | 3.37e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00723  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 32       |
# |    policy_objective       | 0.0157   |
# |    std                    | 0.776    |
# |    value_loss             | 877      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -862     |
# | time/                     |          |
# |    fps                    | 387      |
# |    iterations             | 34       |
# |    time_elapsed           | 179      |
# |    total_timesteps        | 69632    |
# | train/                    |          |
# |    explained_variance     | 3.12e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00746  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 33       |
# |    policy_objective       | 0.0105   |
# |    std                    | 0.743    |
# |    value_loss             | 1.54e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -860     |
# | time/                     |          |
# |    fps                    | 386      |
# |    iterations             | 35       |
# |    time_elapsed           | 185      |
# |    total_timesteps        | 71680    |
# | train/                    |          |
# |    explained_variance     | 3.8e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00891  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 34       |
# |    policy_objective       | 0.0115   |
# |    std                    | 0.758    |
# |    value_loss             | 781      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -843     |
# | time/                     |          |
# |    fps                    | 385      |
# |    iterations             | 36       |
# |    time_elapsed           | 191      |
# |    total_timesteps        | 73728    |
# | train/                    |          |
# |    explained_variance     | 3.8e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00859  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 35       |
# |    policy_objective       | 0.0125   |
# |    std                    | 0.752    |
# |    value_loss             | 837      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -828     |
# | time/                     |          |
# |    fps                    | 384      |
# |    iterations             | 37       |
# |    time_elapsed           | 197      |
# |    total_timesteps        | 75776    |
# | train/                    |          |
# |    explained_variance     | 4.46e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00822  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 36       |
# |    policy_objective       | 0.0148   |
# |    std                    | 0.765    |
# |    value_loss             | 720      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -819     |
# | time/                     |          |
# |    fps                    | 382      |
# |    iterations             | 38       |
# |    time_elapsed           | 203      |
# |    total_timesteps        | 77824    |
# | train/                    |          |
# |    explained_variance     | 5.58e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00868  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 37       |
# |    policy_objective       | 0.0131   |
# |    std                    | 0.77     |
# |    value_loss             | 626      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -810     |
# | time/                     |          |
# |    fps                    | 381      |
# |    iterations             | 39       |
# |    time_elapsed           | 209      |
# |    total_timesteps        | 79872    |
# | train/                    |          |
# |    explained_variance     | 6.5e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00694  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 38       |
# |    policy_objective       | 0.0102   |
# |    std                    | 0.749    |
# |    value_loss             | 883      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -794     |
# | time/                     |          |
# |    fps                    | 380      |
# |    iterations             | 40       |
# |    time_elapsed           | 215      |
# |    total_timesteps        | 81920    |
# | train/                    |          |
# |    explained_variance     | 0.000132 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00822  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 39       |
# |    policy_objective       | 0.0155   |
# |    std                    | 0.746    |
# |    value_loss             | 891      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -791     |
# | time/                     |          |
# |    fps                    | 379      |
# |    iterations             | 41       |
# |    time_elapsed           | 221      |
# |    total_timesteps        | 83968    |
# | train/                    |          |
# |    explained_variance     | 0.355    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00754  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 40       |
# |    policy_objective       | 0.0155   |
# |    std                    | 0.751    |
# |    value_loss             | 707      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -786     |
# | time/                     |          |
# |    fps                    | 378      |
# |    iterations             | 42       |
# |    time_elapsed           | 227      |
# |    total_timesteps        | 86016    |
# | train/                    |          |
# |    explained_variance     | 0.654    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00735  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 41       |
# |    policy_objective       | 0.0172   |
# |    std                    | 0.741    |
# |    value_loss             | 338      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -764     |
# | time/                     |          |
# |    fps                    | 377      |
# |    iterations             | 43       |
# |    time_elapsed           | 233      |
# |    total_timesteps        | 88064    |
# | train/                    |          |
# |    explained_variance     | 0.67     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00809  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 42       |
# |    policy_objective       | 0.015    |
# |    std                    | 0.724    |
# |    value_loss             | 559      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -759     |
# | time/                     |          |
# |    fps                    | 377      |
# |    iterations             | 44       |
# |    time_elapsed           | 238      |
# |    total_timesteps        | 90112    |
# | train/                    |          |
# |    explained_variance     | 0.698    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00694  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 43       |
# |    policy_objective       | 0.0159   |
# |    std                    | 0.728    |
# |    value_loss             | 325      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -743     |
# | time/                     |          |
# |    fps                    | 376      |
# |    iterations             | 45       |
# |    time_elapsed           | 244      |
# |    total_timesteps        | 92160    |
# | train/                    |          |
# |    explained_variance     | 0.709    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00605  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 44       |
# |    policy_objective       | 0.0134   |
# |    std                    | 0.713    |
# |    value_loss             | 499      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -726     |
# | time/                     |          |
# |    fps                    | 375      |
# |    iterations             | 46       |
# |    time_elapsed           | 250      |
# |    total_timesteps        | 94208    |
# | train/                    |          |
# |    explained_variance     | 0.737    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00781  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 45       |
# |    policy_objective       | 0.0194   |
# |    std                    | 0.708    |
# |    value_loss             | 346      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -720     |
# | time/                     |          |
# |    fps                    | 375      |
# |    iterations             | 47       |
# |    time_elapsed           | 256      |
# |    total_timesteps        | 96256    |
# | train/                    |          |
# |    explained_variance     | 0.83     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00779  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 46       |
# |    policy_objective       | 0.0247   |
# |    std                    | 0.697    |
# |    value_loss             | 208      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -683     |
# | time/                     |          |
# |    fps                    | 374      |
# |    iterations             | 48       |
# |    time_elapsed           | 262      |
# |    total_timesteps        | 98304    |
# | train/                    |          |
# |    explained_variance     | 0.799    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00673  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 47       |
# |    policy_objective       | 0.0205   |
# |    std                    | 0.673    |
# |    value_loss             | 279      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -659     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 49       |
# |    time_elapsed           | 268      |
# |    total_timesteps        | 100352   |
# | train/                    |          |
# |    explained_variance     | 0.837    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00771  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 48       |
# |    policy_objective       | 0.0227   |
# |    std                    | 0.666    |
# |    value_loss             | 225      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -639     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 50       |
# |    time_elapsed           | 274      |
# |    total_timesteps        | 102400   |
# | train/                    |          |
# |    explained_variance     | 0.884    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00703  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 49       |
# |    policy_objective       | 0.0202   |
# |    std                    | 0.657    |
# |    value_loss             | 175      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -594     |
# | time/                     |          |
# |    fps                    | 374      |
# |    iterations             | 51       |
# |    time_elapsed           | 278      |
# |    total_timesteps        | 104448   |
# | train/                    |          |
# |    explained_variance     | 0.851    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00773  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 50       |
# |    policy_objective       | 0.0166   |
# |    std                    | 0.639    |
# |    value_loss             | 580      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -540     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 52       |
# |    time_elapsed           | 284      |
# |    total_timesteps        | 106496   |
# | train/                    |          |
# |    explained_variance     | 0.91     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00839  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 51       |
# |    policy_objective       | 0.0277   |
# |    std                    | 0.62     |
# |    value_loss             | 242      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -500     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 53       |
# |    time_elapsed           | 290      |
# |    total_timesteps        | 108544   |
# | train/                    |          |
# |    explained_variance     | 0.947    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00792  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 52       |
# |    policy_objective       | 0.0326   |
# |    std                    | 0.614    |
# |    value_loss             | 195      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -469     |
# | time/                     |          |
# |    fps                    | 372      |
# |    iterations             | 54       |
# |    time_elapsed           | 296      |
# |    total_timesteps        | 110592   |
# | train/                    |          |
# |    explained_variance     | 0.939    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00605  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 53       |
# |    policy_objective       | 0.0173   |
# |    std                    | 0.611    |
# |    value_loss             | 204      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -420     |
# | time/                     |          |
# |    fps                    | 372      |
# |    iterations             | 55       |
# |    time_elapsed           | 302      |
# |    total_timesteps        | 112640   |
# | train/                    |          |
# |    explained_variance     | 0.959    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00825  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 54       |
# |    policy_objective       | 0.0158   |
# |    std                    | 0.596    |
# |    value_loss             | 181      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -384     |
# | time/                     |          |
# |    fps                    | 371      |
# |    iterations             | 56       |
# |    time_elapsed           | 308      |
# |    total_timesteps        | 114688   |
# | train/                    |          |
# |    explained_variance     | 0.979    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0073   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 55       |
# |    policy_objective       | 0.0266   |
# |    std                    | 0.585    |
# |    value_loss             | 79.8     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -348     |
# | time/                     |          |
# |    fps                    | 371      |
# |    iterations             | 57       |
# |    time_elapsed           | 314      |
# |    total_timesteps        | 116736   |
# | train/                    |          |
# |    explained_variance     | 0.98     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00908  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 56       |
# |    policy_objective       | 0.0395   |
# |    std                    | 0.578    |
# |    value_loss             | 75.4     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -320     |
# | time/                     |          |
# |    fps                    | 371      |
# |    iterations             | 58       |
# |    time_elapsed           | 320      |
# |    total_timesteps        | 118784   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00804  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 57       |
# |    policy_objective       | 0.0438   |
# |    std                    | 0.581    |
# |    value_loss             | 65.2     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -291     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 59       |
# |    time_elapsed           | 325      |
# |    total_timesteps        | 120832   |
# | train/                    |          |
# |    explained_variance     | 0.93     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00753  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 58       |
# |    policy_objective       | 0.0207   |
# |    std                    | 0.586    |
# |    value_loss             | 91.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -258     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 60       |
# |    time_elapsed           | 331      |
# |    total_timesteps        | 122880   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00718  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 59       |
# |    policy_objective       | 0.0169   |
# |    std                    | 0.588    |
# |    value_loss             | 57.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -253     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 61       |
# |    time_elapsed           | 337      |
# |    total_timesteps        | 124928   |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00799  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 60       |
# |    policy_objective       | 0.0203   |
# |    std                    | 0.571    |
# |    value_loss             | 59.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -246     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 62       |
# |    time_elapsed           | 343      |
# |    total_timesteps        | 126976   |
# | train/                    |          |
# |    explained_variance     | 0.977    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00843  |
# ...
# | train/                    |          |
# |    explained_variance     | 0.966    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00735  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 77       |
# |    policy_objective       | 0.028    |
# |    std                    | 0.576    |
# |    value_loss             | 28.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 79       |
# |    time_elapsed           | 440      |
# |    total_timesteps        | 161792   |
# | train/                    |          |
# |    explained_variance     | 0.995    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00667  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 78       |
# |    policy_objective       | 0.0224   |
# |    std                    | 0.571    |
# |    value_loss             | 2.71     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 80       |
# |    time_elapsed           | 446      |
# |    total_timesteps        | 163840   |
# | train/                    |          |
# |    explained_variance     | 0.889    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00761  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 79       |
# |    policy_objective       | 0.0244   |
# |    std                    | 0.569    |
# |    value_loss             | 91.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 366      |
# |    iterations             | 81       |
# |    time_elapsed           | 452      |
# |    total_timesteps        | 165888   |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00876  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 80       |
# |    policy_objective       | 0.0295   |
# |    std                    | 0.565    |
# |    value_loss             | 25.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 366      |
# |    iterations             | 82       |
# |    time_elapsed           | 458      |
# |    total_timesteps        | 167936   |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00778  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 81       |
# |    policy_objective       | 0.0191   |
# |    std                    | 0.557    |
# |    value_loss             | 8.86     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 83       |
# |    time_elapsed           | 464      |
# |    total_timesteps        | 169984   |
# | train/                    |          |
# |    explained_variance     | 0.946    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.007    |
# |    learning_rate          | 0.001    |
# |    n_updates              | 82       |
# |    policy_objective       | 0.022    |
# |    std                    | 0.561    |
# |    value_loss             | 40.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -164     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 84       |
# |    time_elapsed           | 470      |
# |    total_timesteps        | 172032   |
# | train/                    |          |
# |    explained_variance     | 0.991    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00693  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 83       |
# |    policy_objective       | 0.0258   |
# |    std                    | 0.563    |
# |    value_loss             | 5.52     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -165     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 85       |
# |    time_elapsed           | 476      |
# |    total_timesteps        | 174080   |
# | train/                    |          |
# |    explained_variance     | 0.975    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00746  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 84       |
# |    policy_objective       | 0.0311   |
# |    std                    | 0.562    |
# |    value_loss             | 30.3     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -170     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 86       |
# |    time_elapsed           | 482      |
# |    total_timesteps        | 176128   |
# | train/                    |          |
# |    explained_variance     | 0.985    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00843  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 85       |
# |    policy_objective       | 0.0345   |
# |    std                    | 0.573    |
# |    value_loss             | 8.76     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -170     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 87       |
# |    time_elapsed           | 487      |
# |    total_timesteps        | 178176   |
# | train/                    |          |
# |    explained_variance     | 0.99     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00702  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 86       |
# |    policy_objective       | 0.0203   |
# |    std                    | 0.57     |
# |    value_loss             | 9.55     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -180     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 88       |
# |    time_elapsed           | 493      |
# |    total_timesteps        | 180224   |
# | train/                    |          |
# |    explained_variance     | 0.99     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00665  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 87       |
# |    policy_objective       | 0.0268   |
# |    std                    | 0.565    |
# |    value_loss             | 12.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -179     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 89       |
# |    time_elapsed           | 499      |
# |    total_timesteps        | 182272   |
# | train/                    |          |
# |    explained_variance     | 0.995    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00957  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 88       |
# |    policy_objective       | 0.0427   |
# |    std                    | 0.576    |
# |    value_loss             | 6.52     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -176     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 90       |
# |    time_elapsed           | 505      |
# |    total_timesteps        | 184320   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00685  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 89       |
# |    policy_objective       | 0.0449   |
# |    std                    | 0.586    |
# |    value_loss             | 6.82     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 91       |
# |    time_elapsed           | 511      |
# |    total_timesteps        | 186368   |
# | train/                    |          |
# |    explained_variance     | 0.973    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00424  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 90       |
# |    policy_objective       | 0.0261   |
# |    std                    | 0.587    |
# |    value_loss             | 25.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -174     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 92       |
# |    time_elapsed           | 516      |
# |    total_timesteps        | 188416   |
# | train/                    |          |
# |    explained_variance     | 0.985    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0057   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 91       |
# |    policy_objective       | 0.0301   |
# |    std                    | 0.586    |
# |    value_loss             | 10.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -177     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 93       |
# |    time_elapsed           | 522      |
# |    total_timesteps        | 190464   |
# | train/                    |          |
# |    explained_variance     | 0.984    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00838  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 92       |
# |    policy_objective       | 0.017    |
# |    std                    | 0.586    |
# |    value_loss             | 4.35     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -171     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 94       |
# |    time_elapsed           | 529      |
# |    total_timesteps        | 192512   |
# | train/                    |          |
# |    explained_variance     | 0.982    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00831  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 93       |
# |    policy_objective       | 0.0465   |
# |    std                    | 0.585    |
# |    value_loss             | 17.1     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -173     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 95       |
# |    time_elapsed           | 535      |
# |    total_timesteps        | 194560   |
# | train/                    |          |
# |    explained_variance     | 0.935    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00854  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 94       |
# |    policy_objective       | 0.0242   |
# |    std                    | 0.601    |
# |    value_loss             | 31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -172     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 96       |
# |    time_elapsed           | 540      |
# |    total_timesteps        | 196608   |
# | train/                    |          |
# |    explained_variance     | 0.942    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00848  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 95       |
# |    policy_objective       | 0.0231   |
# |    std                    | 0.601    |
# |    value_loss             | 9.35     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 97       |
# |    time_elapsed           | 546      |
# |    total_timesteps        | 198656   |
# | train/                    |          |
# |    explained_variance     | 0.982    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00834  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 96       |
# |    policy_objective       | 0.0224   |
# |    std                    | 0.595    |
# |    value_loss             | 14.8     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 98       |
# |    time_elapsed           | 552      |
# |    total_timesteps        | 200704   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00981  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 97       |
# |    policy_objective       | 0.0308   |
# |    std                    | 0.602    |
# |    value_loss             | 12.1     |
# ----------------------------------------

# %%
TRPO_model.save("models/Pendulmn_TRPO_Policy")

# %%
from sb3_contrib import TRPO
from Client_diff import FRLClient
from Agent import SB3Agent
import copy
from stable_baselines3.common.evaluation import evaluate_policy
import torch
from H_Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def evaluate_clients_models(clients, device='cuda' if torch.cuda.is_available() else 'cpu'):
    evaluation_results = {i: [] for i in range(len(clients))}

    for i, client in enumerate(clients):
        client.model.to(device)  # 将模型移动到指定设备
        for j, other_client in enumerate(clients):
            inputs = other_client.test_X.astype(np.float32).values
            labels = other_client.test_y.astype(np.float32).values
            
            inputs = torch.tensor(inputs).to(device)
            labels = torch.tensor(labels).to(device)

            with torch.no_grad():
                outputs = client.model(inputs)
                loss = mean_squared_error(outputs.cpu().numpy(), labels.cpu().numpy())  # 将张量移回 CPU 进行计算

            evaluation_results[i].append(loss)
            print(f"Client {i} evaluated on Client {j}'s data - MSE Loss: {loss:.4f}")

    return evaluation_results

# %%
# 初始化
TRPO_model = TRPO.load("models/Pendulmn_TRPO_Policy")

timesteps_real_per_round = 500
timesteps_fc_per_round = timesteps_real_per_round * 30
epoch_per_round = 100
CLIENTS_NUM = 3
rounds_num = 10
batch_size_env_model = 128
Global_RL = TRPO_model

gravitys = [8.0, 10.0, 12.0]
real_envs = []

# 初始化真实环境
for gravity in gravitys:
    env = TimeLimit(PendulumEnv(g=gravity), max_episode_steps=200)
    real_envs.append(env)

# 记录每个 round 的数据
round_train_loss = []
round_test_avg = []
round_evaluation_results = []

for round_idx in range(rounds_num):
    env_models = []
    Clients = []
    
    for i in range(CLIENTS_NUM):
        policy_net = Global_RL
        agent = SB3Agent(policy_net)
        client = FRLClient(real_envs[i], agent, lr=3e-4, hidden_size=256, device=device)
        Clients.append(client)
        env_model = copy.deepcopy(client.model)
        env_models.append(env_model)
    
    train_loss_list = []
    test_avg_list = []

    for client_idx in range(len(Clients)):
        print('------------------------------')
        print("client: " + str(client_idx))
        # update policy
        # train prediction models
        Clients[client_idx].learn(timesteps_real_per_round, epoch_per_round, batch_size_env_model)
        train_loss_list.append(Clients[client_idx].train_loss_list)
        test_avg_list.append(Clients[client_idx].test_avg_list)
    
    evaluation_results = evaluate_clients_models(Clients)

    round_train_loss.append(train_loss_list)
    round_test_avg.append(test_avg_list)
    round_evaluation_results.append(evaluation_results)
# Out:
# ------------------------------
# client: 0
# Avg loss: 0.027727382965834598!
# Avg loss: 0.022213299819268287!
# Avg loss: 0.01910459987887104!
# Avg loss: 0.01709465267599929!
# Avg loss: 0.015104095106265352!
# Avg loss: 0.013255485554312448!
# Avg loss: 0.011605426305110692!
# Avg loss: 0.010699762162757906!
# Avg loss: 0.010419092330836672!
# Avg loss: 0.010296272874353841!
# Avg loss: 0.009892646341231739!
# Avg loss: 0.009592863914731424!
# Avg loss: 0.009490011509956275!
# Avg loss: 0.00947264399486509!
# Avg loss: 0.00932773125150561!
# Avg loss: 0.009215808068981157!
# Avg loss: 0.009186711348885788!
# Avg loss: 0.009127037809604796!
# Avg loss: 0.009093129385444551!
# Avg loss: 0.00909705930780774!
# Avg loss: 0.009071985753676775!
# Avg loss: 0.009038377364469549!
# Avg loss: 0.00904273170667731!
# Avg loss: 0.009030171892637781!
# Avg loss: 0.008990214141631063!
# Avg loss: 0.008972762781187764!
# Avg loss: 0.008971815269908347!
# Avg loss: 0.008961962887542162!
# Avg loss: 0.008951363859046069!
# Avg loss: 0.008953314813003696!
# Avg loss: 0.008952813490544524!
# Avg loss: 0.008950384524402277!
# Avg loss: 0.008946671576908708!
# Avg loss: 0.008942410007920594!
# Avg loss: 0.00894382307805453!
# Avg loss: 0.008940406846753225!
# Avg loss: 0.008933882948837967!
# Avg loss: 0.008932294270648527!
# Avg loss: 0.008929512210909252!
# Avg loss: 0.008924747467084822!
# Avg loss: 0.008923786293266858!
# Avg loss: 0.008922093025320236!
# Avg loss: 0.008920489810575418!
# Avg loss: 0.008918135916869687!
# Avg loss: 0.008917135082429013!
# Avg loss: 0.008916029350953068!
# Avg loss: 0.008914900123351496!
# Avg loss: 0.008913187349260927!
# Avg loss: 0.008912764432775853!
# Avg loss: 0.008911139601362568!
# Avg loss: 0.008910404156065017!
# Avg loss: 0.008908874264839899!
# Avg loss: 0.008909107482265123!
# Avg loss: 0.008907578257838698!
# Avg loss: 0.008907502608876712!
# Avg loss: 0.008905930311505775!
# Avg loss: 0.008906232429334296!
# Avg loss: 0.008904650606041287!
# Avg loss: 0.008905774862985254!
# Avg loss: 0.008903352049273205!
# Avg loss: 0.008904842809483095!
# Avg loss: 0.008902238925796079!
# Avg loss: 0.008904771167414083!
# Avg loss: 0.008901324031545907!
# Avg loss: 0.008905365384066121!
# Avg loss: 0.008900302457378946!
# Avg loss: 0.008905963762676569!
# Avg loss: 0.00889921272588424!
# Avg loss: 0.00890668697367308!
# Avg loss: 0.008897675060910614!
# Avg loss: 0.008908089925505085!
# Avg loss: 0.008896558961371426!
# Avg loss: 0.008910374033569611!
# Avg loss: 0.008896118595410769!
# Avg loss: 0.008913968746263757!
# Avg loss: 0.00889554613775753!
# Avg loss: 0.008919176030183374!
# Avg loss: 0.008896670878429424!
# Avg loss: 0.008928711779830109!
# Avg loss: 0.008899278496913894!
# Avg loss: 0.008947540722394932!
# Avg loss: 0.008906476401202592!
# Avg loss: 0.008989464276100988!
# Avg loss: 0.008931641322171042!
# Avg loss: 0.009095937311255207!
# Avg loss: 0.009013748877447748!
# ------------------------------
# client: 1
# Avg loss: 0.027579999671143014!
# Avg loss: 0.02763725862848029!
# Avg loss: 0.022022245399421082!
# Avg loss: 0.01632635467141275!
# Avg loss: 0.014035857520745291!
# Avg loss: 0.011625363651255612!
# Avg loss: 0.009490333326666586!
# Avg loss: 0.008606210772001455!
# Avg loss: 0.007460574771803294!
# Avg loss: 0.006721222350273213!
# Avg loss: 0.006399150634218434!
# Avg loss: 0.005820863456186392!
# Avg loss: 0.00550962582625895!
# Avg loss: 0.005283131294054329!
# Avg loss: 0.005301112816447737!
# Avg loss: 0.0052749286412048!
# Avg loss: 0.005107976554064871!
# Avg loss: 0.004986109050454388!
# Avg loss: 0.004971554491633772!
# Avg loss: 0.00497925353886482!
# Avg loss: 0.004889094601204912!
# Avg loss: 0.004809557477079807!
# Avg loss: 0.004798982853329411!
# Avg loss: 0.004795074512853717!
# Avg loss: 0.004755824651447256!
# Avg loss: 0.004732378371799465!
# Avg loss: 0.004728349376569743!
# Avg loss: 0.004717816837801744!
# Avg loss: 0.00470500158876348!
# Avg loss: 0.004695352398095262!
# Avg loss: 0.004693520759742569!
# Avg loss: 0.004687962634626122!
# Avg loss: 0.004677563677236094!
# Avg loss: 0.0046734796123272795!
# Avg loss: 0.004670374664273899!
# Avg loss: 0.004665676777657003!
# Avg loss: 0.004657507312603381!
# Avg loss: 0.004651330049305595!
# Avg loss: 0.004646926962933549!
# Avg loss: 0.004646216876718654!
# Avg loss: 0.004640171862995999!
# Avg loss: 0.004636997170208967!
# Avg loss: 0.00463430024703257!
# Avg loss: 0.004631132568035431!
# Avg loss: 0.0046296720343900685!
# Avg loss: 0.004626904950714467!
# Avg loss: 0.004624645755981192!
# Avg loss: 0.0046221554031124394!
# Avg loss: 0.004615612072993448!
# Avg loss: 0.004613175152541752!
# Avg loss: 0.004611618158167138!
# Avg loss: 0.004609980701344038!
# Avg loss: 0.004603797294998818!
# Avg loss: 0.004604542058807605!
# Avg loss: 0.0046072797985656656!
# Avg loss: 0.00460302732979585!
# Avg loss: 0.004598936859519919!
# Avg loss: 0.004592744060742007!
# Avg loss: 0.004593549696383358!
# Avg loss: 0.004593325911378277!
# Avg loss: 0.004591966575106975!
# Avg loss: 0.004590926890818802!
# Avg loss: 0.004590222695937929!
# Avg loss: 0.004590025563416778!
# Avg loss: 0.004585273674847106!
# Avg loss: 0.004580520043918644!
# Avg loss: 0.004581200890645126!
# Avg loss: 0.004584214730928503!
# Avg loss: 0.004581516409331811!
# Avg loss: 0.004576940590067124!
# Avg loss: 0.004574329122256889!
# Avg loss: 0.004573999603542991!
# Avg loss: 0.0045720586964275375!
# Avg loss: 0.0045730792175040355!
# Avg loss: 0.004572925965107212!
# Avg loss: 0.0045724281504135435!
# Avg loss: 0.004568043367158528!
# Avg loss: 0.004565567634225545!
# Avg loss: 0.004565171414039924!
# Avg loss: 0.004568573370631081!
# Avg loss: 0.004566355713896542!
# Avg loss: 0.004563137122828399!
# Avg loss: 0.004561679511844356!
# Avg loss: 0.004562714943183816!
# Avg loss: 0.004560643959437129!
# Avg loss: 0.0045633427595167106!
# Avg loss: 0.004561766507030522!
# Avg loss: 0.004559217440396802!
# Avg loss: 0.004551366868657094!
# Avg loss: 0.004555762121526167!
# Avg loss: 0.004556542087382714!
# Avg loss: 0.004555256757597969!
# Avg loss: 0.00455145743689016!
# Avg loss: 0.004552075280755617!
# Avg loss: 0.004549680242327554!
# Avg loss: 0.004552019967562728!
# Avg loss: 0.0045500763364270825!
# Avg loss: 0.004550709428901314!
# Avg loss: 0.004546138572267656!
# Avg loss: 0.004548266312695735!
# ------------------------------
# client: 2
# Avg loss: 0.0485564071748134!
# Avg loss: 0.0385238195421213!
# Avg loss: 0.029420152673683333!
# Avg loss: 0.0236160432499067!
# Avg loss: 0.019396012572494025!
# Avg loss: 0.01624575087140935!
# Avg loss: 0.013897506925877679!
# Avg loss: 0.012559348767366222!
# Avg loss: 0.011474506887291985!
# Avg loss: 0.010664524430430901!
# Avg loss: 0.010325517238688917!
# Avg loss: 0.00984317620409153!
# Avg loss: 0.009599337417045413!
# Avg loss: 0.00951600833044798!
# Avg loss: 0.009430757450666837!
# Avg loss: 0.009291631493881975!
# Avg loss: 0.009197336293991611!
# Avg loss: 0.009128816206052761!
# Avg loss: 0.0090900521863576!
# Avg loss: 0.009060646804404465!
# Avg loss: 0.009020204198348173!
# Avg loss: 0.008979650463680855!
# Avg loss: 0.008952966971763393!
# Avg loss: 0.008946187360641223!
# Avg loss: 0.008916824064010977!
# Avg loss: 0.008913136246507065!
# Avg loss: 0.008911068081213974!
# Avg loss: 0.0088948401671261!
# Avg loss: 0.008887533287543572!
# Avg loss: 0.008879619773935019!
# Avg loss: 0.008874886675997687!
# Avg loss: 0.008869089323530185!
# Avg loss: 0.008863282920308014!
# Avg loss: 0.008864549673938881!
# Avg loss: 0.00886015147327934!
# Avg loss: 0.008851288371322805!
# Avg loss: 0.008843224474504913!
# Avg loss: 0.008841822767038062!
# Avg loss: 0.008834088170340617!
# Avg loss: 0.008838349916322083!
# Avg loss: 0.008831179914128597!
# Avg loss: 0.008825613443494642!
# Avg loss: 0.008825432653490187!
# Avg loss: 0.008816827240184372!
# Avg loss: 0.008820134206627396!
# Avg loss: 0.008820346887132829!
# Avg loss: 0.008821523978647482!
# Avg loss: 0.008812226270756392!
# Avg loss: 0.008809851309046622!
# Avg loss: 0.00880620728180664!
# Avg loss: 0.008809388916218333!
# Avg loss: 0.008807039558466272!
# Avg loss: 0.008807220205358988!
# Avg loss: 0.008801953622889679!
# Avg loss: 0.008797663953356788!
# Avg loss: 0.008792475345462047!
# Avg loss: 0.008787517568002745!
# Avg loss: 0.008781959350551649!
# Avg loss: 0.008775602397616543!
# Avg loss: 0.008780956837377877!
# Avg loss: 0.008780637744349255!
# Avg loss: 0.00878142781465589!
# Avg loss: 0.008778523027800512!
# Avg loss: 0.008775258643363487!
# Avg loss: 0.00877024064120936!
# Avg loss: 0.008770974610386967!
# Avg loss: 0.008764884739455093!
# Avg loss: 0.008776618157963868!
# Avg loss: 0.008765940825187784!
# Avg loss: 0.008765980262755638!
# Avg loss: 0.00876183121642877!
# Avg loss: 0.00876988289370028!
# Avg loss: 0.00876323861675587!
# Avg loss: 0.008767477370888515!
# Avg loss: 0.008757312688163097!
# Avg loss: 0.008759318529078198!
# Avg loss: 0.008755173130854861!
# Avg loss: 0.008762208498474517!
# Avg loss: 0.008765041739324885!
# Avg loss: 0.00876151161049222!
# Avg loss: 0.008754560928334267!
# Avg loss: 0.00875370264733012!
# Avg loss: 0.008760439605887977!
# Avg loss: 0.008761137114263705!
# Avg loss: 0.008761889425973758!
# Avg loss: 0.00874592083764052!
# Avg loss: 0.008751428392982893!
# Avg loss: 0.008750547193662328!
# Avg loss: 0.008762279884654115!
# Avg loss: 0.00875756153944432!
# Avg loss: 0.008761064438942867!
# Avg loss: 0.008748426713868298!
# Avg loss: 0.008750291553146876!
# Avg loss: 0.008740606030843595!
# Avg loss: 0.008742037723009305!
# Avg loss: 0.008748384679494544!
# Avg loss: 0.008747203117246822!
# Avg loss: 0.008766034082932871!
# Avg loss: 0.008751587077050165!
# Avg loss: 0.00874867499320042!
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0029
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0086
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0156
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0039
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0039
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0060
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0070
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0055
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0042
# ------------------------------
# client: 0
# Avg loss: 0.01885285156914809!
# Avg loss: 0.013053172854512619!
# Avg loss: 0.012915492825753366!
# Avg loss: 0.009455546602863856!
# Avg loss: 0.006342535762002323!
# Avg loss: 0.0055941752739333125!
# Avg loss: 0.00538072506453318!
# Avg loss: 0.004413959819600374!
# Avg loss: 0.0034193598270000317!
# Avg loss: 0.0029624412719810303!
# Avg loss: 0.002637286491905494!
# Avg loss: 0.0020469869555866656!
# Avg loss: 0.0014659320197642955!
# Avg loss: 0.0011871020636408502!
# Avg loss: 0.0010448767398096!
# Avg loss: 0.0008829557170975022!
# Avg loss: 0.0007702774673938014!
# Avg loss: 0.0007013305973426517!
# Avg loss: 0.0006010435092321132!
# Avg loss: 0.0005045318827690911!
# Avg loss: 0.00045031371131851!
# Avg loss: 0.0004223071730560453!
# Avg loss: 0.0004087481456023549!
# Avg loss: 0.00038841111189678184!
# Avg loss: 0.0003563674747609487!
# Avg loss: 0.000335464002240163!
# Avg loss: 0.0003299409827999019!
# Avg loss: 0.0003285874712173609!
# Avg loss: 0.00031960443368158546!
# Avg loss: 0.00030236192165223957!
# Avg loss: 0.00028882108500511095!
# Avg loss: 0.00028319944175260995!
# Avg loss: 0.0002808275016711074!
# Avg loss: 0.000274811133934539!
# Avg loss: 0.00026415751896517275!
# Avg loss: 0.00025520217461083426!
# Avg loss: 0.0002520450591403763!
# Avg loss: 0.0002490594612102844!
# Avg loss: 0.00024283830483303367!
# Avg loss: 0.00023734284653376865!
# Avg loss: 0.00023655081262252982!
# Avg loss: 0.000234230286004428!
# Avg loss: 0.00023017010955072692!
# Avg loss: 0.00022644311103552659!
# Avg loss: 0.00022536810422404111!
# Avg loss: 0.0002225733218089469!
# Avg loss: 0.00022007026849413098!
# Avg loss: 0.00021880176032103312!
# Avg loss: 0.0002171313155539186!
# Avg loss: 0.00021492754484749336!
# Avg loss: 0.00021227709080676505!
# Avg loss: 0.00020896946267839666!
# Avg loss: 0.0002083042768648132!
# Avg loss: 0.00020850325699863485!
# Avg loss: 0.00020790834515821644!
# Avg loss: 0.00020400372683657982!
# Avg loss: 0.00020108143369081214!
# Avg loss: 0.00020128828448036983!
# Avg loss: 0.00020088470762990104!
# Avg loss: 0.00019868280250752454!
# Avg loss: 0.00019705560034509516!
# Avg loss: 0.00019846805470119004!
# Avg loss: 0.00019798337599278662!
# Avg loss: 0.0001930531735417181!
# Avg loss: 0.0001918830382650564!
# Avg loss: 0.00019222679704455458!
# Avg loss: 0.00019315597500830486!
# Avg loss: 0.00019344912703852895!
# Avg loss: 0.00019226330423104324!
# Avg loss: 0.0001905615078950973!
# Avg loss: 0.00018872481570828844!
# Avg loss: 0.00018770841078567932!
# Avg loss: 0.00018587028680864628!
# Avg loss: 0.00018582145098472818!
# Avg loss: 0.00018843285963650184!
# Avg loss: 0.0001874345584318841!
# Avg loss: 0.00018632614412013028!
# Avg loss: 0.0001827537181293337!
# Avg loss: 0.00017958929518291218!
# Avg loss: 0.00018042077582587504!
# Avg loss: 0.000182032137436939!
# Avg loss: 0.00018378827644757696!
# Avg loss: 0.00018187406291228096!
# Avg loss: 0.00017738402262997018!
# Avg loss: 0.00017812434631878205!
# Avg loss: 0.00018001744675946914!
# Avg loss: 0.00017724904276254468!
# Avg loss: 0.0001764320226442351!
# Avg loss: 0.0001798439699369207!
# Avg loss: 0.00017907592896752552!
# Avg loss: 0.0001762112789265302!
# Avg loss: 0.00017543912601846994!
# Avg loss: 0.00017501555503599776!
# Avg loss: 0.00017438891036514783!
# Avg loss: 0.00017680772122010544!
# Avg loss: 0.0001776995265009873!
# Avg loss: 0.00017301516839438592!
# Avg loss: 0.0001720022950276719!
# Avg loss: 0.00017251065948244106!
# Avg loss: 0.00017420211710941658!
# ------------------------------
# client: 1
# Avg loss: 0.026498436916514646!
# Avg loss: 0.02342962613562122!
# Avg loss: 0.020461058764978286!
# Avg loss: 0.01945066327241875!
# Avg loss: 0.017976532469880718!
# Avg loss: 0.01672612328333874!
# Avg loss: 0.016071073332689898!
# Avg loss: 0.015433065006439695!
# Avg loss: 0.015159523768770668!
# Avg loss: 0.01485043237107675!
# Avg loss: 0.014551859571180709!
# Avg loss: 0.01442732168711397!
# Avg loss: 0.014271060669635271!
# Avg loss: 0.014146306599974802!
# Avg loss: 0.014019414957186503!
# Avg loss: 0.01392198499756129!
# Avg loss: 0.013815638231730152!
# Avg loss: 0.013756288014760684!
# Avg loss: 0.013709161338362795!
# Avg loss: 0.01365814072480551!
# Avg loss: 0.013635962537018523!
# Avg loss: 0.013607322055370711!
# Avg loss: 0.013557608829240876!
# Avg loss: 0.013518221493848159!
# Avg loss: 0.013497619911275176!
# Avg loss: 0.013494886375709902!
# Avg loss: 0.013469628505921113!
# Avg loss: 0.013455002573637482!
# Avg loss: 0.013462467231371237!
# Avg loss: 0.0134508203786343!
# Avg loss: 0.013437345905896573!
# Avg loss: 0.013435484352288115!
# Avg loss: 0.0134303125123364!
# Avg loss: 0.013425883389585398!
# Avg loss: 0.0134184036098731!
# Avg loss: 0.013418270250638334!
# Avg loss: 0.01341459404781041!
# Avg loss: 0.013411000788706436!
# Avg loss: 0.013407835960287572!
# Avg loss: 0.013404725593344817!
# Avg loss: 0.013401689902874712!
# Avg loss: 0.013402911372505079!
# Avg loss: 0.013399581365592515!
# Avg loss: 0.013399899382004985!
# Avg loss: 0.013397849295636775!
# Avg loss: 0.013398842577345723!
# Avg loss: 0.013393983182895492!
# Avg loss: 0.013398192293919824!
# Avg loss: 0.013389750169586326!
# Avg loss: 0.013397322975585789!
# Avg loss: 0.013385157639373991!
# Avg loss: 0.013399877553811012!
# Avg loss: 0.013378158397907024!
# Avg loss: 0.013406131871999563!
# Avg loss: 0.013371260278604875!
# Avg loss: 0.013418933069530112!
# Avg loss: 0.013362479449839385!
# Avg loss: 0.013441186744710194!
# Avg loss: 0.01335081355386895!
# Avg loss: 0.013482600839837081!
# Avg loss: 0.013342157740562471!
# Avg loss: 0.013563902965142916!
# Avg loss: 0.013351030031650831!
# Avg loss: 0.01369816466186118!
# Avg loss: 0.013393364909134106!
# Avg loss: 0.013832531062944327!
# Avg loss: 0.013410814257367747!
# Avg loss: 0.013738412420934765!
# Avg loss: 0.013345005455060649!
# Avg loss: 0.013438201398857548!
# Avg loss: 0.01342295027648447!
# ------------------------------
# client: 2
# Avg loss: 0.057584673650465754!
# Avg loss: 0.05492259615270693!
# Avg loss: 0.04000220701001429!
# Avg loss: 0.02955675478146683!
# Avg loss: 0.024672736049451485!
# Avg loss: 0.022195377282620634!
# Avg loss: 0.019914344815768648!
# Avg loss: 0.015855135904021152!
# Avg loss: 0.012407097656808521!
# Avg loss: 0.010330725287991905!
# Avg loss: 0.009184594003415137!
# Avg loss: 0.007740100760117154!
# Avg loss: 0.006295827044462688!
# Avg loss: 0.005517579902501287!
# Avg loss: 0.004898214928398374!
# Avg loss: 0.00460153500311814!
# Avg loss: 0.0042537521985241255!
# Avg loss: 0.0038800810550158834!
# Avg loss: 0.003667153285853904!
# Avg loss: 0.003603628891775467!
# Avg loss: 0.0035169419981184546!
# Avg loss: 0.0034067204478338436!
# Avg loss: 0.0033191976395827777!
# Avg loss: 0.003283033127214973!
# Avg loss: 0.0032673296254438354!
# Avg loss: 0.0032033155359039254!
# Avg loss: 0.0031348021179856763!
# Avg loss: 0.003079516301774371!
# Avg loss: 0.003026384597743951!
# Avg loss: 0.002970130351162273!
# Avg loss: 0.0029224339458710346!
# Avg loss: 0.0028808815259094445!
# Avg loss: 0.0028453753923902998!
# Avg loss: 0.002810147297833131!
# Avg loss: 0.002778779065065464!
# Avg loss: 0.002744438408244605!
# Avg loss: 0.002712809316872911!
# Avg loss: 0.0026855633233996436!
# Avg loss: 0.0026566349359935276!
# Avg loss: 0.002631610735504637!
# Avg loss: 0.0026098698340683768!
# Avg loss: 0.002580812104465527!
# Avg loss: 0.0025614661382547866!
# Avg loss: 0.002544030329464325!
# Avg loss: 0.0025266820254810796!
# Avg loss: 0.0025133904488188817!
# Avg loss: 0.0024998100060057973!
# Avg loss: 0.0024805843137450743!
# Avg loss: 0.002462868135877064!
# Avg loss: 0.0024420017058129893!
# Avg loss: 0.0024219336109740654!
# Avg loss: 0.002407105998163767!
# Avg loss: 0.002396232290669976!
# Avg loss: 0.002387267286414385!
# Avg loss: 0.0023750035325207364!
# Avg loss: 0.0023670707789907887!
# Avg loss: 0.002361632738910847!
# Avg loss: 0.0023543304790964235!
# Avg loss: 0.0023476757179660503!
# Avg loss: 0.002337401175041502!
# Avg loss: 0.0023322583596700496!
# Avg loss: 0.002322423707875032!
# Avg loss: 0.002320547663264089!
# Avg loss: 0.0023114726691769267!
# Avg loss: 0.0023072935808606115!
# Avg loss: 0.0022967923379612408!
# Avg loss: 0.0022977172851780855!
# Avg loss: 0.0022920200923905064!
# Avg loss: 0.0022878394954642073!
# Avg loss: 0.002281180345958281!
# Avg loss: 0.002279283816853912!
# Avg loss: 0.002273249268805273!
# Avg loss: 0.002270343104105355!
# Avg loss: 0.0022638765152297917!
# Avg loss: 0.002263859690823343!
# Avg loss: 0.0022607220317788783!
# Avg loss: 0.002257612654774436!
# Avg loss: 0.0022508496831842705!
# Avg loss: 0.002247626378350631!
# Avg loss: 0.0022427200602148406!
# Avg loss: 0.0022416837270018658!
# Avg loss: 0.002236156093644534!
# Avg loss: 0.0022345164575009826!
# Avg loss: 0.002231997035683643!
# Avg loss: 0.0022333766701054143!
# Avg loss: 0.002227693096453246!
# Avg loss: 0.0022297209502774723!
# Avg loss: 0.0022200582684240543!
# Avg loss: 0.0022217214526205!
# Avg loss: 0.0022166264757026966!
# Avg loss: 0.0022175285971068586!
# Avg loss: 0.002217840772806312!
# Avg loss: 0.0022185306982339626!
# Avg loss: 0.0022131917508577694!
# Avg loss: 0.0022141115332389443!
# Avg loss: 0.0022115387805077564!
# Avg loss: 0.0022137388427123975!
# Avg loss: 0.002205108667076227!
# Avg loss: 0.0022079569948493826!
# Avg loss: 0.002207518059440569!
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0028
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0055
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0124
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0035
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0041
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0046
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0059
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0048
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0028
# ------------------------------
# client: 0
# Avg loss: 0.015992441673976523!
# Avg loss: 0.014939066735096276!
# Avg loss: 0.012193871496953458!
# Avg loss: 0.009418721098494037!
# Avg loss: 0.008275640554202254!
# Avg loss: 0.006209537968631291!
# Avg loss: 0.004358520289191196!
# Avg loss: 0.0037172877957164017!
# Avg loss: 0.0031738582948310067!
# Avg loss: 0.0026011508290321216!
# Avg loss: 0.002227375271747102!
# Avg loss: 0.0019393023071881997!
# Avg loss: 0.0017363357692738645!
# Avg loss: 0.0015330111056543199!
# Avg loss: 0.0014083701881342373!
# Avg loss: 0.0013652617666048172!
# Avg loss: 0.001342451907873207!
# Avg loss: 0.0013314803004353356!
# Avg loss: 0.0012897999251542083!
# Avg loss: 0.0012712835957033046!
# Avg loss: 0.0012512896411105126!
# Avg loss: 0.0012318074512267666!
# Avg loss: 0.0012387664462047117!
# Avg loss: 0.0012450715356533237!
# Avg loss: 0.001238069148445599!
# Avg loss: 0.001210694262542802!
# Avg loss: 0.0011943060186581534!
# Avg loss: 0.0011922841796028175!
# Avg loss: 0.0011960251150590294!
# Avg loss: 0.0011955685858708875!
# Avg loss: 0.001189194245315169!
# Avg loss: 0.0011792281170547388!
# Avg loss: 0.0011730005805291436!
# Avg loss: 0.0011739493986706862!
# Avg loss: 0.0011719670011937449!
# Avg loss: 0.0011669788604717723!
# Avg loss: 0.0011646235576888368!
# Avg loss: 0.0011610711340527284!
# Avg loss: 0.0011581429701683988!
# Avg loss: 0.0011589180730317138!
# Avg loss: 0.0011552626426596646!
# Avg loss: 0.0011524744268396603!
# Avg loss: 0.0011525277657542196!
# Avg loss: 0.0011485206501760103!
# Avg loss: 0.0011448303940898086!
# Avg loss: 0.0011425551165717706!
# Avg loss: 0.0011426433923082868!
# Avg loss: 0.001140664709071378!
# Avg loss: 0.0011388445478375312!
# Avg loss: 0.0011376944385465511!
# Avg loss: 0.0011355543707337764!
# Avg loss: 0.0011350608920434506!
# Avg loss: 0.0011320667981317455!
# Avg loss: 0.001129666992976676!
# Avg loss: 0.0011315774327736487!
# Avg loss: 0.0011313793940995727!
# Avg loss: 0.001127449302442661!
# Avg loss: 0.00112476206754053!
# Avg loss: 0.0011247988175359562!
# Avg loss: 0.0011233791633349218!
# Avg loss: 0.0011226934048560603!
# Avg loss: 0.0011206604639817878!
# Avg loss: 0.0011207855490522434!
# Avg loss: 0.0011214839126955194!
# Avg loss: 0.0011166666518725302!
# Avg loss: 0.0011172331722343642!
# Avg loss: 0.0011163602219177921!
# Avg loss: 0.0011163464392482563!
# Avg loss: 0.001114747538417665!
# Avg loss: 0.0011138612576272067!
# Avg loss: 0.001113734827218972!
# Avg loss: 0.0011133048819184901!
# Avg loss: 0.001112455128582231!
# Avg loss: 0.0011099188744850609!
# Avg loss: 0.001109895219072617!
# Avg loss: 0.0011079515679323511!
# Avg loss: 0.0011095955437111608!
# Avg loss: 0.0011099313983424963!
# Avg loss: 0.0011089928944433799!
# Avg loss: 0.0011044848155520508!
# Avg loss: 0.0011054465249793566!
# Avg loss: 0.0011061628941684868!
# Avg loss: 0.0011070320049538888!
# Avg loss: 0.001105826370901847!
# Avg loss: 0.00110631528948673!
# Avg loss: 0.0011029243650546997!
# Avg loss: 0.001103051677700743!
# Avg loss: 0.001104638527696693!
# Avg loss: 0.0011042380586806643!
# Avg loss: 0.0010997482802829002!
# Avg loss: 0.0010992143097622413!
# Avg loss: 0.0011018486517832392!
# Avg loss: 0.0011019513983387696!
# Avg loss: 0.0011003204453645785!
# Avg loss: 0.001097976253835782!
# Avg loss: 0.001100671865665485!
# Avg loss: 0.0010978720062231181!
# Avg loss: 0.0010979421545399266!
# Avg loss: 0.0010968029069674875!
# Avg loss: 0.001097782450742623!
# ------------------------------
# client: 1
# Avg loss: 0.029987412762226693!
# Avg loss: 0.030709914285932123!
# Avg loss: 0.026486000368652944!
# Avg loss: 0.02117967389085!
# Avg loss: 0.016240657086552042!
# Avg loss: 0.013125634599346086!
# Avg loss: 0.011631739694148564!
# Avg loss: 0.010663943558465689!
# Avg loss: 0.009816951147440705!
# Avg loss: 0.008884803921088556!
# Avg loss: 0.008147959075364876!
# Avg loss: 0.007682176976950359!
# Avg loss: 0.007226779737896626!
# Avg loss: 0.006749290382925513!
# Avg loss: 0.006492971559997993!
# Avg loss: 0.006348857453724576!
# Avg loss: 0.006170214462019127!
# Avg loss: 0.005995474543593294!
# Avg loss: 0.005885745795958428!
# Avg loss: 0.005821682465584672!
# Avg loss: 0.005721187137556475!
# Avg loss: 0.005618946072681865!
# Avg loss: 0.005558636567751213!
# Avg loss: 0.005508867613150794!
# Avg loss: 0.00546078530604215!
# Avg loss: 0.005449936040975748!
# Avg loss: 0.005434340444091959!
# Avg loss: 0.005407330339736139!
# Avg loss: 0.005384788770177996!
# Avg loss: 0.005379371178682959!
# Avg loss: 0.005370727965684712!
# Avg loss: 0.0053564979564324254!
# Avg loss: 0.00535377843175335!
# Avg loss: 0.005345467986346648!
# Avg loss: 0.00533718133036397!
# Avg loss: 0.005329735305548032!
# Avg loss: 0.005324909503400288!
# Avg loss: 0.005313927280869469!
# Avg loss: 0.0053070422406131!
# Avg loss: 0.005306047673716374!
# Avg loss: 0.005302548946768865!
# Avg loss: 0.0052961694461473975!
# Avg loss: 0.005295165455348373!
# Avg loss: 0.0052915248859168665!
# Avg loss: 0.0052920863476542!
# Avg loss: 0.005294864377489811!
# Avg loss: 0.0052878875174716695!
# Avg loss: 0.0052822898646809335!
# Avg loss: 0.005282051417912802!
# Avg loss: 0.005277897474527815!
# Avg loss: 0.005276974726989086!
# Avg loss: 0.0052732120975715205!
# Avg loss: 0.005273001158649701!
# Avg loss: 0.0052712796791036!
# Avg loss: 0.005277211885225768!
# Avg loss: 0.005272466465016035!
# Avg loss: 0.00527106997560035!
# Avg loss: 0.005267202743758996!
# Avg loss: 0.00527206525692795!
# Avg loss: 0.005264264234655609!
# Avg loss: 0.005271384899127156!
# Avg loss: 0.005263319792217279!
# Avg loss: 0.005267712457526367!
# Avg loss: 0.005257937821473888!
# Avg loss: 0.005265736554029547!
# Avg loss: 0.005258694628933919!
# Avg loss: 0.005270191386601984!
# Avg loss: 0.005258973374917464!
# Avg loss: 0.005266788854894079!
# Avg loss: 0.005255225256341684!
# Avg loss: 0.005266203337531011!
# Avg loss: 0.005254975201294201!
# Avg loss: 0.005265332561622529!
# Avg loss: 0.005252546812953748!
# Avg loss: 0.00526688943080965!
# Avg loss: 0.005256230863447087!
# Avg loss: 0.0052645392632364955!
# Avg loss: 0.005251821705427678!
# Avg loss: 0.005263559329988823!
# Avg loss: 0.005255515203233471!
# Avg loss: 0.005264931522317132!
# Avg loss: 0.005251330268765126!
# Avg loss: 0.005260489743700513!
# Avg loss: 0.005254825981669574!
# Avg loss: 0.005263170504543003!
# Avg loss: 0.005253173375546965!
# Avg loss: 0.005260103256547097!
# Avg loss: 0.00525625763623026!
# Avg loss: 0.005262049821096753!
# Avg loss: 0.005257852010987846!
# Avg loss: 0.005261191902301429!
# Avg loss: 0.005259658949164982!
# ------------------------------
# client: 2
# Avg loss: 0.035367764578356095!
# Avg loss: 0.027057847705533884!
# Avg loss: 0.021285569265989276!
# Avg loss: 0.016562548803146154!
# Avg loss: 0.013287364239998472!
# Avg loss: 0.012444634184794268!
# Avg loss: 0.010666249182152872!
# Avg loss: 0.007912585971895775!
# Avg loss: 0.0065011306710251425!
# Avg loss: 0.005841764583202955!
# Avg loss: 0.005446669510379251!
# Avg loss: 0.00516602283630012!
# Avg loss: 0.005007178219342071!
# Avg loss: 0.0047624314021512265!
# Avg loss: 0.004602859186076481!
# Avg loss: 0.004439716655237286!
# Avg loss: 0.004283129481251535!
# Avg loss: 0.00423883801629529!
# Avg loss: 0.004203090943789221!
# Avg loss: 0.004098769776674089!
# Avg loss: 0.004044149430252067!
# Avg loss: 0.004027015989022023!
# Avg loss: 0.003985465371731607!
# Avg loss: 0.003960980318406655!
# Avg loss: 0.003958292729770771!
# Avg loss: 0.003947623710492583!
# Avg loss: 0.003925200482330714!
# Avg loss: 0.0039117529160701756!
# Avg loss: 0.003903438347122498!
# Avg loss: 0.003889529934156144!
# Avg loss: 0.0038754039221779142!
# Avg loss: 0.003866054726220985!
# Avg loss: 0.003860855886487495!
# Avg loss: 0.0038512786904182877!
# Avg loss: 0.0038519075390661328!
# Avg loss: 0.0038445690063686772!
# Avg loss: 0.0038339307020836106!
# Avg loss: 0.0038301345574749727!
# Avg loss: 0.003821997759014266!
# Avg loss: 0.003817446934662409!
# Avg loss: 0.003810662870342488!
# Avg loss: 0.0038086278963085835!
# Avg loss: 0.0038066872359733377!
# Avg loss: 0.00380192075323824!
# Avg loss: 0.0037974473663636367!
# Avg loss: 0.003792114536616206!
# Avg loss: 0.0037893868288472275!
# Avg loss: 0.0037863439817995945!
# Avg loss: 0.0037851638143695256!
# Avg loss: 0.0037803065685278626!
# Avg loss: 0.0037780746256280886!
# Avg loss: 0.003774298982154202!
# Avg loss: 0.0037737857528838013!
# Avg loss: 0.003774280482778067!
# Avg loss: 0.0037669148200728843!
# Avg loss: 0.003764878105745216!
# Avg loss: 0.003760610321172161!
# Avg loss: 0.0037585801156511897!
# Avg loss: 0.003758438262983835!
# Avg loss: 0.003753319734629391!
# Avg loss: 0.0037531338810501327!
# Avg loss: 0.0037519462835417985!
# Avg loss: 0.0037484392451373337!
# Avg loss: 0.0037486652425119853!
# Avg loss: 0.0037411412782100938!
# Avg loss: 0.003737801033417393!
# Avg loss: 0.003735762782493879!
# Avg loss: 0.0037341403096777625!
# Avg loss: 0.0037345411994338445!
# Avg loss: 0.0037284148956508055!
# Avg loss: 0.003729476295186724!
# Avg loss: 0.00372921102874308!
# Avg loss: 0.0037294997288995547!
# Avg loss: 0.0037295070948921588!
# Avg loss: 0.003724223364198262!
# Avg loss: 0.0037233901911308464!
# Avg loss: 0.0037224813958712842!
# Avg loss: 0.0037222367874923633!
# Avg loss: 0.003720678723468846!
# Avg loss: 0.003722192728182468!
# Avg loss: 0.003717282059319018!
# Avg loss: 0.003717468066988848!
# Avg loss: 0.0037183283136576505!
# Avg loss: 0.0037164108866344727!
# Avg loss: 0.003717003625871295!
# Avg loss: 0.0037164321248772583!
# Avg loss: 0.0037177399438909713!
# Avg loss: 0.003714211075177237!
# Avg loss: 0.0037153756740117196!
# Avg loss: 0.003712309891304244!
# Avg loss: 0.003710909692320191!
# Avg loss: 0.003714686220997218!
# Avg loss: 0.0037096025938878796!
# Avg loss: 0.003712481548741664!
# Avg loss: 0.0037077086057051172!
# Avg loss: 0.0037070490390590295!
# Avg loss: 0.0037090654606938027!
# Avg loss: 0.0037040483667531514!
# Avg loss: 0.00370877746272735!
# Avg loss: 0.0037044772612676033!
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0010
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0127
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0211
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0017
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0039
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0047
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0039
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0053
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0023
# ------------------------------
# client: 0
# Avg loss: 0.014501747176594412!
# Avg loss: 0.012173631413752446!
# Avg loss: 0.0099247265979587!
# Avg loss: 0.008958192286469662!
# Avg loss: 0.007846862624937785!
# Avg loss: 0.006277025008457713!
# Avg loss: 0.005011481437480446!
# Avg loss: 0.00418968521419932!
# Avg loss: 0.0036851061325584547!
# Avg loss: 0.003407351467700816!
# Avg loss: 0.003055966090601032!
# Avg loss: 0.0026924386153064006!
# Avg loss: 0.002442268756428424!
# Avg loss: 0.002237366490333746!
# Avg loss: 0.0021053931323876895!
# Avg loss: 0.001954303304558683!
# Avg loss: 0.0018803322445531496!
# Avg loss: 0.0018786802953331971!
# Avg loss: 0.001862563633112586!
# Avg loss: 0.001812217759717214!
# Avg loss: 0.0017685105012363541!
# Avg loss: 0.0017530947601161037!
# Avg loss: 0.001732680172264812!
# Avg loss: 0.0017118161779579092!
# Avg loss: 0.0017060548784532633!
# Avg loss: 0.0017016761363157684!
# Avg loss: 0.0016805413494228106!
# Avg loss: 0.0016668405714216307!
# Avg loss: 0.0016626612011578837!
# Avg loss: 0.001656244965845417!
# Avg loss: 0.0016468750669533468!
# Avg loss: 0.001640307217684267!
# Avg loss: 0.0016380961071210246!
# Avg loss: 0.001633985771384232!
# Avg loss: 0.0016306886038584404!
# Avg loss: 0.0016275030449090385!
# Avg loss: 0.00161851545160971!
# Avg loss: 0.0016135191737595277!
# Avg loss: 0.0016111507105396564!
# Avg loss: 0.0016095702943361328!
# Avg loss: 0.0016096726798220592!
# Avg loss: 0.0016032098921804543!
# Avg loss: 0.0016000951484436616!
# Avg loss: 0.0015990248355776278!
# Avg loss: 0.0015966979536005017!
# Avg loss: 0.0015963357435980186!
# Avg loss: 0.0015941072577506077!
# Avg loss: 0.0015869284539327092!
# Avg loss: 0.0015851067846706474!
# Avg loss: 0.0015846932595098907!
# Avg loss: 0.001582345468737903!
# Avg loss: 0.0015845261542541777!
# Avg loss: 0.0015791657224186295!
# Avg loss: 0.0015756620991997038!
# Avg loss: 0.0015740954880869632!
# Avg loss: 0.0015712590205953347!
# Avg loss: 0.001572031597328305!
# Avg loss: 0.001572669280502339!
# Avg loss: 0.0015704162714967158!
# Avg loss: 0.001569811059138703!
# Avg loss: 0.0015728183692142277!
# Avg loss: 0.0015704133308282427!
# Avg loss: 0.0015673840104376306!
# Avg loss: 0.0015628994345014272!
# Avg loss: 0.001559709737253551!
# Avg loss: 0.0015589362513209438!
# Avg loss: 0.0015575051061121788!
# Avg loss: 0.0015571524885525415!
# Avg loss: 0.0015593863297164035!
# Avg loss: 0.0015583270426470601!
# Avg loss: 0.0015591663938842734!
# Avg loss: 0.0015584255015443204!
# Avg loss: 0.001556912082721169!
# Avg loss: 0.0015565780861314475!
# Avg loss: 0.0015552385296142054!
# Avg loss: 0.0015562601002762715!
# Avg loss: 0.0015528077151489347!
# Avg loss: 0.0015516952653849359!
# Avg loss: 0.001553432555497025!
# Avg loss: 0.0015520517969476444!
# Avg loss: 0.0015537206970860022!
# Avg loss: 0.0015486156244507161!
# Avg loss: 0.0015493564883180492!
# Avg loss: 0.0015518185873431279!
# Avg loss: 0.0015529171043326489!
# Avg loss: 0.0015496560637444172!
# Avg loss: 0.0015470934812401064!
# Avg loss: 0.0015488899234647828!
# Avg loss: 0.0015515918391104814!
# Avg loss: 0.0015483726574509642!
# Avg loss: 0.001543516569172733!
# Avg loss: 0.0015429136729949277!
# Avg loss: 0.0015442789262783425!
# Avg loss: 0.0015467572920140307!
# Avg loss: 0.0015427355552551628!
# Avg loss: 0.00154025148529889!
# Avg loss: 0.001540584256401883!
# Avg loss: 0.0015402295867585755!
# Avg loss: 0.001534223950158804!
# Avg loss: 0.0015359244944689364!
# ------------------------------
# client: 1
# Avg loss: 0.03489619285411512!
# Avg loss: 0.02865299008054232!
# Avg loss: 0.02393497294028445!
# Avg loss: 0.02047406725798889!
# Avg loss: 0.020059816469462626!
# Avg loss: 0.017630026081927402!
# Avg loss: 0.013775616331889371!
# Avg loss: 0.01163770825456595!
# Avg loss: 0.010646110084829463!
# Avg loss: 0.010031061212163574!
# Avg loss: 0.009821088037254715!
# Avg loss: 0.009217382679004611!
# Avg loss: 0.008735881886071486!
# Avg loss: 0.00856165899829648!
# Avg loss: 0.00851419274720456!
# Avg loss: 0.008566458742155116!
# Avg loss: 0.008440915269516154!
# Avg loss: 0.008359488266351037!
# Avg loss: 0.008359181524671537!
# Avg loss: 0.008419354869814318!
# Avg loss: 0.008412136520807962!
# Avg loss: 0.008350215035388448!
# Avg loss: 0.008311813143147025!
# Avg loss: 0.00832782505440529!
# Avg loss: 0.008320947626932593!
# Avg loss: 0.008296074677114025!
# Avg loss: 0.008290865500929195!
# Avg loss: 0.008299891786817379!
# Avg loss: 0.008290595780120119!
# Avg loss: 0.008267721479345104!
# Avg loss: 0.008262769799237048!
# Avg loss: 0.0082660070438979!
# Avg loss: 0.008259737660811008!
# Avg loss: 0.00824593875680795!
# Avg loss: 0.008239978368623611!
# Avg loss: 0.008238344208778017!
# Avg loss: 0.00823127642430477!
# Avg loss: 0.00822607203873383!
# Avg loss: 0.008225150540042041!
# Avg loss: 0.008221210458369228!
# Avg loss: 0.008213623972326474!
# Avg loss: 0.00820888315037763!
# Avg loss: 0.008206564682648387!
# Avg loss: 0.008202442560182703!
# Avg loss: 0.008197618281425652!
# Avg loss: 0.008194230486514964!
# Avg loss: 0.008190865529532706!
# Avg loss: 0.008186589240088532!
# Avg loss: 0.008183477668132847!
# Avg loss: 0.008181268975942355!
# Avg loss: 0.008177036981431532!
# Avg loss: 0.008174714369934388!
# Avg loss: 0.008175813844889603!
# Avg loss: 0.0081734526328565!
# Avg loss: 0.00816920823752317!
# Avg loss: 0.008167796743779073!
# Avg loss: 0.00816637281481159!
# Avg loss: 0.008163606405006286!
# Avg loss: 0.008162874527671041!
# Avg loss: 0.008160304384833618!
# Avg loss: 0.008158559123967658!
# Avg loss: 0.008154930183329535!
# Avg loss: 0.008153536220154554!
# Avg loss: 0.008152084689862988!
# Avg loss: 0.008152225504692107!
# Avg loss: 0.008150123248961638!
# Avg loss: 0.008149204865445844!
# Avg loss: 0.008146637549198582!
# Avg loss: 0.008144215566319416!
# Avg loss: 0.008142520578987605!
# Avg loss: 0.00814235991198392!
# Avg loss: 0.008141406964686458!
# Avg loss: 0.008140609295755136!
# Avg loss: 0.008139145582414263!
# Avg loss: 0.008136873042064773!
# Avg loss: 0.008137462917747201!
# Avg loss: 0.008135980876401732!
# Avg loss: 0.008134875883138762!
# Avg loss: 0.008131862380744224!
# Avg loss: 0.008134264741976836!
# Avg loss: 0.008130527714286018!
# Avg loss: 0.008131476733401163!
# Avg loss: 0.00812947114423944!
# Avg loss: 0.008128786701982638!
# Avg loss: 0.008126495973983197!
# Avg loss: 0.008126690154136706!
# Avg loss: 0.008125455561382751!
# Avg loss: 0.008125911017025563!
# Avg loss: 0.008125693394673969!
# Avg loss: 0.008123307012471817!
# Avg loss: 0.008124421060876633!
# Avg loss: 0.008122923625721038!
# Avg loss: 0.008123553686248215!
# Avg loss: 0.008120358297150953!
# Avg loss: 0.008123224088747823!
# Avg loss: 0.008119349528948494!
# Avg loss: 0.008121353271973438!
# Avg loss: 0.008116583832121856!
# Avg loss: 0.008120547496373736!
# Avg loss: 0.008117476886833022!
# ------------------------------
# client: 2
# Avg loss: 0.04636768201521287!
# Avg loss: 0.03893831646433682!
# Avg loss: 0.03305815825801498!
# Avg loss: 0.028816255656517267!
# Avg loss: 0.025001001078041252!
# Avg loss: 0.021689365158429914!
# Avg loss: 0.019282059868719444!
# Avg loss: 0.01740594995995726!
# Avg loss: 0.01596469022264197!
# Avg loss: 0.01495710619442434!
# Avg loss: 0.014211626886808517!
# Avg loss: 0.01381026048168072!
# Avg loss: 0.013514198957775439!
# Avg loss: 0.013326703967396346!
# Avg loss: 0.013197010131699851!
# Avg loss: 0.013183320670174605!
# Avg loss: 0.013145668082288467!
# Avg loss: 0.013159537256142358!
# Avg loss: 0.013148497152870581!
# Avg loss: 0.013053268065362621!
# Avg loss: 0.013049103274098191!
# Avg loss: 0.013031170471788868!
# Avg loss: 0.012974730567979122!
# Avg loss: 0.012967538684317787!
# Avg loss: 0.012943428074474876!
# Avg loss: 0.012917539012478111!
# Avg loss: 0.012890131200847843!
# Avg loss: 0.012888171390465383!
# Avg loss: 0.012880644246076827!
# Avg loss: 0.012888779865543635!
# Avg loss: 0.012868924636874605!
# Avg loss: 0.012871550544585943!
# Avg loss: 0.0128472161812374!
# Avg loss: 0.0128485861380445!
# Avg loss: 0.012844970968507284!
# Avg loss: 0.012848596864844429!
# Avg loss: 0.012841472606815596!
# Avg loss: 0.012841699474393143!
# Avg loss: 0.012835602299962072!
# Avg loss: 0.01283965070841551!
# Avg loss: 0.01283701524949663!
# Avg loss: 0.012838561733947719!
# Avg loss: 0.01283459376526262!
# Avg loss: 0.012836425826910348!
# Avg loss: 0.012834595716087497!
# Avg loss: 0.01283605342349612!
# Avg loss: 0.012833140424252083!
# Avg loss: 0.012834136325054715!
# Avg loss: 0.01283010899352874!
# Avg loss: 0.012830804323770432!
# Avg loss: 0.012824382669543818!
# Avg loss: 0.012826564334150324!
# Avg loss: 0.012821423630713298!
# Avg loss: 0.012821193689003299!
# Avg loss: 0.012812040463090474!
# Avg loss: 0.012813494323799166!
# Avg loss: 0.01280741410565516!
# Avg loss: 0.01281075989051601!
# Avg loss: 0.012807018990657563!
# Avg loss: 0.012806062262078702!
# Avg loss: 0.012802078548143357!
# Avg loss: 0.012803590497127667!
# Avg loss: 0.012801666572252538!
# Avg loss: 0.012805103629460272!
# Avg loss: 0.012798255926994576!
# Avg loss: 0.01280148528643212!
# Avg loss: 0.012806785895625363!
# Avg loss: 0.012800418908202146!
# Avg loss: 0.012796452105921573!
# Avg loss: 0.012801841457644892!
# Avg loss: 0.012794967092478942!
# Avg loss: 0.012802752382280668!
# Avg loss: 0.012807117093070038!
# Avg loss: 0.012807393648038404!
# Avg loss: 0.012800385953289795!
# Avg loss: 0.01280441062717955!
# Avg loss: 0.012804320185771113!
# Avg loss: 0.012814068757445844!
# Avg loss: 0.01280932866664088!
# Avg loss: 0.01279834941580385!
# Avg loss: 0.01279333873986919!
# Avg loss: 0.012796914173532249!
# Avg loss: 0.012810841243673867!
# Avg loss: 0.012808703311634986!
# Avg loss: 0.012804974474674585!
# Avg loss: 0.012796033030545146!
# Avg loss: 0.012809109833153679!
# Avg loss: 0.012811942290612173!
# Avg loss: 0.012808808382319056!
# Avg loss: 0.012798064407959895!
# Avg loss: 0.012798802115048129!
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0023
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0065
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0140
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0030
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0029
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0055
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0045
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0040
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0039
# ------------------------------
# client: 0
# Avg loss: 0.015215059262967163!
# Avg loss: 0.01060625413088322!
# Avg loss: 0.009010376658467673!
# Avg loss: 0.007402947775829792!
# Avg loss: 0.005702393623093182!
# Avg loss: 0.00462019739636465!
# Avg loss: 0.004075303679247403!
# Avg loss: 0.003916079102761311!
# Avg loss: 0.0035892869860526845!
# Avg loss: 0.0032985399260178384!
# Avg loss: 0.0030276275509254448!
# Avg loss: 0.0029232976237350762!
# Avg loss: 0.002818221533192021!
# Avg loss: 0.0027166133459316675!
# Avg loss: 0.0026284267037776014!
# Avg loss: 0.002591194440910461!
# Avg loss: 0.0025641217535288282!
# Avg loss: 0.002528388250076053!
# Avg loss: 0.0024849007636335804!
# Avg loss: 0.002459401382730751!
# Avg loss: 0.0024381520115298373!
# Avg loss: 0.002408304296573078!
# Avg loss: 0.0023817061490495916!
# Avg loss: 0.0023632394631677776!
# Avg loss: 0.0023419027660160434!
# Avg loss: 0.0023187456499924033!
# Avg loss: 0.0023056532070264285!
# Avg loss: 0.0022960258204547776!
# Avg loss: 0.0022853486761837873!
# Avg loss: 0.0022789816361682824!
# Avg loss: 0.0022756190563372534!
# Avg loss: 0.0022710173402358197!
# Avg loss: 0.0022676658218968746!
# Avg loss: 0.0022667900763834346!
# Avg loss: 0.002265209581267982!
# Avg loss: 0.002261203212078537!
# Avg loss: 0.002259726255788858!
# Avg loss: 0.002263948960144309!
# Avg loss: 0.0022659060100383263!
# Avg loss: 0.0022598632967042913!
# Avg loss: 0.002256634214418985!
# Avg loss: 0.0022564311399335384!
# Avg loss: 0.002259607022823218!
# Avg loss: 0.0022618651023630794!
# Avg loss: 0.0022592613867402633!
# Avg loss: 0.002257473156776797!
# Avg loss: 0.0022609090637536154!
# Avg loss: 0.0022603438775735184!
# Avg loss: 0.0022598425722020463!
# Avg loss: 0.0022582779583251995!
# Avg loss: 0.002258782240578891!
# Avg loss: 0.0022609971922564636!
# ------------------------------
# client: 1
# Avg loss: 0.02358432395713559!
# Avg loss: 0.018681169074552598!
# Avg loss: 0.016735589096291126!
# Avg loss: 0.015650180458348283!
# Avg loss: 0.014428226160289341!
# Avg loss: 0.01348380520939827!
# Avg loss: 0.012137738720484776!
# Avg loss: 0.010852103176544005!
# Avg loss: 0.009977712143244541!
# Avg loss: 0.009359652733185916!
# Avg loss: 0.008947932639791057!
# Avg loss: 0.008580775477466508!
# Avg loss: 0.008121099043394982!
# Avg loss: 0.007537196437703339!
# Avg loss: 0.0071192464790510715!
# Avg loss: 0.006868380294520951!
# Avg loss: 0.006753343020196022!
# Avg loss: 0.006674800013053641!
# Avg loss: 0.006576886624855736!
# Avg loss: 0.006494115138624087!
# Avg loss: 0.0064604348657136745!
# Avg loss: 0.00646277515642718!
# Avg loss: 0.006472822649009231!
# Avg loss: 0.0064613267303586025!
# Avg loss: 0.006439698480631553!
# Avg loss: 0.006429054569320745!
# Avg loss: 0.006428822994295918!
# Avg loss: 0.006431903245398492!
# Avg loss: 0.006437399965338196!
# Avg loss: 0.006436100505320989!
# Avg loss: 0.006429562388049419!
# Avg loss: 0.006426456442297119!
# Avg loss: 0.006422412324169879!
# Avg loss: 0.006414666915286488!
# Avg loss: 0.006411509022804011!
# Avg loss: 0.0064102617327792665!
# Avg loss: 0.0064070283103023935!
# Avg loss: 0.0064042562051668025!
# Avg loss: 0.0063985691122184106!
# Avg loss: 0.006393143784504976!
# Avg loss: 0.006387796711017396!
# Avg loss: 0.006385017586404539!
# Avg loss: 0.006381472266401716!
# Avg loss: 0.006376237242850114!
# Avg loss: 0.006373113241835047!
# Avg loss: 0.006370737209318236!
# Avg loss: 0.006370274610982657!
# Avg loss: 0.006366126220018013!
# Avg loss: 0.006362992900701651!
# Avg loss: 0.006360540213341702!
# Avg loss: 0.0063590921133260285!
# Avg loss: 0.006363858982027561!
# Avg loss: 0.006365070425949663!
# Avg loss: 0.006363500134089482!
# Avg loss: 0.006361655339560457!
# Avg loss: 0.006359262150617724!
# Avg loss: 0.006358349717943952!
# Avg loss: 0.006361644900106284!
# Avg loss: 0.0063601585149499346!
# Avg loss: 0.0063604725941473345!
# Avg loss: 0.00635780129260354!
# Avg loss: 0.006355908692984732!
# Avg loss: 0.006357936130609119!
# Avg loss: 0.0063561091631904295!
# Avg loss: 0.006359173857046017!
# Avg loss: 0.006356512861890356!
# Avg loss: 0.006356943729612112!
# Avg loss: 0.006353176729739592!
# Avg loss: 0.006355768355661932!
# Avg loss: 0.006353151506659363!
# Avg loss: 0.006353636537478262!
# Avg loss: 0.006355241792484397!
# Avg loss: 0.00635406780411093!
# Avg loss: 0.00635761166947816!
# Avg loss: 0.0063566204918256135!
# Avg loss: 0.006354373382755985!
# Avg loss: 0.006351062126023142!
# Avg loss: 0.006352481274713568!
# Avg loss: 0.006354648756444021!
# Avg loss: 0.006358789536447678!
# Avg loss: 0.006362549943262555!
# Avg loss: 0.006359383186318723!
# Avg loss: 0.006356978218803988!
# Avg loss: 0.006352969617754667!
# Avg loss: 0.006357836276246948!
# Avg loss: 0.006354053187292455!
# Avg loss: 0.00635499822704143!
# ------------------------------
# client: 2
# Avg loss: 0.05413609386164656!
# Avg loss: 0.051496697252441666!
# Avg loss: 0.04237555504922057!
# Avg loss: 0.034311493967155306!
# Avg loss: 0.03054688130641201!
# Avg loss: 0.026515653037737744!
# Avg loss: 0.022059195383359716!
# Avg loss: 0.019233510972068567!
# Avg loss: 0.01675949757428801!
# Avg loss: 0.014616565117842886!
# Avg loss: 0.01323557074138686!
# Avg loss: 0.011658954496718554!
# Avg loss: 0.010561747974064322!
# Avg loss: 0.010201657730382674!
# Avg loss: 0.010047059837185467!
# Avg loss: 0.009987511974577501!
# Avg loss: 0.009751805759454632!
# Avg loss: 0.009589098415720703!
# Avg loss: 0.00953144901849252!
# Avg loss: 0.00948068879651449!
# Avg loss: 0.00940965809123251!
# Avg loss: 0.009294564629987387!
# Avg loss: 0.009233951500561185!
# Avg loss: 0.009199359761866314!
# Avg loss: 0.009181716154907918!
# Avg loss: 0.00914249164748071!
# Avg loss: 0.009114328058480699!
# Avg loss: 0.009108124070477668!
# Avg loss: 0.009115412502426541!
# Avg loss: 0.009106799193186438!
# Avg loss: 0.009095092397706518!
# Avg loss: 0.009091991391672612!
# Avg loss: 0.009088876729614413!
# Avg loss: 0.009078020660019774!
# Avg loss: 0.009071482185599961!
# Avg loss: 0.009071725955018147!
# Avg loss: 0.009069942385594535!
# Avg loss: 0.009060925573567146!
# Avg loss: 0.00905106123011895!
# Avg loss: 0.00904766963041008!
# Avg loss: 0.00904446684735755!
# Avg loss: 0.009040909373635865!
# Avg loss: 0.009040042316640514!
# Avg loss: 0.009035799340149425!
# Avg loss: 0.009029261524625933!
# Avg loss: 0.009024253126099968!
# Avg loss: 0.009022847217862591!
# Avg loss: 0.009022719100823907!
# Avg loss: 0.009024796716417238!
# Avg loss: 0.00902106033824263!
# Avg loss: 0.009012503596719247!
# Avg loss: 0.009011311586680979!
# Avg loss: 0.009013758635891616!
# Avg loss: 0.009013218461828577!
# Avg loss: 0.009010432293890366!
# Avg loss: 0.009006644584806054!
# Avg loss: 0.009004612916808506!
# Avg loss: 0.009005406663876177!
# Avg loss: 0.009004196666000249!
# Avg loss: 0.009001774779485838!
# Avg loss: 0.009000112610816208!
# Avg loss: 0.00899894770566334!
# Avg loss: 0.008999228833569078!
# Avg loss: 0.008999214953082249!
# Avg loss: 0.008998064497336221!
# Avg loss: 0.00899791908193985!
# Avg loss: 0.008997328517632469!
# Avg loss: 0.008997274265220009!
# Avg loss: 0.008995937471076066!
# Avg loss: 0.008992963917302366!
# Avg loss: 0.008997086850617392!
# Avg loss: 0.008998443447577149!
# Avg loss: 0.008999765152146514!
# Avg loss: 0.00899779925802098!
# Avg loss: 0.00899181613033657!
# Avg loss: 0.008990596690436519!
# Avg loss: 0.00899396937420742!
# Avg loss: 0.008992090145239141!
# Avg loss: 0.008990769377266238!
# Avg loss: 0.008991170673952453!
# Avg loss: 0.008992632653652114!
# Avg loss: 0.008993780629259712!
# Avg loss: 0.008990109603745773!
# Avg loss: 0.008989348980050806!
# Avg loss: 0.008988751034340178!
# Avg loss: 0.008990020622904946!
# Avg loss: 0.008991113309606323!
# Avg loss: 0.0089873958481067!
# Avg loss: 0.008985806319492109!
# Avg loss: 0.008989825295231195!
# Avg loss: 0.00898922673824662!
# Avg loss: 0.008983990180861762!
# Avg loss: 0.00897994545361551!
# Avg loss: 0.00897950876745521!
# Avg loss: 0.008984673847036101!
# Avg loss: 0.008986660097751837!
# Avg loss: 0.008982560955298596!
# Avg loss: 0.00898081646142155!
# Avg loss: 0.008981375365565328!
# Avg loss: 0.008984664309642199!
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0030
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0058
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0166
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0041
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0047
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0159
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0060
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0055
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0054
# ------------------------------
# client: 0
# Avg loss: 0.010952009154473974!
# Avg loss: 0.007790219145778489!
# Avg loss: 0.006175368433614495!
# Avg loss: 0.004589300728330272!
# Avg loss: 0.0032751198108113993!
# Avg loss: 0.0023808869271306323!
# Avg loss: 0.001664369773012974!
# Avg loss: 0.001507911089429399!
# Avg loss: 0.0011862030896857808!
# Avg loss: 0.0009380463069919642!
# Avg loss: 0.0008843202168948968!
# Avg loss: 0.0008259945682372442!
# ...
# Avg loss: 0.008695170745874444!
# Avg loss: 0.006486925474891905!
# Avg loss: 0.004348693358867119!
# Avg loss: 0.0028137567830102245!
# Avg loss: 0.0019273361120819268!
# Avg loss: 0.0017606703817121645!
# Avg loss: 0.001561267061961189!
# Avg loss: 0.0012229246348882347!
# Avg loss: 0.0009699212550610052!
# Avg loss: 0.0009068820139843107!
# Avg loss: 0.0008764253111803555!
# Avg loss: 0.0007187265793557648!
# Avg loss: 0.0005915520604200234!
# Avg loss: 0.0004982418309646164!
# Avg loss: 0.0004250109251415779!
# Avg loss: 0.0003678903952277324!
# Avg loss: 0.0003304183416685191!
# Avg loss: 0.0002988171154765951!
# Avg loss: 0.00027122699134148813!
# Avg loss: 0.00025436591686154014!
# Avg loss: 0.00023716220061487548!
# Avg loss: 0.0002269591378012592!
# Avg loss: 0.00022125097490591846!
# Avg loss: 0.0002139360162345838!
# Avg loss: 0.0002082900338905347!
# Avg loss: 0.00020454019238513865!
# Avg loss: 0.00019689149901552127!
# Avg loss: 0.0001915939967655807!
# Avg loss: 0.00018794198122198697!
# Avg loss: 0.0001846582562355555!
# Avg loss: 0.0001825097612601212!
# Avg loss: 0.00017945631393691505!
# Avg loss: 0.00017370747412921142!
# Avg loss: 0.0001727602630110899!
# Avg loss: 0.0001724301637064703!
# Avg loss: 0.0001701614485640827!
# Avg loss: 0.0001677810977472897!
# Avg loss: 0.0001671773876929213!
# Avg loss: 0.0001685117594051159!
# Avg loss: 0.00016759124777687855!
# Avg loss: 0.0001653009665240764!
# Avg loss: 0.00016507727871707326!
# Avg loss: 0.00016479164640069636!
# Avg loss: 0.0001655459676224306!
# Avg loss: 0.0001658820328554119!
# Avg loss: 0.0001650245553463492!
# Avg loss: 0.00016356579230944135!
# Avg loss: 0.0001632027693024914!
# Avg loss: 0.00016325788416139632!
# Avg loss: 0.0001644131307461786!
# Avg loss: 0.00016476855436844555!
# Avg loss: 0.00016252815521644002!
# Avg loss: 0.0001618237332756204!
# Avg loss: 0.00016330180657632808!
# Avg loss: 0.0001626927008491445!
# Avg loss: 0.00016310097316951064!
# Avg loss: 0.0001629702794214912!
# Avg loss: 0.0001618057001237124!
# Avg loss: 0.0001625091905667849!
# Avg loss: 0.0001621863591338979!
# Avg loss: 0.00016030272263568198!
# Avg loss: 0.0001618762738667101!
# Avg loss: 0.00016216813012154792!
# Avg loss: 0.00016314253618929798!
# Avg loss: 0.00016428514493895818!
# Avg loss: 0.00016443497271249422!
# Avg loss: 0.00016272620919645912!
# Avg loss: 0.0001607849004083543!
# Avg loss: 0.0001636709880174673!
# Avg loss: 0.0001666985638629844!
# Avg loss: 0.00016577702221430476!
# ------------------------------
# client: 1
# Avg loss: 0.03154478949232725!
# Avg loss: 0.028427088671984773!
# Avg loss: 0.023502327256331532!
# Avg loss: 0.021290903914001926!
# Avg loss: 0.0204560884872141!
# Avg loss: 0.018792095345512887!
# Avg loss: 0.017873472624796705!
# Avg loss: 0.01716790402900794!
# Avg loss: 0.0163387189402268!
# Avg loss: 0.01609421776205636!
# Avg loss: 0.016033927138504017!
# Avg loss: 0.0161343150281391!
# Avg loss: 0.016219271879487376!
# Avg loss: 0.01601354347667363!
# Avg loss: 0.015715726968792296!
# Avg loss: 0.01548238296847823!
# Avg loss: 0.015396338530610289!
# Avg loss: 0.015247473628276869!
# Avg loss: 0.015030573872219672!
# Avg loss: 0.014840568697588121!
# Avg loss: 0.014731136055885751!
# Avg loss: 0.01463816140507106!
# Avg loss: 0.0145472088470918!
# Avg loss: 0.014472387316983864!
# Avg loss: 0.014437320605904157!
# Avg loss: 0.01441550362644989!
# Avg loss: 0.01439309448401256!
# Avg loss: 0.014369300509987018!
# Avg loss: 0.014340186062133853!
# Avg loss: 0.014319195958628371!
# Avg loss: 0.014304005592678854!
# Avg loss: 0.014278517476230566!
# Avg loss: 0.014251884055834883!
# Avg loss: 0.014237713815762542!
# Avg loss: 0.014229909464238516!
# Avg loss: 0.014219028999934456!
# Avg loss: 0.014204134687759051!
# Avg loss: 0.014195771793571338!
# Avg loss: 0.014190451859132812!
# Avg loss: 0.014182145280035077!
# Avg loss: 0.014177504111387596!
# Avg loss: 0.014172553350047206!
# Avg loss: 0.014164070143295552!
# Avg loss: 0.014156431689653779!
# Avg loss: 0.014149951317499188!
# Avg loss: 0.014143914196362543!
# Avg loss: 0.014138939459596097!
# Avg loss: 0.014136387996701055!
# Avg loss: 0.014133639576606735!
# Avg loss: 0.014130061564687253!
# Avg loss: 0.01412729090212044!
# Avg loss: 0.014125186665496442!
# Avg loss: 0.014122601932373679!
# Avg loss: 0.014119743793890199!
# Avg loss: 0.014116663929538689!
# Avg loss: 0.014115584522742636!
# Avg loss: 0.014112885819401413!
# Avg loss: 0.014110902156921531!
# Avg loss: 0.01411032015896339!
# Avg loss: 0.014108521919513207!
# Avg loss: 0.014106040986591684!
# Avg loss: 0.014104986311200066!
# Avg loss: 0.014103247323624828!
# Avg loss: 0.014102801481025723!
# Avg loss: 0.014101006823769116!
# Avg loss: 0.014100597989522517!
# Avg loss: 0.01409917251500616!
# Avg loss: 0.014099609405344325!
# Avg loss: 0.01409780980812163!
# Avg loss: 0.014098127406812443!
# Avg loss: 0.014095704675380556!
# Avg loss: 0.014096581311183343!
# Avg loss: 0.014094171219309809!
# Avg loss: 0.014095153713915422!
# Avg loss: 0.014091949462320485!
# Avg loss: 0.014095505315242462!
# Avg loss: 0.014091664955471591!
# Avg loss: 0.014094719779859138!
# Avg loss: 0.014090440789375644!
# Avg loss: 0.01409348272621017!
# Avg loss: 0.014088540554936059!
# Avg loss: 0.014093029542358314!
# Avg loss: 0.014086557835764022!
# Avg loss: 0.014091526096992293!
# Avg loss: 0.014085412892882706!
# Avg loss: 0.014089934106326278!
# Avg loss: 0.014084069400297968!
# Avg loss: 0.014088886593654593!
# Avg loss: 0.014083572500597512!
# Avg loss: 0.014086952167110856!
# Avg loss: 0.014082700654438299!
# Avg loss: 0.014084741623904525!
# Avg loss: 0.014083500652311755!
# Avg loss: 0.014082514649281185!
# Avg loss: 0.014083889302626449!
# Avg loss: 0.014079959674205587!
# Avg loss: 0.01408529041223377!
# Avg loss: 0.014078645244532074!
# Avg loss: 0.014086361315092095!
# Avg loss: 0.014076782384950566!
# ------------------------------
# client: 2
# Avg loss: 0.023270437839116007!
# Avg loss: 0.01948499405310334!
# Avg loss: 0.014762929210755829!
# Avg loss: 0.011919824896976934!
# Avg loss: 0.009899822186465219!
# Avg loss: 0.007968333685247823!
# Avg loss: 0.0061565531226551685!
# Avg loss: 0.004613322435585966!
# Avg loss: 0.0034954653658648264!
# Avg loss: 0.0025418846299635335!
# Avg loss: 0.0018161721979769634!
# Avg loss: 0.0014181151330330977!
# Avg loss: 0.0011550334472728234!
# Avg loss: 0.0009901333832355401!
# Avg loss: 0.000879639899255172!
# Avg loss: 0.0007674338462682803!
# Avg loss: 0.0006129937018802896!
# Avg loss: 0.000514158699966932!
# Avg loss: 0.0004685138235921234!
# Avg loss: 0.00040769837859443213!
# Avg loss: 0.0003453400747055942!
# Avg loss: 0.00031908266214675983!
# Avg loss: 0.00029370933713967893!
# Avg loss: 0.00027631152376386583!
# Avg loss: 0.0002567913531546158!
# Avg loss: 0.00023819399569385762!
# Avg loss: 0.0002281690484971932!
# Avg loss: 0.00021738068939688068!
# Avg loss: 0.00021653283126624957!
# Avg loss: 0.00021411357711410042!
# Avg loss: 0.00020614622016485858!
# Avg loss: 0.00020191364713051976!
# Avg loss: 0.00020040806074575812!
# Avg loss: 0.0001999763853192841!
# Avg loss: 0.00019629889689061505!
# Avg loss: 0.00019409015974891492!
# Avg loss: 0.00018753534578687929!
# Avg loss: 0.000184484672319248!
# Avg loss: 0.00018833064768841723!
# Avg loss: 0.00018716461091116798!
# Avg loss: 0.00018410733600224678!
# Avg loss: 0.00018226787200887885!
# Avg loss: 0.00017651314360061103!
# Avg loss: 0.0001792226729976202!
# Avg loss: 0.0001769488039379515!
# Avg loss: 0.0001849894327256152!
# Avg loss: 0.00018217007373399005!
# Avg loss: 0.00018306114878517595!
# Avg loss: 0.0001797034609929445!
# Avg loss: 0.00018806034472120813!
# Avg loss: 0.0001883367323929027!
# Avg loss: 0.00020172882820456076!
# Avg loss: 0.00020121177195809044!
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0047
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0055
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0067
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0057
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0042
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0043
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0083
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0051
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0035
# ------------------------------
# client: 0
# Avg loss: 0.023426584859504752!
# Avg loss: 0.020396976112921645!
# Avg loss: 0.01692385886638173!
# Avg loss: 0.015147127315516021!
# Avg loss: 0.013832758546971793!
# Avg loss: 0.012981159133256976!
# Avg loss: 0.012704157186420085!
# Avg loss: 0.012225264412330338!
# Avg loss: 0.011882654469066741!
# Avg loss: 0.011673602916565263!
# Avg loss: 0.011616271212960782!
# Avg loss: 0.011588120917294872!
# Avg loss: 0.011457074888940042!
# Avg loss: 0.011399123117774555!
# Avg loss: 0.011390351536665549!
# Avg loss: 0.011404631086064683!
# Avg loss: 0.011359819951254431!
# Avg loss: 0.011319297538827395!
# Avg loss: 0.011309705089628893!
# Avg loss: 0.011316700821086413!
# Avg loss: 0.011304595403358254!
# Avg loss: 0.011280135838516685!
# Avg loss: 0.011268466980915074!
# Avg loss: 0.011271289935585382!
# Avg loss: 0.011270592182939746!
# Avg loss: 0.01126510050620027!
# Avg loss: 0.011265734316841075!
# Avg loss: 0.011269642759758084!
# Avg loss: 0.011270696354761517!
# Avg loss: 0.011271256627072528!
# Avg loss: 0.01127573445426492!
# Avg loss: 0.011276887121500939!
# Avg loss: 0.011274170351310129!
# Avg loss: 0.011272399485925177!
# Avg loss: 0.011274740614870117!
# Avg loss: 0.011274361612773115!
# ------------------------------
# client: 1
# Avg loss: 0.02544120974075213!
# Avg loss: 0.02490226266868073!
# Avg loss: 0.018545331289727376!
# Avg loss: 0.014528644643141887!
# Avg loss: 0.012346417579004386!
# Avg loss: 0.009452266585955537!
# Avg loss: 0.007255651455191886!
# Avg loss: 0.00593575380557013!
# Avg loss: 0.004803759864850387!
# Avg loss: 0.004002557491906676!
# Avg loss: 0.0031820673936332846!
# Avg loss: 0.0023586643061086457!
# Avg loss: 0.00180265178962145!
# Avg loss: 0.0015344130954205563!
# Avg loss: 0.0013484561925846113!
# Avg loss: 0.001066542772102063!
# Avg loss: 0.0008730428820975551!
# Avg loss: 0.0007883635119969768!
# Avg loss: 0.0007472835970050558!
# Avg loss: 0.0006692064035617781!
# Avg loss: 0.0005792995978140425!
# Avg loss: 0.0005537919895171702!
# Avg loss: 0.0005382401751713435!
# Avg loss: 0.0005182820488988681!
# Avg loss: 0.0004891668051057726!
# Avg loss: 0.00047896789400738273!
# Avg loss: 0.00046736219012927905!
# Avg loss: 0.00045720719045372484!
# Avg loss: 0.00044208877853028146!
# Avg loss: 0.00042555126336083046!
# Avg loss: 0.00041038339587733694!
# Avg loss: 0.0003987500611401629!
# Avg loss: 0.00038795600864583926!
# Avg loss: 0.00037698788616580714!
# Avg loss: 0.0003695815732074455!
# Avg loss: 0.0003641138343088339!
# Avg loss: 0.00035528250588261776!
# Avg loss: 0.00034685445566689545!
# Avg loss: 0.00034543716229260707!
# Avg loss: 0.00034044968516354856!
# Avg loss: 0.0003343606907136139!
# Avg loss: 0.00032773368119099665!
# Avg loss: 0.00032179509240828945!
# Avg loss: 0.0003187159013183797!
# Avg loss: 0.00031748445010028564!
# Avg loss: 0.00031612861857865937!
# Avg loss: 0.0003122891744389259!
# Avg loss: 0.00031245119243825077!
# Avg loss: 0.00030281616274957437!
# Avg loss: 0.00029352311756080475!
# Avg loss: 0.0002946544019111267!
# Avg loss: 0.00029348717400959383!
# Avg loss: 0.0002950231104334004!
# Avg loss: 0.00029173324214752937!
# Avg loss: 0.000284009024981818!
# Avg loss: 0.00028105985244792465!
# Avg loss: 0.00028032490539165643!
# Avg loss: 0.0002758774018419293!
# Avg loss: 0.00027316108815739426!
# Avg loss: 0.00027206018926411466!
# Avg loss: 0.0002739606918278999!
# Avg loss: 0.0002722782093799954!
# Avg loss: 0.00026277776297623255!
# Avg loss: 0.0002579855809820704!
# Avg loss: 0.00026487070754910747!
# Avg loss: 0.0002646661231892722!
# Avg loss: 0.0002626920940080405!
# Avg loss: 0.00025821901378776603!
# Avg loss: 0.00025208886426222914!
# Avg loss: 0.0002509608035802557!
# Avg loss: 0.00025472065927639655!
# Avg loss: 0.0002542799109683832!
# Avg loss: 0.00025376425918769503!
# Avg loss: 0.0002479819052257426!
# Avg loss: 0.0002442478553128543!
# Avg loss: 0.00024378735493238915!
# Avg loss: 0.0002425930089174244!
# Avg loss: 0.0002467280149755879!
# Avg loss: 0.0002449455490905924!
# Avg loss: 0.00024489782631235355!
# Avg loss: 0.00023835641426956045!
# Avg loss: 0.00024109949499461435!
# Avg loss: 0.0002443613292507507!
# Avg loss: 0.0002551925794076245!
# Avg loss: 0.0002500916353346838!
# Avg loss: 0.0002631755446198743!
# Avg loss: 0.0002683711134181976!
# Avg loss: 0.0003010938435772914!
# Avg loss: 0.00030920929802353685!
# Avg loss: 0.0003275824153176169!
# Avg loss: 0.0003257727966168507!
# ------------------------------
# client: 2
# Avg loss: 0.023032891443290283!
# Avg loss: 0.021913022379109557!
# Avg loss: 0.01770323365800626!
# Avg loss: 0.01202525557291286!
# Avg loss: 0.008544971428954492!
# Avg loss: 0.006545822169694778!
# Avg loss: 0.005089597641702615!
# Avg loss: 0.004322088501206357!
# Avg loss: 0.004019158969564766!
# Avg loss: 0.0032932704324897108!
# Avg loss: 0.002530892740633135!
# Avg loss: 0.002038644569202006!
# Avg loss: 0.001643195403922467!
# Avg loss: 0.0014171810583311147!
# Avg loss: 0.0012634632794161387!
# Avg loss: 0.001221690426850491!
# Avg loss: 0.0012620424955427248!
# Avg loss: 0.0012292595639807283!
# Avg loss: 0.0011887404339843972!
# Avg loss: 0.0011869838936263478!
# Avg loss: 0.001174141295837406!
# Avg loss: 0.0011645450095911277!
# Avg loss: 0.0011484576224019822!
# Avg loss: 0.0011232917279850577!
# Avg loss: 0.0011091423673205252!
# Avg loss: 0.001109157422847981!
# Avg loss: 0.0011066714993179024!
# Avg loss: 0.0011059069820858742!
# Avg loss: 0.0011050436471132723!
# Avg loss: 0.001102116709257075!
# Avg loss: 0.001097684653146492!
# Avg loss: 0.0010957642585954848!
# Avg loss: 0.0010949307427076367!
# Avg loss: 0.0010911106039236528!
# Avg loss: 0.0010854598374983955!
# Avg loss: 0.0010800255942020462!
# Avg loss: 0.0010772460039686392!
# Avg loss: 0.0010743191371216198!
# Avg loss: 0.001071378307450838!
# Avg loss: 0.0010669270734122924!
# Avg loss: 0.0010639945763387005!
# Avg loss: 0.0010606577477778956!
# Avg loss: 0.0010579189637299653!
# Avg loss: 0.0010563299499337594!
# Avg loss: 0.0010567913167706896!
# Avg loss: 0.0010552937362729154!
# Avg loss: 0.0010513532164543448!
# Avg loss: 0.0010497045175484724!
# Avg loss: 0.0010497280524236884!
# Avg loss: 0.001047859395821149!
# Avg loss: 0.0010463617904857376!
# Avg loss: 0.001045692450087093!
# Avg loss: 0.001043386424522623!
# Avg loss: 0.0010413016918323593!
# Avg loss: 0.0010394550359357406!
# Avg loss: 0.0010403185577247125!
# Avg loss: 0.0010395656442409517!
# Avg loss: 0.0010389768626805562!
# Avg loss: 0.0010384317645327694!
# Avg loss: 0.0010359743705816982!
# Avg loss: 0.0010365264704164663!
# Avg loss: 0.0010358114460985728!
# Avg loss: 0.0010357453744419824!
# Avg loss: 0.001033312395741556!
# Avg loss: 0.001032136678723911!
# Avg loss: 0.0010316315072786135!
# Avg loss: 0.0010332484642414385!
# Avg loss: 0.0010322769616075789!
# Avg loss: 0.0010284157702581827!
# Avg loss: 0.0010260763444847499!
# Avg loss: 0.0010279734303780211!
# Avg loss: 0.0010286185752602251!
# Avg loss: 0.001025283022683349!
# Avg loss: 0.0010232369773657032!
# Avg loss: 0.0010257814561694546!
# Avg loss: 0.0010257369940465347!
# Avg loss: 0.001021997653053764!
# Avg loss: 0.0010194215745341732!
# Avg loss: 0.0010208071321371412!
# Avg loss: 0.0010216631206710265!
# Avg loss: 0.0010194358919348664!
# Avg loss: 0.0010190686192458997!
# Avg loss: 0.0010210041824670194!
# Avg loss: 0.0010205376929565092!
# Avg loss: 0.0010198800936297896!
# Avg loss: 0.0010183580174657437!
# Avg loss: 0.001017275818236006!
# Avg loss: 0.0010140005387334365!
# Avg loss: 0.0010162663750268545!
# Avg loss: 0.0010181585154089134!
# Avg loss: 0.0010160429123159058!
# Avg loss: 0.0010174480416140596!
# Avg loss: 0.001014863459331347!
# Avg loss: 0.0010159886907752025!
# Avg loss: 0.0010174387627855214!
# Avg loss: 0.0010156658570754!
# Avg loss: 0.0010138677699527913!
# Avg loss: 0.0010149737946325863!
# Avg loss: 0.001016310459931778!
# Avg loss: 0.0010178587743503915!
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0034
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0075
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0103
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0044
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0045
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0033
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0067
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0058
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0018

# %%
import pickle

# 创建一个字典保存所有数据
data_to_save = {
    'round_train_loss': round_train_loss,
    'round_test_avg': round_test_avg,
    'round_evaluation_results': round_evaluation_results
}

# 将数据保存到文件中
with open('Diff_Env_training_data_test1.pkl', 'wb') as f:
    pickle.dump(data_to_save, f)

print("Data saved successfully.")
# Out:
# Data saved successfully.

# %%
data_to_save['round_evaluation_results']
# Out:
# [{0: [0.0028890145, 0.008645038, 0.015587084],
#   1: [0.0038760307, 0.003941332, 0.005974651],
#   2: [0.0069550215, 0.0055361353, 0.0041896286]},
#  {0: [0.00277886, 0.0055262004, 0.012424688],
#   1: [0.0035076533, 0.004052601, 0.004615461],
#   2: [0.0059233024, 0.0048393174, 0.0027668702]},
#  {0: [0.0009832619, 0.012735342, 0.021146888],
#   1: [0.0017016614, 0.0038646802, 0.0047120564],
#   2: [0.0038551344, 0.005250651, 0.002260029]},
#  {0: [0.002309709, 0.0064615975, 0.01395063],
#   1: [0.0030294464, 0.0029341758, 0.0055295336],
#   2: [0.00452233, 0.004038671, 0.0039434195]},
#  {0: [0.0029681362, 0.0058104303, 0.016649956],
#   1: [0.0040684305, 0.004696302, 0.015946008],
#   2: [0.005979432, 0.005520022, 0.0054364293]},
#  {0: [0.0057819975, 0.0053324434, 0.018964386],
#   1: [0.010343716, 0.0031823886, 0.014050335],
#   2: [0.0096573355, 0.003713542, 0.003941545]},
#  {0: [0.003756425, 0.004775083, 0.015305094],
#   1: [0.004799711, 0.0021616307, 0.0076889643],
#   2: [0.007933814, 0.0041418225, 0.004617559]},
#  {0: [0.0033852716, 0.0051898733, 0.010171612],
#   1: [0.004374616, 0.0037828858, 0.008257341],
#   2: [0.006618621, 0.004924863, 0.0050240657]},
#  {0: [0.00465174, 0.005496137, 0.006694296],
#   1: [0.0057267253, 0.004237262, 0.0043236213],
#   2: [0.008290044, 0.005147131, 0.0035367522]},
#  {0: [0.003419582, 0.007544456, 0.010252889],
#   1: [0.0044015744, 0.0044843624, 0.0033001415],
#   2: [0.0066966005, 0.005837669, 0.0017543794]}]

# %%
round_idx = 0
client_idx =0 
test_dataset_idx = 0

# %%
data_to_save['round_evaluation_results'][round_idx][client_idx][test_dataset_idx]
# Out:
# 0.0028890145

# %%
def calculate_mean_and_variance(data, client_idx):
    # Initialize lists to store all losses for each dataset
    losses = []
    num_datasets = len(data[0][client_idx])

    # Gather losses for each dataset across all rounds
    for i in range(num_datasets):
        losses.append([])

    for round_data in data:
        for i in range(num_datasets):
            losses[i].append(round_data[client_idx][i])

    # Calculate mean and variance for each dataset
    means = [np.mean(loss) for loss in losses]
    variances = [np.var(loss) for loss in losses]
#     print(losses)

    return means, variances

# %%
client_idx = 2

means, variances = calculate_mean_and_variance(data_to_save['round_evaluation_results'], client_idx)

# %%
means, variances
# Out:
# ([0.0032923997, 0.0067516603, 0.014114754],
#  [1.5115413e-06, 5.2426203e-06, 1.7139057e-05])

# %%
# Number of clients and datasets
num_clients = len(data_to_save['round_evaluation_results'][0])
num_datasets = len(data_to_save['round_evaluation_results'][0][0])

# Initialize storage for all means and variances
all_means = []
all_variances = []

# Calculate means and variances for each client
for client_idx in range(num_clients):
    means, variances = calculate_mean_and_variance(data_to_save['round_evaluation_results'], client_idx)
    all_means.append(means)
    all_variances.append(variances)

# Plot the results
x = np.arange(num_datasets)

fig, ax = plt.subplots(2, 1, figsize=(10, 8))

for client_idx in range(num_clients):
    ax[0].plot(x, all_means[client_idx], label=f'Client {client_idx}')
    ax[1].plot(x, all_variances[client_idx], label=f'Client {client_idx}')

ax[0].set_title('Mean Losses for Each Client')
ax[0].set_xlabel('Dataset Index')
ax[0].set_ylabel('Mean Loss')
ax[0].legend()

ax[1].set_title('Variance of Losses for Each Client')
ax[1].set_xlabel('Dataset Index')
ax[1].set_ylabel('Variance of Loss')
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
def plot_mean_and_variance(round_evaluation_results):
    # Number of clients and datasets
    num_clients = len(round_evaluation_results[0])
    num_datasets = len(round_evaluation_results[0][0])

    # Initialize storage for all means and variances
    all_means = []
    all_variances = []

    # Calculate means and variances for each client
    for client_idx in range(num_clients):
        means, variances = calculate_mean_and_variance(round_evaluation_results, client_idx)
        all_means.append(means)
        all_variances.append(variances)
        # Print means and variances
        print(f"Client {client_idx}:")
        for i in range(num_datasets):
            print(f"  Dataset {i}: Mean = {means[i]:.6f}, Variance = {variances[i]:.6f}")

    # Plot the results
    x = np.arange(num_datasets)
    plt.figure(figsize=(12, 8))

    for client_idx in range(num_clients):
        means = all_means[client_idx]
        variances = all_variances[client_idx]
        std_devs = np.sqrt(variances)
        plt.errorbar(x, means, yerr=std_devs, label=f'Client {client_idx}', 
                     capsize=5, marker='o', linestyle='-', linewidth=2)

    plt.title('Mean and Variance of Losses for Each Client')
    plt.xlabel('Dataset Index')
    plt.ylabel('Loss')
    plt.xticks(x)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_mean_and_variance(data_to_save['round_evaluation_results'])
# Out:
# Client 0:
#   Dataset 0: Mean = 0.003292, Variance = 0.000002
#   Dataset 1: Mean = 0.006752, Variance = 0.000005
#   Dataset 2: Mean = 0.014115, Variance = 0.000017
# Client 1:
#   Dataset 0: Mean = 0.004583, Variance = 0.000005
#   Dataset 1: Mean = 0.003734, Variance = 0.000001
#   Dataset 2: Mean = 0.007440, Variance = 0.000016
# Client 2:
#   Dataset 0: Mean = 0.006643, Variance = 0.000003
#   Dataset 1: Mean = 0.004895, Variance = 0.000000
#   Dataset 2: Mean = 0.003747, Variance = 0.000001

# %%
data_to_save['round_test_avg'][round_idx][client_idx][-1]
# Out:
# 0.00874867499320042

# %%
data_to_save['round_train_loss'][round_idx][client_idx][-1]
# Out:
# 0.002248886807215931

# %%
Clients[0].dataset_X
# Out:
#             0         1         2        actions
# 0    0.723126 -0.690716 -0.665330          [2.0]
# 1    0.695654 -0.718377 -0.779759          [2.0]
# 2    0.662230 -0.749301 -0.910785          [2.0]
# 3    0.621591 -0.783342 -1.060366          [2.0]
# 4    0.572256 -0.820075 -1.230371          [2.0]
# ..        ...       ...       ...            ...
# 494  0.998019 -0.062918 -0.308787   [0.96656954]
# 495  0.997334 -0.072972 -0.201553    [1.3084062]
# 496  0.997152 -0.075419 -0.049075  [-0.25345343]
# 497  0.996631 -0.082016 -0.132344    [1.3916724]
# 498  0.996742 -0.080661  0.027197  [-0.03239578]
#
# [499 rows x 4 columns]

# %%
TRPO_model = TRPO.load("models/Pendulmn_TRPO_Policy")

timesteps_real_per_round = 500
timesteps_fc_per_round = timesteps_real_per_round * 30
epoch_per_round = 100
CLIENTS_NUM = 3
rounds_num = 20
batch_size_env_model = 128

env_models = []

Global_RL = TRPO_model

gravitys = [8.0, 10.0, 12.0]
# lengths = [0.5, 0.2, 0.8]
real_envs = []
Clients = []
for i in range(CLIENTS_NUM):
#     real_envs.append( TimeLimit(PendulumEnv(), max_episode_steps=200) )
    gravity = gravitys[i]
#     length = lengths[i]
    env = TimeLimit(PendulumEnv( g = gravity), max_episode_steps = 200)
    real_envs.append(env)
    
    policy_net = Global_RL
    agent = SB3Agent(policy_net)
    client = FRLClient(real_envs[i], agent, lr = 3e-4, hidden_size = 256,  device = device)
    Clients.append(client)
    env_model = copy.deepcopy(client.model)
    env_models.append(env_model)

    
train_loss_list = []
test_avg_list = []

for client_idx in range(len(Clients)):
    print('------------------------------')
    print("client: " + str(client_idx))
    # update policy
    # train prediction models
    Clients[client_idx].learn(timesteps_real_per_round, epoch_per_round, batch_size_env_model)
     #
    train_loss_list.append(Clients[client_idx].train_loss_list)
    test_avg_list.append(Clients[client_idx].test_avg_list)
# Out:
# ------------------------------
# client: 0
# Avg loss: 0.009274743266093234!
# Avg loss: 0.007902312006432719!
# Avg loss: 0.005649189879623009!
# Avg loss: 0.004647292995393097!
# Avg loss: 0.0036832242877062526!
# Avg loss: 0.0031982338622401586!
# Avg loss: 0.002492288133382772!
# Avg loss: 0.0016974277898665!
# Avg loss: 0.0013609852676108858!
# Avg loss: 0.0010917374417946726!
# Avg loss: 0.0009267679778349702!
# Avg loss: 0.0007027580534971397!
# Avg loss: 0.0005279598885196416!
# Avg loss: 0.0004443033954188043!
# Avg loss: 0.00041183847330766334!
# Avg loss: 0.00038625569815849305!
# Avg loss: 0.00035956268443063284!
# Avg loss: 0.00034269556362232835!
# Avg loss: 0.0003232596268634325!
# Avg loss: 0.00029712718526070603!
# Avg loss: 0.0002745977464837779!
# Avg loss: 0.0002710714733397405!
# Avg loss: 0.00027480470003941567!
# Avg loss: 0.00026702416179527215!
# Avg loss: 0.0002502312044551521!
# Avg loss: 0.0002380383900050731!
# Avg loss: 0.00023209897155349307!
# Avg loss: 0.00022589344972229715!
# Avg loss: 0.0002212804530027294!
# Avg loss: 0.00021575103667809497!
# Avg loss: 0.00021050426923087192!
# Avg loss: 0.00020553638876814754!
# Avg loss: 0.00019950452086646918!
# Avg loss: 0.00019238734991821124!
# Avg loss: 0.00018706284988771434!
# Avg loss: 0.0001845374086442083!
# Avg loss: 0.0001802125650898271!
# Avg loss: 0.00017449582761363066!
# Avg loss: 0.00016990421028083345!
# Avg loss: 0.0001669119224545549!
# Avg loss: 0.00016402740107222276!
# Avg loss: 0.00016144925232509878!
# Avg loss: 0.00015815592041163267!
# Avg loss: 0.00015658508053102574!
# Avg loss: 0.00015427606597171462!
# Avg loss: 0.00015265674048038137!
# Avg loss: 0.00014828733410629033!
# Avg loss: 0.00014714752658449016!
# Avg loss: 0.0001448341256400454!
# Avg loss: 0.00014463937822370098!
# Avg loss: 0.00013926796769756796!
# Avg loss: 0.00013916792560811093!
# Avg loss: 0.00013723053581818096!
# Avg loss: 0.00013853869175648015!
# Avg loss: 0.00013475165350451828!
# Avg loss: 0.00013319879515731733!
# Avg loss: 0.00012955160692153337!
# Avg loss: 0.00013051041651415573!
# Avg loss: 0.0001282431474997973!
# Avg loss: 0.00012917395680043834!
# Avg loss: 0.0001250722316477019!
# Avg loss: 0.00012670026344731392!
# Avg loss: 0.00012337150747545895!
# Avg loss: 0.00012487664534432952!
# Avg loss: 0.00012228697694808944!
# Avg loss: 0.00012489195577719176!
# Avg loss: 0.00012056985051704791!
# Avg loss: 0.00011981699202891605!
# Avg loss: 0.00011900532409285347!
# Avg loss: 0.00012129423124984366!
# Avg loss: 0.0001189966955544719!
# Avg loss: 0.00011832615495436017!
# Avg loss: 0.00011715013825764232!
# Avg loss: 0.00011936971345344697!
# Avg loss: 0.0001178988122912017!
# Avg loss: 0.00011774791284220025!
# Avg loss: 0.00011556592867715191!
# Avg loss: 0.00011701175543597249!
# Avg loss: 0.00011657014106750316!
# Avg loss: 0.00011631724458055715!
# Avg loss: 0.00011502708543910481!
# Avg loss: 0.00011697756916177582!
# Avg loss: 0.00011622789620929552!
# Avg loss: 0.00011339871204199881!
# Avg loss: 0.00011397600945457498!
# Avg loss: 0.00011491065444564204!
# Avg loss: 0.00011565819919601002!
# Avg loss: 0.00011444249047234697!
# Avg loss: 0.0001131315883921502!
# Avg loss: 0.00011247284323909905!
# Avg loss: 0.00011468998746920534!
# Avg loss: 0.00011448977362031579!
# Avg loss: 0.00011327632064623098!
# Avg loss: 0.0001128741856960384!
# Avg loss: 0.00011267046916780525!
# Avg loss: 0.00011251383254877586!
# Avg loss: 0.00011337967124016283!
# Avg loss: 0.00011450077340687888!
# Avg loss: 0.00011312984645779049!
# Avg loss: 0.0001122588025292733!
# ------------------------------
# client: 1
# Avg loss: 0.015067083284032681!
# Avg loss: 0.012698742892219646!
# Avg loss: 0.010651908607287623!
# Avg loss: 0.007427248281425515!
# Avg loss: 0.005120543840372799!
# Avg loss: 0.003898345235284069!
# Avg loss: 0.0029482919082147417!
# Avg loss: 0.0023828411660406345!
# Avg loss: 0.0019115824328355302!
# Avg loss: 0.0014841126099084552!
# Avg loss: 0.0012129567830076364!
# Avg loss: 0.0009654285828401044!
# Avg loss: 0.0008385269110037067!
# Avg loss: 0.0007205213788514205!
# Avg loss: 0.0005869727663912272!
# Avg loss: 0.000526427202952012!
# Avg loss: 0.0004834949361982884!
# Avg loss: 0.0004596983980369866!
# Avg loss: 0.0004256979327753167!
# Avg loss: 0.0003941744093519143!
# Avg loss: 0.0003722738996990908!
# Avg loss: 0.0003539174601625443!
# Avg loss: 0.00033588034313803897!
# Avg loss: 0.00032091209866014957!
# Avg loss: 0.000308862711347615!
# Avg loss: 0.0002965487202576848!
# Avg loss: 0.0002880860676342915!
# Avg loss: 0.0002866349743953833!
# Avg loss: 0.0002832400627719759!
# Avg loss: 0.00027656590101363083!
# Avg loss: 0.0002710392461686221!
# Avg loss: 0.00026831163065973366!
# Avg loss: 0.00026341529416223843!
# Avg loss: 0.0002607085255715447!
# Avg loss: 0.00025814883367843324!
# Avg loss: 0.000254440400343204!
# Avg loss: 0.0002476775285106214!
# Avg loss: 0.0002437311118743916!
# Avg loss: 0.00023907765745169248!
# Avg loss: 0.0002339050290375629!
# Avg loss: 0.00023568720798796978!
# Avg loss: 0.00023651396417676552!
# Avg loss: 0.00023236097034252148!
# Avg loss: 0.00023065800207594596!
# Avg loss: 0.00022898463394483315!
# Avg loss: 0.00022466394021572946!
# Avg loss: 0.00022113586244434675!
# Avg loss: 0.00022250476915208612!
# Avg loss: 0.00022139714165480957!
# Avg loss: 0.00022177915118049897!
# Avg loss: 0.00022044632405311405!
# Avg loss: 0.00021628781698306435!
# Avg loss: 0.00021514728548841807!
# Avg loss: 0.00021530991654818385!
# Avg loss: 0.00021577559968363858!
# Avg loss: 0.00021174570109072494!
# Avg loss: 0.0002149785133868439!
# Avg loss: 0.00021430781972033705!
# Avg loss: 0.0002095342025924888!
# Avg loss: 0.00021177330858051846!
# Avg loss: 0.0002103817325639549!
# Avg loss: 0.00020619863871312798!
# Avg loss: 0.00020583085468539746!
# Avg loss: 0.0002066905394766157!
# Avg loss: 0.000209667700178026!
# Avg loss: 0.00020695622362344087!
# Avg loss: 0.0002030207900635735!
# Avg loss: 0.0002013297414687069!
# Avg loss: 0.0002007880987586456!
# Avg loss: 0.0002037764537840303!
# Avg loss: 0.0002053369725471536!
# Avg loss: 0.00020361959952348721!
# Avg loss: 0.00020465420796142553!
# Avg loss: 0.00020155640013446902!
# Avg loss: 0.00019818066085633746!
# Avg loss: 0.0002014833924776364!
# Avg loss: 0.00020156515921134619!
# Avg loss: 0.00020091571647355976!
# Avg loss: 0.00019989238075159696!
# Avg loss: 0.0002001363183603644!
# Avg loss: 0.00020438978275005108!
# Avg loss: 0.0002037670912354391!
# Avg loss: 0.00020123410204424394!
# Avg loss: 0.0002031360289448969!
# Avg loss: 0.0002029678021150024!
# ------------------------------
# client: 2
# Avg loss: 0.026282244947797153!
# Avg loss: 0.02542995947757542!
# Avg loss: 0.022911779479666924!
# Avg loss: 0.019567338872050945!
# Avg loss: 0.017435719182467436!
# Avg loss: 0.01562377636486417!
# Avg loss: 0.01430712722869733!
# Avg loss: 0.01341844987621054!
# Avg loss: 0.01227077478585367!
# Avg loss: 0.011294932807832083!
# Avg loss: 0.010873580036362303!
# Avg loss: 0.010575759641821302!
# Avg loss: 0.010177472453948818!
# Avg loss: 0.009775993815862118!
# Avg loss: 0.009516772354824449!
# Avg loss: 0.009331914652423924!
# Avg loss: 0.009180391254229031!
# Avg loss: 0.009072960989710737!
# Avg loss: 0.008972608406795644!
# Avg loss: 0.008863795592113395!
# Avg loss: 0.008758385973311912!
# Avg loss: 0.008684174430438058!
# Avg loss: 0.00863243406921318!
# Avg loss: 0.00859076512381383!
# Avg loss: 0.008566135519691518!
# Avg loss: 0.008546135460249692!
# Avg loss: 0.008512647714974264!
# Avg loss: 0.008491869213694372!
# Avg loss: 0.008475474200968164!
# Avg loss: 0.00847064970855854!
# Avg loss: 0.00845765846262566!
# Avg loss: 0.008445574143003114!
# Avg loss: 0.008449667175596006!
# Avg loss: 0.008456207937462447!
# Avg loss: 0.008447178114033704!
# Avg loss: 0.008440003962485131!
# Avg loss: 0.008438402803661992!
# Avg loss: 0.008441900949164657!
# Avg loss: 0.008439219998835578!
# Avg loss: 0.008432346482738542!
# Avg loss: 0.008426545513920776!
# Avg loss: 0.008426032715676683!
# Avg loss: 0.008426669672463352!
# Avg loss: 0.008423972012060025!
# Avg loss: 0.008420249255453123!
# Avg loss: 0.008417288191592813!
# Avg loss: 0.008418191165663226!
# Avg loss: 0.008414571710655612!
# Avg loss: 0.008410801236742978!
# Avg loss: 0.008407417813015551!
# Avg loss: 0.008405877285733065!
# Avg loss: 0.008404667051648478!
# Avg loss: 0.008404533832976995!
# Avg loss: 0.008402081462994981!
# Avg loss: 0.008397491791445949!
# Avg loss: 0.008394895535661816!
# Avg loss: 0.008395789501355845!
# Avg loss: 0.00839209768316247!
# Avg loss: 0.008389048568410544!
# Avg loss: 0.00838670494558831!
# Avg loss: 0.008387385975706253!
# Avg loss: 0.008386771864876437!
# Avg loss: 0.008388088130928584!
# Avg loss: 0.008382866747883782!
# Avg loss: 0.008382306330235754!
# Avg loss: 0.00838049727008221!
# Avg loss: 0.008379816357617831!
# Avg loss: 0.008377887504119599!
# Avg loss: 0.008378090898797836!
# Avg loss: 0.008378437856515574!
# Avg loss: 0.008378280972036124!
# Avg loss: 0.008374702417866425!
# Avg loss: 0.008376740119255904!
# Avg loss: 0.00837586478417696!
# Avg loss: 0.00838031058059073!
# Avg loss: 0.008372997551677296!
# Avg loss: 0.008376480266736432!
# Avg loss: 0.008375427994256484!
# Avg loss: 0.008378412539659432!
# Avg loss: 0.008376863663657445!
# Avg loss: 0.00837753521170498!
# Avg loss: 0.008375984533640045!
# Avg loss: 0.008380512050543416!
# Avg loss: 0.008374783218005935!
# Avg loss: 0.008376701697679134!
# Avg loss: 0.008373491545265399!

# %%
train_log = {}
test_log = {}

# %%
train_log["Droput"] = train_loss_list
test_log["Droput"] = test_avg_list

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_loss_curves_and_statistics(loss_list):
    """
    绘制loss曲线和统计信息图像。

    参数:
    loss_list (list of list of float): 每个元素是一个模型在每个epoch的loss列表。
    """
    # 绘制每个模型的loss曲线
    plt.figure(figsize=(10, 6))
    for idx, loss in enumerate(loss_list):
        plt.plot(loss, label=f'Model {idx+1}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    # 计算每个模型最后一个epoch的loss值
    last_epoch_losses = [loss[-1] for loss in loss_list]

    # 计算最后一个epoch的平均值和方差
    mean_last_epoch_loss = np.mean(last_epoch_losses)
    std_last_epoch_loss = np.std(last_epoch_losses)

    # 绘制最后一个epoch的loss值，平均值和方差
    plt.figure(figsize=(10, 6))
    plt.plot(last_epoch_losses, 'o-', label='Last Epoch Loss')
    plt.axhline(mean_last_epoch_loss, color='r', linestyle='--', label=f'Mean: {mean_last_epoch_loss:.2f}')
    plt.fill_between(range(len(last_epoch_losses)), mean_last_epoch_loss - std_last_epoch_loss, mean_last_epoch_loss + std_last_epoch_loss, color='r', alpha=0.2, label=f'Std Dev: {std_last_epoch_loss:.2f}')
    plt.xlabel('Model Index')
    plt.ylabel('Loss')
    plt.title('Last Epoch Losses with Mean and Std Dev')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_loss_curves_and_statistics(train_loss_list)

# %%
plot_loss_curves_and_statistics(test_avg_list)

# %%
def evaluate_clients_models(clients, device='cuda' if torch.cuda.is_available() else 'cpu'):
    evaluation_results = {i: [] for i in range(len(clients))}

    for i, client in enumerate(clients):
        client.model.to(device)  # 将模型移动到指定设备
        for j, other_client in enumerate(clients):
            inputs = other_client.dataset_X.astype(np.float32).values
            labels = other_client.dataset_y.astype(np.float32).values
            
            inputs = torch.tensor(inputs).to(device)
            labels = torch.tensor(labels).to(device)

            with torch.no_grad():
                outputs = client.model(inputs)
                loss = mean_squared_error(outputs.cpu().numpy(), labels.cpu().numpy())  # 将张量移回 CPU 进行计算

            evaluation_results[i].append(loss)
            print(f"Client {i} evaluated on Client {j}'s data - MSE Loss: {loss:.4f}")

    return evaluation_results

# %%
evaluation_results = evaluate_clients_models(Clients)
# Out:
# Client 0 evaluated on Client 0's data - MSE Loss: 0.0015
# Client 0 evaluated on Client 1's data - MSE Loss: 0.0063
# Client 0 evaluated on Client 2's data - MSE Loss: 0.0126
# Client 1 evaluated on Client 0's data - MSE Loss: 0.0021
# Client 1 evaluated on Client 1's data - MSE Loss: 0.0030
# Client 1 evaluated on Client 2's data - MSE Loss: 0.0063
# Client 2 evaluated on Client 0's data - MSE Loss: 0.0038
# Client 2 evaluated on Client 1's data - MSE Loss: 0.0050
# Client 2 evaluated on Client 2's data - MSE Loss: 0.0037

# %%
Clients[1].dataset_X
# Out:
#             0         1         2        actions
# 0   -0.915650 -0.401976  0.270737    [1.9583638]
# 1   -0.910285 -0.413982  0.263009    [1.3503298]
# 2   -0.907048 -0.421028  0.155072          [2.0]
# 3   -0.904093 -0.427335  0.139301          [2.0]
# 4   -0.901539 -0.432698  0.118800    [1.0185691]
# ..        ...       ...       ...            ...
# 494  0.999848 -0.017439 -0.009609    [1.1253121]
# 495  0.999949 -0.010135  0.146108  [-0.87655824]
# 496  0.999952 -0.009784  0.007023  [-0.44934645]
# 497  0.999913 -0.013169 -0.067716    [1.5312085]
# 498  0.999985 -0.005565  0.152088  [-0.49040866]
#
# [499 rows x 4 columns]
