# %%
from Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
env = PendulumEnv()
env = TimeLimit(env, max_episode_steps=200)

# %%
from sb3_contrib import TRPO

# %%
TRPO_model = TRPO("MlpPolicy", env=env, verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TRPO_model.learn(200000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    fps             | 521      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -272     |
# | time/                     |          |
# |    fps                    | 496      |
# |    iterations             | 2        |
# |    time_elapsed           | 8        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.912    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00737  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 50       |
# |    policy_objective       | 0.0233   |
# |    std                    | 0.74     |
# |    value_loss             | 199      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -237     |
# | time/                     |          |
# |    fps                    | 487      |
# |    iterations             | 3        |
# |    time_elapsed           | 12       |
# |    total_timesteps        | 6144     |
# | train/                    |          |
# |    explained_variance     | 0.935    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00759  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 51       |
# |    policy_objective       | 0.0233   |
# |    std                    | 0.726    |
# |    value_loss             | 312      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -234     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 4        |
# |    time_elapsed           | 17       |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.939    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00839  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 52       |
# |    policy_objective       | 0.0566   |
# |    std                    | 0.726    |
# |    value_loss             | 108      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -261     |
# | time/                     |          |
# |    fps                    | 463      |
# |    iterations             | 5        |
# |    time_elapsed           | 22       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 0.96     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00805  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 53       |
# |    policy_objective       | 0.0253   |
# |    std                    | 0.713    |
# |    value_loss             | 77.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -260     |
# | time/                     |          |
# |    fps                    | 443      |
# |    iterations             | 6        |
# |    time_elapsed           | 27       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 0.915    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00784  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 54       |
# |    policy_objective       | 0.0228   |
# |    std                    | 0.704    |
# |    value_loss             | 252      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -253     |
# | time/                     |          |
# |    fps                    | 439      |
# |    iterations             | 7        |
# |    time_elapsed           | 32       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 0.949    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00777  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 55       |
# |    policy_objective       | 0.0216   |
# |    std                    | 0.679    |
# |    value_loss             | 131      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -243     |
# | time/                     |          |
# |    fps                    | 443      |
# |    iterations             | 8        |
# |    time_elapsed           | 36       |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 0.939    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00801  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 56       |
# |    policy_objective       | 0.0189   |
# |    std                    | 0.674    |
# |    value_loss             | 130      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -250     |
# | time/                     |          |
# |    fps                    | 446      |
# |    iterations             | 9        |
# |    time_elapsed           | 41       |
# |    total_timesteps        | 18432    |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00652  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 57       |
# |    policy_objective       | 0.0126   |
# |    std                    | 0.673    |
# |    value_loss             | 47.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -258     |
# | time/                     |          |
# |    fps                    | 432      |
# |    iterations             | 10       |
# |    time_elapsed           | 47       |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 0.972    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00717  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 58       |
# |    policy_objective       | 0.0143   |
# |    std                    | 0.671    |
# |    value_loss             | 242      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -262     |
# | time/                     |          |
# |    fps                    | 424      |
# |    iterations             | 11       |
# |    time_elapsed           | 53       |
# |    total_timesteps        | 22528    |
# | train/                    |          |
# |    explained_variance     | 0.902    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00749  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 59       |
# |    policy_objective       | 0.0149   |
# |    std                    | 0.665    |
# |    value_loss             | 231      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -248     |
# | time/                     |          |
# |    fps                    | 422      |
# |    iterations             | 12       |
# |    time_elapsed           | 58       |
# |    total_timesteps        | 24576    |
# | train/                    |          |
# |    explained_variance     | 0.892    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00779  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 60       |
# |    policy_objective       | 0.0244   |
# |    std                    | 0.68     |
# |    value_loss             | 205      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -273     |
# | time/                     |          |
# |    fps                    | 419      |
# |    iterations             | 13       |
# |    time_elapsed           | 63       |
# |    total_timesteps        | 26624    |
# | train/                    |          |
# |    explained_variance     | 0.939    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00935  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 61       |
# |    policy_objective       | 0.0346   |
# |    std                    | 0.673    |
# |    value_loss             | 37.1     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -279     |
# | time/                     |          |
# |    fps                    | 407      |
# |    iterations             | 14       |
# |    time_elapsed           | 70       |
# |    total_timesteps        | 28672    |
# | train/                    |          |
# |    explained_variance     | 0.821    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00826  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 62       |
# |    policy_objective       | 0.0142   |
# |    std                    | 0.672    |
# |    value_loss             | 423      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -267     |
# | time/                     |          |
# |    fps                    | 403      |
# |    iterations             | 15       |
# |    time_elapsed           | 76       |
# |    total_timesteps        | 30720    |
# | train/                    |          |
# |    explained_variance     | 0.925    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00796  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 63       |
# |    policy_objective       | 0.0328   |
# |    std                    | 0.674    |
# |    value_loss             | 324      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -276     |
# | time/                     |          |
# |    fps                    | 397      |
# |    iterations             | 16       |
# |    time_elapsed           | 82       |
# |    total_timesteps        | 32768    |
# | train/                    |          |
# |    explained_variance     | 0.95     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00721  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 64       |
# |    policy_objective       | 0.0228   |
# |    std                    | 0.654    |
# |    value_loss             | 118      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -290     |
# | time/                     |          |
# |    fps                    | 392      |
# |    iterations             | 17       |
# |    time_elapsed           | 88       |
# |    total_timesteps        | 34816    |
# | train/                    |          |
# |    explained_variance     | 0.976    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00925  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 65       |
# |    policy_objective       | 0.0204   |
# |    std                    | 0.643    |
# |    value_loss             | 239      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -293     |
# | time/                     |          |
# |    fps                    | 389      |
# |    iterations             | 18       |
# |    time_elapsed           | 94       |
# |    total_timesteps        | 36864    |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00728  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 66       |
# |    policy_objective       | 0.0203   |
# |    std                    | 0.643    |
# |    value_loss             | 162      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -280     |
# | time/                     |          |
# |    fps                    | 388      |
# |    iterations             | 19       |
# |    time_elapsed           | 100      |
# |    total_timesteps        | 38912    |
# | train/                    |          |
# |    explained_variance     | 0.984    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00675  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 67       |
# |    policy_objective       | 0.0175   |
# |    std                    | 0.637    |
# |    value_loss             | 50.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -252     |
# | time/                     |          |
# |    fps                    | 390      |
# |    iterations             | 20       |
# |    time_elapsed           | 104      |
# |    total_timesteps        | 40960    |
# | train/                    |          |
# |    explained_variance     | 0.984    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00798  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 68       |
# |    policy_objective       | 0.0412   |
# |    std                    | 0.637    |
# |    value_loss             | 25.3     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -265     |
# | time/                     |          |
# |    fps                    | 391      |
# |    iterations             | 21       |
# |    time_elapsed           | 109      |
# |    total_timesteps        | 43008    |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0064   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 69       |
# |    policy_objective       | 0.0297   |
# |    std                    | 0.633    |
# |    value_loss             | 18.8     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -282     |
# | time/                     |          |
# |    fps                    | 390      |
# |    iterations             | 22       |
# |    time_elapsed           | 115      |
# |    total_timesteps        | 45056    |
# | train/                    |          |
# |    explained_variance     | 0.911    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00622  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 70       |
# |    policy_objective       | 0.0128   |
# |    std                    | 0.634    |
# |    value_loss             | 185      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -251     |
# | time/                     |          |
# |    fps                    | 389      |
# |    iterations             | 23       |
# |    time_elapsed           | 120      |
# |    total_timesteps        | 47104    |
# | train/                    |          |
# |    explained_variance     | 0.915    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00766  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 71       |
# |    policy_objective       | 0.0185   |
# |    std                    | 0.64     |
# |    value_loss             | 275      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -252     |
# | time/                     |          |
# |    fps                    | 387      |
# |    iterations             | 24       |
# |    time_elapsed           | 126      |
# |    total_timesteps        | 49152    |
# | train/                    |          |
# |    explained_variance     | 0.958    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00587  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 72       |
# |    policy_objective       | 0.0173   |
# |    std                    | 0.645    |
# |    value_loss             | 36.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -245     |
# | time/                     |          |
# |    fps                    | 386      |
# |    iterations             | 25       |
# |    time_elapsed           | 132      |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 0.858    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00623  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 73       |
# |    policy_objective       | 0.0201   |
# |    std                    | 0.632    |
# |    value_loss             | 126      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -225     |
# | time/                     |          |
# |    fps                    | 384      |
# |    iterations             | 26       |
# |    time_elapsed           | 138      |
# |    total_timesteps        | 53248    |
# | train/                    |          |
# |    explained_variance     | 0.951    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00638  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 74       |
# |    policy_objective       | 0.017    |
# |    std                    | 0.635    |
# |    value_loss             | 32.7     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -206     |
# | time/                     |          |
# |    fps                    | 381      |
# |    iterations             | 27       |
# |    time_elapsed           | 145      |
# |    total_timesteps        | 55296    |
# | train/                    |          |
# |    explained_variance     | 0.963    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00792  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 75       |
# |    policy_objective       | 0.0236   |
# |    std                    | 0.636    |
# |    value_loss             | 45.7     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -215     |
# | time/                     |          |
# |    fps                    | 380      |
# |    iterations             | 28       |
# |    time_elapsed           | 150      |
# |    total_timesteps        | 57344    |
# | train/                    |          |
# |    explained_variance     | 0.91     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00877  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 76       |
# |    policy_objective       | 0.0261   |
# |    std                    | 0.628    |
# |    value_loss             | 49       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -210     |
# | time/                     |          |
# |    fps                    | 379      |
# |    iterations             | 29       |
# |    time_elapsed           | 156      |
# |    total_timesteps        | 59392    |
# | train/                    |          |
# |    explained_variance     | 0.97     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00585  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 77       |
# |    policy_objective       | 0.0218   |
# |    std                    | 0.625    |
# |    value_loss             | 85.7     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -207     |
# | time/                     |          |
# |    fps                    | 378      |
# |    iterations             | 30       |
# |    time_elapsed           | 162      |
# |    total_timesteps        | 61440    |
# | train/                    |          |
# |    explained_variance     | 0.96     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00772  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 78       |
# |    policy_objective       | 0.0318   |
# |    std                    | 0.626    |
# |    value_loss             | 15.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -188     |
# | time/                     |          |
# |    fps                    | 379      |
# |    iterations             | 31       |
# |    time_elapsed           | 167      |
# |    total_timesteps        | 63488    |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0097   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 79       |
# |    policy_objective       | 0.0207   |
# |    std                    | 0.626    |
# |    value_loss             | 10.1     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -173     |
# | time/                     |          |
# |    fps                    | 377      |
# |    iterations             | 32       |
# |    time_elapsed           | 173      |
# |    total_timesteps        | 65536    |
# | train/                    |          |
# |    explained_variance     | 0.982    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0068   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 80       |
# |    policy_objective       | 0.0156   |
# |    std                    | 0.628    |
# |    value_loss             | 6.14     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 376      |
# |    iterations             | 33       |
# |    time_elapsed           | 179      |
# |    total_timesteps        | 67584    |
# | train/                    |          |
# |    explained_variance     | 0.991    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00719  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 81       |
# |    policy_objective       | 0.0153   |
# |    std                    | 0.633    |
# |    value_loss             | 12.3     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 375      |
# |    iterations             | 34       |
# |    time_elapsed           | 185      |
# |    total_timesteps        | 69632    |
# | train/                    |          |
# |    explained_variance     | 0.996    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0055   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 82       |
# |    policy_objective       | 0.0188   |
# |    std                    | 0.633    |
# |    value_loss             | 6.45     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 35       |
# |    time_elapsed           | 192      |
# |    total_timesteps        | 71680    |
# | train/                    |          |
# |    explained_variance     | 0.98     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00763  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 83       |
# |    policy_objective       | 0.0305   |
# |    std                    | 0.627    |
# |    value_loss             | 26.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -174     |
# | time/                     |          |
# |    fps                    | 371      |
# |    iterations             | 36       |
# |    time_elapsed           | 198      |
# |    total_timesteps        | 73728    |
# | train/                    |          |
# |    explained_variance     | 0.963    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00733  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 84       |
# |    policy_objective       | 0.0221   |
# |    std                    | 0.624    |
# |    value_loss             | 38       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -161     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 37       |
# |    time_elapsed           | 204      |
# |    total_timesteps        | 75776    |
# | train/                    |          |
# |    explained_variance     | 0.98     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00757  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 85       |
# |    policy_objective       | 0.0299   |
# |    std                    | 0.621    |
# |    value_loss             | 11.7     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -165     |
# | time/                     |          |
# |    fps                    | 369      |
# |    iterations             | 38       |
# |    time_elapsed           | 210      |
# |    total_timesteps        | 77824    |
# | train/                    |          |
# |    explained_variance     | 0.951    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00671  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 86       |
# |    policy_objective       | 0.0253   |
# |    std                    | 0.614    |
# |    value_loss             | 39.2     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -167     |
# | time/                     |          |
# |    fps                    | 368      |
# |    iterations             | 39       |
# |    time_elapsed           | 216      |
# |    total_timesteps        | 79872    |
# | train/                    |          |
# |    explained_variance     | 0.991    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00786  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 87       |
# |    policy_objective       | 0.0225   |
# |    std                    | 0.606    |
# |    value_loss             | 9.45     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -177     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 40       |
# |    time_elapsed           | 222      |
# |    total_timesteps        | 81920    |
# | train/                    |          |
# |    explained_variance     | 0.984    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00884  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 88       |
# |    policy_objective       | 0.0251   |
# |    std                    | 0.604    |
# |    value_loss             | 11.4     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -190     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 41       |
# |    time_elapsed           | 228      |
# |    total_timesteps        | 83968    |
# | train/                    |          |
# |    explained_variance     | 0.993    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0072   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 89       |
# |    policy_objective       | 0.028    |
# |    std                    | 0.599    |
# |    value_loss             | 10.4     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -187     |
# | time/                     |          |
# |    fps                    | 368      |
# |    iterations             | 42       |
# |    time_elapsed           | 233      |
# |    total_timesteps        | 86016    |
# | train/                    |          |
# |    explained_variance     | 0.996    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00727  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 90       |
# |    policy_objective       | 0.0208   |
# |    std                    | 0.589    |
# |    value_loss             | 7.26     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -190     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 43       |
# |    time_elapsed           | 239      |
# |    total_timesteps        | 88064    |
# | train/                    |          |
# |    explained_variance     | 0.991    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00712  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 91       |
# |    policy_objective       | 0.0211   |
# |    std                    | 0.579    |
# |    value_loss             | 4.38     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -190     |
# | time/                     |          |
# |    fps                    | 368      |
# |    iterations             | 44       |
# |    time_elapsed           | 244      |
# |    total_timesteps        | 90112    |
# | train/                    |          |
# |    explained_variance     | 0.995    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.007    |
# |    learning_rate          | 0.001    |
# |    n_updates              | 92       |
# |    policy_objective       | 0.0195   |
# |    std                    | 0.56     |
# |    value_loss             | 9.41     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -184     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 45       |
# |    time_elapsed           | 250      |
# |    total_timesteps        | 92160    |
# | train/                    |          |
# |    explained_variance     | 0.995    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00648  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 93       |
# |    policy_objective       | 0.0261   |
# |    std                    | 0.551    |
# |    value_loss             | 5.55     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -193     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 46       |
# |    time_elapsed           | 256      |
# |    total_timesteps        | 94208    |
# | train/                    |          |
# |    explained_variance     | 0.989    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00776  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 94       |
# |    policy_objective       | 0.0241   |
# |    std                    | 0.556    |
# |    value_loss             | 3.04     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -196     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 47       |
# |    time_elapsed           | 261      |
# |    total_timesteps        | 96256    |
# | train/                    |          |
# |    explained_variance     | 0.981    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00914  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 95       |
# |    policy_objective       | 0.0311   |
# |    std                    | 0.554    |
# |    value_loss             | 29.3     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -197     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 48       |
# |    time_elapsed           | 267      |
# |    total_timesteps        | 98304    |
# | train/                    |          |
# |    explained_variance     | 0.994    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00801  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 96       |
# |    policy_objective       | 0.0206   |
# |    std                    | 0.552    |
# |    value_loss             | 3.88     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -193     |
# | time/                     |          |
# |    fps                    | 368      |
# |    iterations             | 49       |
# |    time_elapsed           | 272      |
# |    total_timesteps        | 100352   |
# | train/                    |          |
# |    explained_variance     | 0.989    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00777  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 97       |
# |    policy_objective       | 0.0394   |
# |    std                    | 0.558    |
# |    value_loss             | 7.23     |
# ----------------------------------------

# %%
TRPO_model.save("models/TRPO_200k")

# %%
from Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

env = PendulumEnv()
env = TimeLimit(env, max_episode_steps=200)

# %%
from sb3_contrib import TRPO
TRPO_model = TRPO.load("models/TRPO_200k.zip", env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
from sb3_contrib import TRPO
from Client_diff_Dropout import FRLClient
from Agent import SB3Agent
import copy
from stable_baselines3.common.evaluation import evaluate_policy
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
train_log = {}
test_log = {}

# %%
timesteps_real_per_round = 500
timesteps_fc_per_round = timesteps_real_per_round * 30
epoch_per_round = 100
CLIENTS_NUM = 5
rounds_num = 20
batch_size_env_model = 128

env_models = []

Global_RL = TRPO_model

env_theta = [0.1, 0.3, 0.5, 0.7, 0.9]
real_envs = []
Clients = []
for i in range(CLIENTS_NUM):
    real_envs.append( TimeLimit(PendulumEnv(), max_episode_steps=200) )
    policy_net = Global_RL
    agent = SB3Agent(policy_net)
    client = FRLClient(real_envs[i], agent, lr = 3e-4, hidden_size = 256, device = device)
    Clients.append(client)
    env_model = copy.deepcopy(client.model)
    env_models.append(env_model)

    
train_loss_list = []
test_avg_list = []

for client_idx in range(len(Clients)):
    print('------------------------------')
    print("client: " + str(client_idx))
    # update policy
    # train prediction models
    Clients[client_idx].learn(timesteps_real_per_round, epoch_per_round, batch_size_env_model)
     #
    train_loss_list.append(Clients[client_idx].train_loss_list)
    test_avg_list.append(Clients[client_idx].test_avg_list)
# Out:
# ------------------------------
# client: 0
# Avg loss: 0.028937024446058786!
# Avg loss: 0.028823216592912405!
# Avg loss: 0.027956936258027174!
# Avg loss: 0.02506009914310804!
# Avg loss: 0.023430145450499065!
# Avg loss: 0.022898096846377787!
# Avg loss: 0.02220964148834658!
# Avg loss: 0.020931826995996137!
# Avg loss: 0.019501799592496052!
# Avg loss: 0.018365832081520542!

# %%
train_log["Droput"] = train_loss_list

# %%
train_log["Droput"]
# Out:
# [[0.0796382598002524,
#   0.0572470675908392,
#   0.059868148541382185,
#   0.058853451365386174,
#   0.048217550048172304,
#   0.04944240192970779,
#   0.04521475685360097,
#   0.04184090988683837,
#   0.0388406586851978,
#   0.039875135039190164,
#   0.03534503652578097,
#   0.03354495029394811,
#   0.03537317538329728,
#   0.03192451416933775,
#   0.03234397989289467,
#   0.023782265562041098,
#   0.027432150690466763,
#   0.027965860585428583,
#   0.02923224033803858,
#   0.0311071305698515,
#   0.025594771420716558,
#   0.020898430941781204,
#   0.02505527116507719,
#   0.02739421105316512,
#   0.02353651749028859,
#   0.022059008521815086,
#   0.019931193067556124,
#   0.021458601883284342,
#   0.02058717753620749,
#   0.02188623771284918,
#   0.02366658268138809,
#   0.01574068834583534,
#   0.020644972864058093,
#   0.018700345881005755,
#   0.018071157542887253,
#   0.01719268311060602,
#   0.01856653225797637,
#   0.020718375044770775,
#   0.017823540720352127,
#   0.018034067741437763,
#   0.017675121397548555,
#   0.018020003777861938,
#   0.015536236558056152,
#   0.019623081458673777,
#   0.015951312715481208,
#   0.014479246727033468,
#   0.015094509439003843,
#   0.015505217207878572,
#   0.016140947027670962,
#   0.015418630274797238,
#   0.014304528263715071,
#   0.014903698063169988,
#   0.013566155488306609,
#   0.013761955209311236,
#   0.014834590661833142,
#   0.012464670704565622,
#   0.012559548660813909,
#   0.012864970033694816,
#   0.013002550704431397,
#   0.014440595932881266,
#   0.012644344551173869,
#   0.012977539980650632,
#   0.013109783046908229,
#   0.013088623910373808,
#   0.014629352741733322,
#   0.011438483153509888,
#   0.011768181207870003,
#   0.013875149724135085,
#   0.011006617102035479,
#   0.012838507450070969,
#   0.010811522047977393,
#   0.012099153503647507,
#   0.013612739336183215]]
