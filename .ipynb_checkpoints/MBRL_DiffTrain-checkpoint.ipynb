# %%
from Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
env = PendulumEnv()
env = TimeLimit(env, max_episode_steps=200)

# %%
env.reset()
# Out:
# (array([-0.9434946, -0.3313878, -0.5660853], dtype=float32), {})

# %%
from stable_baselines3 import PPO
import torch

# %%
from MBEnvs.mb_pendulum2 import MB_PendulumEnv
env_models = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

MB_env = MB_PendulumEnv(env_models, device)

# %%
Global_RL = PPO("MlpPolicy", MB_env)

# %%
agent_sb3 = SB3Agent(policy_net=Global_RL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 agent_sb3 = SB3Agent(policy_net=Global_RL)
#
# NameError: name 'SB3Agent' is not defined

# %%
test_client = FRLClient(env=env,agent=agent_sb3, lr=0.0001, hidden_size= 256, device=device)

# %%
test_client.sample_data(100)

# %%
test_client.dataset_X

# %%
test_client.dataset_y

# %%
device
# Out:
# device(type='cuda')

# %%
from sb3_contrib import TRPO
from Client_diff import FRLClient
from Agent import SB3Agent
import copy
from stable_baselines3.common.evaluation import evaluate_policy
import torch

# %%
from Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit
from MBEnvs.mb_pendulum2 import MB_PendulumEnv

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# initialize the client and server
timesteps_real_per_round = 500
timesteps_fc_per_round = timesteps_real_per_round * 30
epoch_per_round = 100
CLIENTS_NUM = 3
rounds_num = 30
batch_size_env_model = 128

test_dir = "Diff_test1"
model_tmp_path = test_dir + "/models/tmp"

env_models = []
MB_env = TimeLimit(MB_PendulumEnv(env_models,device), max_episode_steps = 200)

# Global_RL = PPO("MlpPolicy", MB_env, verbose=1)
Global_RL = TRPO("MlpPolicy", MB_env, verbose=1)

env_theta = [0.1, 0.3, 0.5, 0.7, 0.9]
real_envs = []
Clients = []
for i in range(CLIENTS_NUM):
    real_envs.append( TimeLimit(PendulumEnv(), max_episode_steps=200) )
    policy_net = Global_RL
    agent = SB3Agent(policy_net)
    client = FRLClient(real_envs[i], agent, lr = 3e-4, hidden_size = 256, device = device)
    Clients.append(client)
    env_model = copy.deepcopy(client.model)
    env_models.append(env_model)
    

    
Global_RL.env.models = env_models

Global_RL.save(test_dir+'/models/tmp')

rewards_log = []

env_models = []
for round_idx in range(rounds_num):
    print('------------------------------')
    print("round: " + str(round_idx))
    for client_idx in range(len(Clients)):
        print('------------------------------')
        print("client: " + str(client_idx))
        # update policy
        Clients[client_idx].agent.policy_net = Global_RL
        # train prediction models
        Clients[client_idx].learn(timesteps_real_per_round, epoch_per_round, batch_size_env_model)
        #
        env_model = Clients[client_idx].get_prediction_model()
        env_models.append(env_model)
    
#     Server.update_env_models(env_models)

    MB_env = TimeLimit(MB_PendulumEnv(env_models,device), max_episode_steps = 200)
    
    Global_RL = TRPO.load("models/tmp.zip", env = MB_env)
#     Global_RL.env.models = env_models
    #
    Global_RL.learn(total_timesteps=timesteps_fc_per_round)
    
    Global_RL.save(f'models/tmp')
#     Server.learn(timesteps_real_per_round = 10000)
    # test performance
    mean_reward, std_reward = evaluate_policy(Global_RL, real_envs[1], n_eval_episodes=10)
    rewards_log.append(mean_reward)
    print("mean_reward in real env:" + str(mean_reward))
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------
# Avg loss: 0.00011078601233407425!
# Avg loss: 0.00010744112405940124!
# Avg loss: 0.00011084271062325494!
# Avg loss: 0.00010389754373553236!
# Avg loss: 0.0001150264656855408!
# Avg loss: 0.00010561915415394196!
# Avg loss: 0.00012149834337549237!
# Avg loss: 0.00010714077497444426!
# Avg loss: 0.0001456889617353833!
# Avg loss: 0.00013116981557080484!
# Avg loss: 0.00022731744188301186!
# Avg loss: 0.00022424998295415813!
# Avg loss: 0.00043641298279302037!
# Avg loss: 0.00045871747880786036!
# ------------------------------
# client: 2
# Avg loss: 0.0013528118113754317!
# Avg loss: 0.00036354566011141285!
# Avg loss: 0.0007774292986869113!
# Avg loss: 0.00046284446007727333!
# Avg loss: 0.0004466491660483977!
# Avg loss: 0.00022267465837709702!
# Avg loss: 0.00022356471916888646!
# Avg loss: 0.00031999218750570433!
# Avg loss: 0.0002584245193126359!
# Avg loss: 0.00019757886822693158!
# Avg loss: 0.00016028256862379446!
# Avg loss: 0.000213675848293254!
# Avg loss: 0.0001921634567311988!
# Avg loss: 0.00018430372324246491!
# Avg loss: 0.0001999027685405963!
# Avg loss: 0.00017916077974457304!
# Avg loss: 0.0001901176284854955!
# Avg loss: 0.00018786774058412447!
# Avg loss: 0.0001757062921344262!
# Avg loss: 0.00017484767853432004!
# Avg loss: 0.0001827377293417006!
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -297     |
# | time/              |          |
# |    fps             | 362      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -372     |
# | time/                     |          |
# |    fps                    | 348      |
# |    iterations             | 2        |
# |    time_elapsed           | 11       |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.923    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00811  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 169      |
# |    policy_objective       | 0.0166   |
# |    std                    | 0.549    |
# |    value_loss             | 419      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -374     |
# | time/                     |          |
# |    fps                    | 333      |
# |    iterations             | 3        |
# |    time_elapsed           | 18       |
# |    total_timesteps        | 6144     |
# | train/                    |          |
# |    explained_variance     | 0.928    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00791  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 170      |
# |    policy_objective       | 0.0181   |
# |    std                    | 0.563    |
# |    value_loss             | 632      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -340     |
# | time/                     |          |
# |    fps                    | 331      |
# |    iterations             | 4        |
# |    time_elapsed           | 24       |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.922    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00618  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 171      |
# |    policy_objective       | 0.0151   |
# |    std                    | 0.561    |
# |    value_loss             | 511      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -317     |
# | time/                     |          |
# |    fps                    | 335      |
# |    iterations             | 5        |
# |    time_elapsed           | 30       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 0.932    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00645  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 172      |
# |    policy_objective       | 0.0186   |
# |    std                    | 0.554    |
# |    value_loss             | 290      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -332     |
# | time/                     |          |
# |    fps                    | 342      |
# |    iterations             | 6        |
# |    time_elapsed           | 35       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 0.93     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0049   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 173      |
# |    policy_objective       | 0.0108   |
# |    std                    | 0.539    |
# |    value_loss             | 326      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -340     |
# | time/                     |          |
# |    fps                    | 334      |
# |    iterations             | 7        |
# |    time_elapsed           | 42       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 0.905    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00857  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 174      |
# |    policy_objective       | 0.0135   |
# |    std                    | 0.55     |
# |    value_loss             | 836      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -368     |
# | time/                     |          |
# |    fps                    | 334      |
# |    iterations             | 8        |
# |    time_elapsed           | 49       |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 0.944    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00712  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 175      |
# |    policy_objective       | 0.0194   |
# |    std                    | 0.553    |
# |    value_loss             | 420      |
# ----------------------------------------
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward in real env:-322.57824533195674
# ------------------------------
# round: 2
# ------------------------------
# client: 0
# Avg loss: 0.001586087491014041!
# Avg loss: 0.0007692032838137189!
# Avg loss: 0.0007054476091313214!
# Avg loss: 0.000521594451298976!
# Avg loss: 0.00033057872644652283!
# Avg loss: 0.0003194691121825599!
# Avg loss: 0.00024402061966611655!
# Avg loss: 0.00021571567974509285!
# Avg loss: 0.0002172894291023416!
# Avg loss: 0.00015131791070416512!
# Avg loss: 0.0002055660224186795!
# Avg loss: 0.00015884560038254374!
# Avg loss: 0.0001631207790939726!
# Avg loss: 0.0001348643843867118!
# Avg loss: 0.00012803385203236908!
# Avg loss: 0.00014617484086519047!
# Avg loss: 0.0001451608749660712!
# Avg loss: 0.0001342386811643337!
# Avg loss: 0.00013010556341631248!
# Avg loss: 0.00013328104219157902!
# Avg loss: 0.00014186437523652746!
# Avg loss: 0.0001393663595584845!
# Avg loss: 0.0001378354675048854!
# Avg loss: 0.00013783142191916417!
# Avg loss: 0.00013855404040109912!
# ------------------------------
# client: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 37>()
#      44 Clients[client_idx].agent.policy_net = Global_RL
#      45 # train prediction models
# ---> 46 Clients[client_idx].learn(timesteps_real_per_round, epoch_per_round, batch_size_env_model)
#      47 #
#      48 env_model = Clients[client_idx].get_prediction_model()
#
# File F:\AI\RL\FedMBRL\Client_diff.py:141, in FRLClient.learn(self, timesteps, epoch, batch_size)
#     138 def learn(self, timesteps = 1000, epoch = 10, batch_size = 32):
#     139   self.sample_data(timesteps)
# --> 141   self.train_prediction_model(timesteps, num_epoch = epoch, batch_size=batch_size)
#
# File F:\AI\RL\FedMBRL\Client_diff.py:96, in FRLClient.train_prediction_model(self, num_data, num_epoch, batch_size)
#      94 # Train the model for a given number of epochs
#      95 for t in range(num_epoch):
# ---> 96     train_loss = model_train(train_X, train_y, self.model, loss_fn, optimizer, batch_size)
#      97     test_avg = model_test(test_X, test_y, self.model, loss_fn, batch_size)
#      98     self.train_loss_list.append(train_loss)
#
# File F:\AI\RL\FedMBRL\Client_diff.py:160, in model_train(X, y, model, loss_fn, optimizer, batch_size)
#     158 # Compute loss for each sample in the batch
#     159 for k in range(min(batch_size, len(train_X))):
# --> 160     pred = model.forward(train_X[k].float())
#     161     loss += loss_fn(pred.to(torch.float32), train_y[k].to(torch.float32))
#     162 loss_sum += loss.item()
#
# File F:\AI\RL\FedMBRL\PredictionModel.py:33, in PredictionModel.forward(self, x)
#      32 def forward(self, x):
# ---> 33     return self.net(x)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\activation.py:101, in ReLU.forward(self, input)
#     100 def forward(self, input: Tensor) -> Tensor:
# --> 101     return F.relu(input, inplace=self.inplace)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\functional.py:1471, in relu(input, inplace)
#    1469     result = torch.relu_(input)
#    1470 else:
# -> 1471     result = torch.relu(input)
#    1472 return result
#
# KeyboardInterrupt:

# %%
print(rewards_log)
# Out:
# [-1038.7943773828447, -1045.9350143310614, -951.3175517857075, -1020.5909036640078, -964.1606939467601, -867.1792511432898, -868.0582246852107, -913.905212187767, -836.2855417923071, -728.9114932481665, -545.917725222162, -155.52740640905904, -264.6216640957631, -140.80942666865036, -170.25116414086224, -141.46617155181667, -205.1278325101186, -141.58884100608412, -154.63558592207227, -128.89181493105426]

# %%
import matplotlib.pyplot as plt

def plot_rewards(rewards, steps_per_round):
    """
    绘制奖励曲线图

    参数:
    rewards (list or array): 每轮的奖励
    steps_per_round (int): 每轮的固定步数
    """
    # 计算每轮的平均奖励
    avg_rewards = [reward / steps_per_round for reward in rewards]

    plt.figure(figsize=(10, 6), dpi=300)
    plt.plot(range(1, len(rewards) + 1), avg_rewards, label='Average Reward per Step')
    plt.xlabel('Round')
    plt.ylabel('Average Reward')
    plt.title('Average Reward per Step Over Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_rewards(rewards_log, 500)

# %%
Global_RL.env.models
# Out:
# [GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  )]

# %%
Global_RL.env.models
# Out:
# [GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  ),
#  GaussianModel(
#    (fc_net): Sequential(
#      (0): Linear(in_features=4, out_features=256, bias=True)
#      (1): ReLU()
#      (2): Linear(in_features=256, out_features=256, bias=True)
#      (3): ReLU()
#    )
#    (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
#  )]

# %%
MB_env.reset()
# Out:
# (array([ 0.25910562, -0.965849  ,  0.49215463], dtype=float32), {})

# %%
MB_env.obs
# Out:
# array([ 0.25910562, -0.965849  ,  0.49215463], dtype=float32)

# %%
MB_env.step(MB_env.action_space.sample())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 MB_env.step(MB_env.action_space.sample())
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File F:\AI\RL\FedMBRL\MBEnvs\mb_pendulum2_gaussian.py:147, in MB_PendulumEnv.step(self, u)
#     144 def step(self, u):
#     145     last_obs = self.obs  # th := theta
# --> 147     reward = self._get_reward(self.obs, u)
#     149     next_obs = self._get_obs_by_model(last_obs, action=u)
#     150     self.obs = next_obs
#
# File F:\AI\RL\FedMBRL\MBEnvs\mb_pendulum2_gaussian.py:210, in MB_PendulumEnv._get_reward(self, obs, action)
#     209 def _get_reward(self, obs, action):
# --> 210     obs1, obs2, thdot = obs
#     211     th = self._recover_theta(obs1, obs2)
#     212     costs = angle_normalize(th) ** 2 + 0.1 * thdot**2 + 0.001 * (action**2)
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
MB_env.obs
# Out:
# array([[ 0.2085361, -0.7650793, -1.1017272]], dtype=float32)

# %%
obs,_ = Clients[0].env.reset()

# %%
obs
# Out:
# array([ 0.43307275,  0.90135896, -0.16240236], dtype=float32)

# %%
action =  Clients[0].agent.act(obs)

# %%
action
# Out:
# array([-0.33290574], dtype=float32)

# %%
Clients[0].model
# Out:
# GaussianModel(
#   (fc_net): Sequential(
#     (0): Linear(in_features=4, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ReLU()
#   )
#   (mean_logvar): Linear(in_features=256, out_features=6, bias=True)
# )

# %%
obs_tensor = torch.tensor(obs, dtype=torch.float32)
action_tensor = torch.tensor(action, dtype=torch.float32)
input_d = torch.cat((obs_tensor, action_tensor))

# %%
input_d
# Out:
# tensor([ 0.4331,  0.9014, -0.1624, -0.3329])

# %%
input_d = input_d.to(device)

# %%
mean, logvar = Clients[0].model.forward(input_d)

# %%
mean, logvar[0]
# Out:
# (tensor([-0.0052, -0.0026,  0.6155], device='cuda:0', grad_fn=<SliceBackward0>),
#  tensor([-3.5161, -2.7553, -2.9714], device='cuda:0', grad_fn=<SelectBackward0>))

# %%
std = torch.exp(0.5 * logvar[0])
std
# Out:
# tensor([0.1724, 0.2522, 0.2263], device='cuda:0', grad_fn=<ExpBackward0>)

# %%
eps = torch.randn_like(std)

# %%
eps
# Out:
# tensor([0.7962, 0.2781, 1.4486], device='cuda:0')

# %%
pred_state_change = mean + eps * std

# %%
pred_state_change
# Out:
# tensor([0.1320, 0.0675, 0.9434], device='cuda:0', grad_fn=<AddBackward0>)

# %%
output_np = pred_state_change.detach().cpu().numpy()

# %%
output_np
# Out:
# array([0.13200563, 0.06751756, 0.94340324], dtype=float32)

# %%
obs
# Out:
# array([ 0.43307275,  0.90135896, -0.16240236], dtype=float32)

# %%
obs_new = obs + output_np

# %%
obs_new
# Out:
# array([0.5650784 , 0.96887654, 0.78100085], dtype=float32)

# %%
import numpy as np

# %%
obs_clipped = np.clip(obs, Clients[0].env.observation_space.low, Clients[0].env.observation_space.high)

# %%
obs_clipped
# Out:
# array([ 0.43307275,  0.90135896, -0.16240236], dtype=float32)

# %%
Clients[0].agent.policy_net.predict(obs)[0]
# Out:
# array([-0.30735433], dtype=float32)

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# mean_reward, std_reward = evaluate_policy(Global_RL, real_envs[1], n_eval_episodes=10)
mean_reward, std_reward = evaluate_policy(Global_RL, MB_env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward} +/- {std_reward}")
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: -93.15121025741101 +/- 109.2765889131137

# %%
from sb3_contrib import TRPO

# %%
TRPO_model = TRPO("MlpPolicy", env=real_envs[0], verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TRPO_model.learn(100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -829     |
# | time/              |          |
# |    fps             | 520      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -847     |
# | time/                     |          |
# |    fps                    | 478      |
# |    iterations             | 2        |
# |    time_elapsed           | 8        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.715    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00696  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 50       |
# |    policy_objective       | 0.0147   |
# |    std                    | 0.809    |
# |    value_loss             | 433      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -893     |
# | time/                     |          |
# |    fps                    | 481      |
# |    iterations             | 3        |
# |    time_elapsed           | 12       |
# |    total_timesteps        | 6144     |
# | train/                    |          |
# |    explained_variance     | 0.749    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00777  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 51       |
# |    policy_objective       | 0.0188   |
# |    std                    | 0.789    |
# |    value_loss             | 629      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -890     |
# | time/                     |          |
# |    fps                    | 470      |
# |    iterations             | 4        |
# |    time_elapsed           | 17       |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.759    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00865  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 52       |
# |    policy_objective       | 0.0126   |
# |    std                    | 0.762    |
# |    value_loss             | 857      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -875     |
# | time/                     |          |
# |    fps                    | 470      |
# |    iterations             | 5        |
# |    time_elapsed           | 21       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 0.8      |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00702  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 53       |
# |    policy_objective       | 0.0123   |
# |    std                    | 0.769    |
# |    value_loss             | 679      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -860     |
# | time/                     |          |
# |    fps                    | 465      |
# |    iterations             | 6        |
# |    time_elapsed           | 26       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 0.825    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00762  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 54       |
# |    policy_objective       | 0.0143   |
# |    std                    | 0.757    |
# |    value_loss             | 660      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -832     |
# | time/                     |          |
# |    fps                    | 467      |
# |    iterations             | 7        |
# |    time_elapsed           | 30       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 0.851    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00773  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 55       |
# |    policy_objective       | 0.0167   |
# |    std                    | 0.743    |
# |    value_loss             | 428      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -808     |
# | time/                     |          |
# |    fps                    | 470      |
# |    iterations             | 8        |
# |    time_elapsed           | 34       |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 0.881    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00726  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 56       |
# |    policy_objective       | 0.0213   |
# |    std                    | 0.72     |
# |    value_loss             | 291      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -794     |
# | time/                     |          |
# |    fps                    | 472      |
# |    iterations             | 9        |
# |    time_elapsed           | 39       |
# |    total_timesteps        | 18432    |
# | train/                    |          |
# |    explained_variance     | 0.876    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00698  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 57       |
# |    policy_objective       | 0.0147   |
# |    std                    | 0.728    |
# |    value_loss             | 506      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -758     |
# | time/                     |          |
# |    fps                    | 471      |
# |    iterations             | 10       |
# |    time_elapsed           | 43       |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 0.914    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00761  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 58       |
# |    policy_objective       | 0.0205   |
# |    std                    | 0.72     |
# |    value_loss             | 376      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -734     |
# | time/                     |          |
# |    fps                    | 472      |
# |    iterations             | 11       |
# |    time_elapsed           | 47       |
# |    total_timesteps        | 22528    |
# | train/                    |          |
# |    explained_variance     | 0.883    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00787  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 59       |
# |    policy_objective       | 0.0231   |
# |    std                    | 0.698    |
# |    value_loss             | 250      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -690     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 12       |
# |    time_elapsed           | 51       |
# |    total_timesteps        | 24576    |
# | train/                    |          |
# |    explained_variance     | 0.927    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00787  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 60       |
# |    policy_objective       | 0.0255   |
# |    std                    | 0.692    |
# |    value_loss             | 283      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -644     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 13       |
# |    time_elapsed           | 56       |
# |    total_timesteps        | 26624    |
# | train/                    |          |
# |    explained_variance     | 0.928    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00833  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 61       |
# |    policy_objective       | 0.0195   |
# |    std                    | 0.681    |
# |    value_loss             | 334      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -604     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 14       |
# |    time_elapsed           | 60       |
# |    total_timesteps        | 28672    |
# | train/                    |          |
# |    explained_variance     | 0.884    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00801  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 62       |
# |    policy_objective       | 0.0296   |
# |    std                    | 0.677    |
# |    value_loss             | 282      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -550     |
# | time/                     |          |
# |    fps                    | 474      |
# |    iterations             | 15       |
# |    time_elapsed           | 64       |
# |    total_timesteps        | 30720    |
# | train/                    |          |
# |    explained_variance     | 0.927    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00836  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 63       |
# |    policy_objective       | 0.0263   |
# |    std                    | 0.654    |
# |    value_loss             | 260      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -499     |
# | time/                     |          |
# |    fps                    | 474      |
# |    iterations             | 16       |
# |    time_elapsed           | 69       |
# |    total_timesteps        | 32768    |
# | train/                    |          |
# |    explained_variance     | 0.926    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00848  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 64       |
# |    policy_objective       | 0.0303   |
# |    std                    | 0.638    |
# |    value_loss             | 274      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -445     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 17       |
# |    time_elapsed           | 73       |
# |    total_timesteps        | 34816    |
# | train/                    |          |
# |    explained_variance     | 0.954    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00868  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 65       |
# |    policy_objective       | 0.0229   |
# |    std                    | 0.639    |
# |    value_loss             | 202      |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 TRPO_model.learn(100000)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\sb3_contrib\trpo\trpo.py:412, in TRPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     403 def learn(
#     404     self: SelfTRPO,
#     405     total_timesteps: int,
#    (...)
#     410     progress_bar: bool = False,
#     411 ) -> SelfTRPO:
# --> 412     return super().learn(
#     413         total_timesteps=total_timesteps,
#     414         callback=callback,
#     415         log_interval=log_interval,
#     416         tb_log_name=tb_log_name,
#     417         reset_num_timesteps=reset_num_timesteps,
#     418         progress_bar=progress_bar,
#     419     )
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:169, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     166 with th.no_grad():
#     167     # Convert to pytorch tensor or to TensorDict
#     168     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 169     actions, values, log_probs = self.policy(obs_tensor)
#     170 actions = actions.cpu().numpy()
#     172 # Rescale and perform action
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\policies.py:619, in ActorCriticPolicy.forward(self, obs, deterministic)
#     617 features = self.extract_features(obs)
#     618 if self.share_features_extractor:
# --> 619     latent_pi, latent_vf = self.mlp_extractor(features)
#     620 else:
#     621     pi_features, vf_features = features
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\torch_layers.py:222, in MlpExtractor.forward(self, features)
#     217 def forward(self, features: th.Tensor) -> Tuple[th.Tensor, th.Tensor]:
#     218     """
#     219     :return: latent_policy, latent_value of the specified network.
#     220         If all layers are shared, then ``latent_policy == latent_value``
#     221     """
# --> 222     return self.forward_actor(features), self.forward_critic(features)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\torch_layers.py:225, in MlpExtractor.forward_actor(self, features)
#     224 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 225     return self.policy_net(features)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\activation.py:356, in Tanh.forward(self, input)
#     355 def forward(self, input: Tensor) -> Tensor:
# --> 356     return torch.tanh(input)
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# 定义GaussianModel
class GaussianModel(nn.Module):
    def __init__(self, obs_size, action_size, hidden_size=256, learn_logvar_bounds=False):
        super(GaussianModel, self).__init__()
        self.out_size = obs_size
        
        self.fc_net = nn.Sequential(
            nn.Linear(obs_size + action_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
        )
        
        self.mean_logvar = nn.Linear(hidden_size, obs_size * 2)
        
        self.min_logvar = nn.Parameter(
            -10 * torch.ones(1, obs_size), requires_grad=learn_logvar_bounds
        )
        self.max_logvar = nn.Parameter(
            0.5 * torch.ones(1, obs_size), requires_grad=learn_logvar_bounds
        )
        
    def forward(self, x):
        x = self.fc_net(x)
        mean_and_logvar = self.mean_logvar(x)
        mean = mean_and_logvar[..., :self.out_size]
        logvar = mean_and_logvar[..., self.out_size:]
        
        logvar = self.max_logvar - F.softplus(self.max_logvar - logvar)
        logvar = self.min_logvar + F.softplus(logvar - self.min_logvar)
        
        # If the original input was one-dimensional, squeeze the output
        if logvar.shape[0] == 1:
            mean = mean.squeeze(0)
            logvar = logvar.squeeze(0)
        
        return mean, logvar

# 定义测试用例
def test_gaussian_model():
    obs_size = 4
    action_size = 2
    hidden_size = 256

    model = GaussianModel(obs_size, action_size, hidden_size)

    # 单个输入数据
    single_input = torch.randn(obs_size + action_size)
    
    # 批量输入数据
    batch_input = torch.randn(5, obs_size + action_size)
    
    # 前向传播
    single_mean, single_logvar = model(single_input)
    batch_mean, batch_logvar = model(batch_input)
    
    print("Single Input Mean:", single_mean)
    print("Single Input Logvar:", single_logvar)
    print("Batch Input Mean:", batch_mean)
    print("Batch Input Logvar:", batch_logvar)
    
    # 构建损失函数
    loss_fn = nn.MSELoss()
    
    # 构造目标数据
    target_mean = torch.randn(obs_size)
    target_logvar = torch.randn(obs_size)
    
    # 计算损失
    single_loss = loss_fn(single_mean, target_mean) + loss_fn(single_logvar, target_logvar)
    batch_loss = loss_fn(batch_mean, target_mean.unsqueeze(0).expand_as(batch_mean)) + \
                 loss_fn(batch_logvar, target_logvar.unsqueeze(0).expand_as(batch_logvar))
    
    print("Single Input Loss:", single_loss.item())
    print("Batch Input Loss:", batch_loss.item())

# 运行测试用例
test_gaussian_model()
# Out:
# Single Input Mean: tensor([ 0.3523, -0.0157, -0.2429,  0.1068], grad_fn=<SqueezeBackward1>)
# Single Input Logvar: tensor([-0.5165, -0.4999, -0.4875, -0.4478], grad_fn=<SqueezeBackward1>)
# Batch Input Mean: tensor([[ 0.1343,  0.0868, -0.1983,  0.0582],
#         [ 0.1066, -0.1898, -0.6315,  0.0736],
#         [ 0.3875,  0.1861, -0.3479,  0.0122],
#         [ 0.1715,  0.0231, -0.1943,  0.1135],
#         [ 0.2438, -0.0612, -0.4051,  0.0425]], grad_fn=<SliceBackward0>)
# Batch Input Logvar: tensor([[-0.4949, -0.4842, -0.5894, -0.4223],
#         [-0.4841, -0.3873, -0.6761, -0.3461],
#         [-0.5958, -0.4917, -0.8158, -0.3497],
#         [-0.4940, -0.4847, -0.5807, -0.4696],
#         [-0.4818, -0.4734, -0.7298, -0.3792]], grad_fn=<AddBackward0>)
# Single Input Loss: 3.6077818870544434
# Batch Input Loss: 3.898193597793579
