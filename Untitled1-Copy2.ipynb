# %%
from Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
env = PendulumEnv()
env = TimeLimit(env, max_episode_steps=200)

# %%
env.reset()
# Out:
# (array([-0.4777246 ,  0.87850964, -0.1921938 ], dtype=float32), {})

# %%
from stable_baselines3 import PPO
import torch

# %%
from MBEnvs.mb_pendulum2 import MB_PendulumEnv
env_models = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

MB_env = MB_PendulumEnv(env_models, device)

# %%
Global_RL = PPO("MlpPolicy", MB_env)

# %%
agent_sb3 = SB3Agent(policy_net=Global_RL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 agent_sb3 = SB3Agent(policy_net=Global_RL)
#
# NameError: name 'SB3Agent' is not defined

# %%
test_client = FRLClient(env=env,agent=agent_sb3, lr=0.0001, hidden_size= 256, device=device)

# %%
test_client.sample_data(100)

# %%
test_client.dataset_X

# %%
test_client.dataset_y

# %%
device
# Out:
# device(type='cuda')

# %%
from sb3_contrib import TRPO
from Client_diff import FRLClient
from Agent import SB3Agent
import copy
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# initialize the client and server
timesteps_real_per_round = 500
timesteps_fc_per_round = timesteps_real_per_round * 100
epoch_per_round = 100
CLIENTS_NUM = 3
rounds_num = 20
batch_size_env_model = 128

env_models = []
MB_env = TimeLimit(MB_PendulumEnv(env_models,device), max_episode_steps = 200)

# Global_RL = PPO("MlpPolicy", MB_env, verbose=1)
Global_RL = TRPO("MlpPolicy", MB_env, verbose=1)

env_theta = [0.1, 0.3, 0.5, 0.7, 0.9]
real_envs = []
Clients = []
for i in range(CLIENTS_NUM):
    real_envs.append( TimeLimit(PendulumEnv(), max_episode_steps=200) )
    policy_net = Global_RL
    agent = SB3Agent(policy_net)
    client = FRLClient(real_envs[i], agent, lr = 3e-4, hidden_size = 256, device = device)
    Clients.append(client)
    env_model = copy.deepcopy(client.model)
    env_models.append(env_model)
    

Global_RL.env.models = env_models


rewards_log = []

env_models = []
for round_idx in range(rounds_num):
    print('------------------------------')
    print("round: " + str(round_idx))
    for client_idx in range(len(Clients)):
        print('------------------------------')
        print("client: " + str(client_idx))
        # update policy
        Clients[client_idx].agent.policy_net = Global_RL
        # train prediction models
        Clients[client_idx].learn(timesteps_real_per_round, epoch_per_round, batch_size_env_model)
        #
        env_model = Clients[client_idx].get_prediction_model()
        env_models.append(env_model)
    
#     Server.update_env_models(env_models)
    Global_RL.env.models = env_models
    #
    Global_RL.learn(total_timesteps=timesteps_fc_per_round)
    
#     Server.learn(timesteps_real_per_round = 10000)
    # test performance
    mean_reward, std_reward = evaluate_policy(Global_RL, real_envs[1], n_eval_episodes=10)
    rewards_log.append(mean_reward)
    print("mean_reward in real env:" + str(mean_reward))
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------
# round: 0
# ------------------------------
# client: 0
# Avg loss: 0.09616694453482827!
# Avg loss: 0.08721562438489248!
# Avg loss: 0.05410275392447753!
# Avg loss: 0.03936646560983111!
# Avg loss: 0.02916467568759496!
# Avg loss: 0.02099951770098414!
# Avg loss: 0.018780317149745922!
# Avg loss: 0.011257480819670793!
# Avg loss: 0.00708533197583165!
# Avg loss: 0.005464718268776778!
# Avg loss: 0.00546454745674661!
# Avg loss: 0.00496996766247321!
# Avg loss: 0.0016275242073758515!
# Avg loss: 0.0016098264613901847!
# Avg loss: 0.0015829188064617483!
# Avg loss: 0.0015613875243798247!
# Avg loss: 0.0015713123232580983!
# Avg loss: 0.0015767029133284419!
# Avg loss: 0.0015503671157913838!
# Avg loss: 0.0015476832011480232!
# Avg loss: 0.0015651960801142195!
# Avg loss: 0.0015788555454961776!
# Avg loss: 0.001569564308694377!
# Avg loss: 0.0015872255506352909!
# Avg loss: 0.0016036497490040348!
# Avg loss: 0.0016053142044476468!
# Avg loss: 0.0016228477437986537!
# Avg loss: 0.0016331837986566218!
# Avg loss: 0.001622858859563697!
# Avg loss: 0.0016495250441251603!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -975     |
# | time/              |          |
# |    fps             | 328      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -968     |
# | time/                     |          |
# |    fps                    | 304      |
# |    iterations             | 2        |
# |    time_elapsed           | 13       |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.00164  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0084   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.00598  |
# |    std                    | 0.945    |
# |    value_loss             | 6.97e+03 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.01e+03 |
# | time/                     |           |
# |    fps                    | 299       |
# |    iterations             | 3         |
# |    time_elapsed           | 20        |
# |    total_timesteps        | 6144      |
# | train/                    |           |
# |    explained_variance     | -0.0122   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00779   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 2         |
# |    policy_objective       | 0.00671   |
# |    std                    | 0.917     |
# |    value_loss             | 6.33e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -939     |
# | time/                     |          |
# |    fps                    | 297      |
# |    iterations             | 4        |
# |    time_elapsed           | 27       |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.000629 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00852  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 3        |
# |    policy_objective       | 0.00741  |
# |    std                    | 0.975    |
# |    value_loss             | 6.83e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -950     |
# | time/                     |          |
# |    fps                    | 293      |
# |    iterations             | 5        |
# |    time_elapsed           | 34       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | -0.00236 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00955  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 4        |
# |    policy_objective       | 0.00421  |
# |    std                    | 0.937    |
# |    value_loss             | 4.26e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -921     |
# | time/                     |          |
# |    fps                    | 289      |
# |    iterations             | 6        |
# |    time_elapsed           | 42       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | -0.00626 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00625  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 5        |
# |    policy_objective       | 0.00443  |
# |    std                    | 0.944    |
# |    value_loss             | 6.57e+03 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -899      |
# | time/                     |           |
# |    fps                    | 289       |
# |    iterations             | 7         |
# |    time_elapsed           | 49        |
# |    total_timesteps        | 14336     |
# | train/                    |           |
# |    explained_variance     | -0.000708 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00563   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 6         |
# |    policy_objective       | 0.00734   |
# |    std                    | 0.935     |
# |    value_loss             | 4.29e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -902      |
# | time/                     |           |
# |    fps                    | 290       |
# |    iterations             | 8         |
# |    time_elapsed           | 56        |
# |    total_timesteps        | 16384     |
# | train/                    |           |
# |    explained_variance     | -0.000147 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00751   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 7         |
# |    policy_objective       | 0.00376   |
# |    std                    | 0.889     |
# |    value_loss             | 4.11e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -897      |
# | time/                     |           |
# |    fps                    | 291       |
# |    iterations             | 9         |
# |    time_elapsed           | 63        |
# |    total_timesteps        | 18432     |
# | train/                    |           |
# |    explained_variance     | -0.000109 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00741   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 8         |
# |    policy_objective       | 0.00844   |
# |    std                    | 0.914     |
# |    value_loss             | 5.09e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -906      |
# | time/                     |           |
# |    fps                    | 291       |
# |    iterations             | 10        |
# |    time_elapsed           | 70        |
# |    total_timesteps        | 20480     |
# | train/                    |           |
# |    explained_variance     | -0.000111 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00724   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 9         |
# |    policy_objective       | 0.00848   |
# |    std                    | 0.863     |
# |    value_loss             | 4.75e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -874      |
# | time/                     |           |
# |    fps                    | 292       |
# |    iterations             | 11        |
# |    time_elapsed           | 76        |
# |    total_timesteps        | 22528     |
# | train/                    |           |
# |    explained_variance     | -9.13e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00933   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 10        |
# |    policy_objective       | 0.00753   |
# |    std                    | 0.83      |
# |    value_loss             | 4.7e+03   |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -884      |
# | time/                     |           |
# |    fps                    | 294       |
# |    iterations             | 12        |
# |    time_elapsed           | 83        |
# |    total_timesteps        | 24576     |
# | train/                    |           |
# |    explained_variance     | -0.000173 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0088    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 11        |
# |    policy_objective       | 0.00573   |
# |    std                    | 0.859     |
# |    value_loss             | 3.62e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -862     |
# | time/                     |          |
# |    fps                    | 296      |
# |    iterations             | 13       |
# |    time_elapsed           | 89       |
# |    total_timesteps        | 26624    |
# | train/                    |          |
# |    explained_variance     | 1.59e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00729  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 12       |
# |    policy_objective       | 0.00446  |
# |    std                    | 0.828    |
# |    value_loss             | 5.6e+03  |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -874      |
# | time/                     |           |
# |    fps                    | 296       |
# |    iterations             | 14        |
# |    time_elapsed           | 96        |
# |    total_timesteps        | 28672     |
# | train/                    |           |
# |    explained_variance     | -2.31e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00664   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 13        |
# |    policy_objective       | 0.00599   |
# |    std                    | 0.828     |
# |    value_loss             | 2.81e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -873     |
# | time/                     |          |
# |    fps                    | 295      |
# |    iterations             | 15       |
# |    time_elapsed           | 103      |
# |    total_timesteps        | 30720    |
# | train/                    |          |
# |    explained_variance     | -0.00012 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00817  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 14       |
# |    policy_objective       | 0.00943  |
# |    std                    | 0.83     |
# |    value_loss             | 4.57e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -858     |
# | time/                     |          |
# |    fps                    | 295      |
# |    iterations             | 16       |
# |    time_elapsed           | 110      |
# |    total_timesteps        | 32768    |
# | train/                    |          |
# |    explained_variance     | 1.79e-07 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0088   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 15       |
# |    policy_objective       | 0.00868  |
# |    std                    | 0.789    |
# |    value_loss             | 3.58e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -894     |
# | time/                     |          |
# |    fps                    | 294      |
# |    iterations             | 17       |
# |    time_elapsed           | 118      |
# |    total_timesteps        | 34816    |
# | train/                    |          |
# |    explained_variance     | 8.82e-06 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00771  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 16       |
# |    policy_objective       | 0.00669  |
# |    std                    | 0.792    |
# |    value_loss             | 2.94e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -917     |
# | time/                     |          |
# |    fps                    | 293      |
# |    iterations             | 18       |
# |    time_elapsed           | 125      |
# |    total_timesteps        | 36864    |
# | train/                    |          |
# |    explained_variance     | 7.44e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00934  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 17       |
# |    policy_objective       | 0.00708  |
# |    std                    | 0.752    |
# |    value_loss             | 4.6e+03  |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -916      |
# | time/                     |           |
# |    fps                    | 294       |
# |    iterations             | 19        |
# |    time_elapsed           | 132       |
# |    total_timesteps        | 38912     |
# | train/                    |           |
# |    explained_variance     | -1.13e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00734   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 18        |
# |    policy_objective       | 0.00861   |
# |    std                    | 0.792     |
# |    value_loss             | 4.28e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -925      |
# | time/                     |           |
# |    fps                    | 294       |
# |    iterations             | 20        |
# |    time_elapsed           | 139       |
# |    total_timesteps        | 40960     |
# | train/                    |           |
# |    explained_variance     | -7.15e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00859   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 19        |
# |    policy_objective       | 0.00974   |
# |    std                    | 0.764     |
# |    value_loss             | 3.46e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -900     |
# | time/                     |          |
# |    fps                    | 293      |
# |    iterations             | 21       |
# |    time_elapsed           | 146      |
# |    total_timesteps        | 43008    |
# | train/                    |          |
# |    explained_variance     | 1.07e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00801  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 20       |
# |    policy_objective       | 0.00887  |
# |    std                    | 0.724    |
# |    value_loss             | 3.38e+03 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -871      |
# | time/                     |           |
# |    fps                    | 294       |
# |    iterations             | 22        |
# |    time_elapsed           | 152       |
# |    total_timesteps        | 45056     |
# | train/                    |           |
# |    explained_variance     | -4.65e-06 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00642   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 21        |
# |    policy_objective       | 0.00405   |
# |    std                    | 0.694     |
# |    value_loss             | 2.68e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -894     |
# | time/                     |          |
# |    fps                    | 294      |
# |    iterations             | 23       |
# |    time_elapsed           | 160      |
# |    total_timesteps        | 47104    |
# | train/                    |          |
# |    explained_variance     | 5.25e-06 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00794  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 22       |
# |    policy_objective       | 0.00836  |
# |    std                    | 0.695    |
# |    value_loss             | 2.48e+03 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -885      |
# | time/                     |           |
# |    fps                    | 293       |
# |    iterations             | 24        |
# |    time_elapsed           | 167       |
# |    total_timesteps        | 49152     |
# | train/                    |           |
# |    explained_variance     | -1.67e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00943   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 23        |
# |    policy_objective       | 0.0063    |
# |    std                    | 0.682     |
# |    value_loss             | 3.21e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -859     |
# | time/                     |          |
# |    fps                    | 292      |
# |    iterations             | 25       |
# |    time_elapsed           | 174      |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 1.13e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00624  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 24       |
# |    policy_objective       | 0.00483  |
# |    std                    | 0.709    |
# |    value_loss             | 2.74e+03 |
# ----------------------------------------
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward in real env:-1092.84687998984
# ------------------------------
# round: 1
# ------------------------------
# client: 0
# Avg loss: 0.11980407462743946!
# Avg loss: 0.115662296544045!
# Avg loss: 0.11122914374008057!
# Avg loss: 0.11220776634697661!
# Avg loss: 0.11600702225721155!
# Avg loss: 0.11304568369680056!
# Avg loss: 0.11097996215610086!
# Avg loss: 0.11179421831172173!
# Avg loss: 0.11331749613229476!
# Avg loss: 0.11191394950659742!
# Avg loss: 0.11100633234097283!
# Avg loss: 0.11195008685194201!
# Avg loss: 0.11249922192613364!
# Avg loss: 0.11160697393203009!
# Avg loss: 0.11164594606199595!
# Avg loss: 0.11223064463452526!
# Avg loss: 0.11193644077770841!
# ------------------------------
# client: 1
# Avg loss: 0.01985270235988234!
# Avg loss: 0.020849362599922944!
# Avg loss: 0.018010837892021906!
# Avg loss: 0.017140325978919766!
# Avg loss: 0.017300706511875128!
# Avg loss: 0.0186002480143361!
# Avg loss: 0.017096640551238426!
# Avg loss: 0.01676324806828537!
# Avg loss: 0.017165734867485297!
# Avg loss: 0.017593018456800565!
# Avg loss: 0.0171923101855585!
# Avg loss: 0.016926126608086633!
# Avg loss: 0.01701309041649741!
# Avg loss: 0.017095145021685312!
# Avg loss: 0.016964437442972363!
# Avg loss: 0.016977692452564953!
# Avg loss: 0.01707475946728664!
# Avg loss: 0.017048068866556604!
# ------------------------------
# client: 2
# Avg loss: 0.007100757802800217!
# Avg loss: 0.0059610031655271695!
# Avg loss: 0.007634197029692587!
# Avg loss: 0.006217691261069073!
# Avg loss: 0.003255088220333467!
# Avg loss: 0.0039851548445100585!
# Avg loss: 0.004812950727355201!
# Avg loss: 0.004021857133739104!
# Avg loss: 0.00313387057524172!
# Avg loss: 0.0035050470537650352!
# Avg loss: 0.003923815341083051!
# Avg loss: 0.0035765590864320984!
# Avg loss: 0.0032847964189735043!
# Avg loss: 0.003537292900033814!
# Avg loss: 0.0036884684199200517!
# Avg loss: 0.0034559287883606277!
# Avg loss: 0.003447762225171876!
# Avg loss: 0.0036175712351875213!
# Avg loss: 0.0036411283684409075!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -735     |
# | time/              |          |
# |    fps             | 301      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -581     |
# | time/                     |          |
# |    fps                    | 291      |
# |    iterations             | 2        |
# |    time_elapsed           | 14       |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 6.2e-06  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0096   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 26       |
# |    policy_objective       | 0.00993  |
# |    std                    | 0.654    |
# |    value_loss             | 2.42e+03 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -781      |
# | time/                     |           |
# |    fps                    | 291       |
# |    iterations             | 3         |
# |    time_elapsed           | 21        |
# |    total_timesteps        | 6144      |
# | train/                    |           |
# |    explained_variance     | -1.67e-06 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00772   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 27        |
# |    policy_objective       | 0.00527   |
# |    std                    | 0.627     |
# |    value_loss             | 1.27e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -793      |
# | time/                     |           |
# |    fps                    | 294       |
# |    iterations             | 4         |
# |    time_elapsed           | 27        |
# |    total_timesteps        | 8192      |
# | train/                    |           |
# |    explained_variance     | -1.81e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00908   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 28        |
# |    policy_objective       | 0.0108    |
# |    std                    | 0.59      |
# |    value_loss             | 3.44e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -811     |
# | time/                     |          |
# |    fps                    | 293      |
# |    iterations             | 5        |
# |    time_elapsed           | 34       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 2.8e-06  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00904  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 29       |
# |    policy_objective       | 0.00554  |
# |    std                    | 0.576    |
# |    value_loss             | 2.49e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -838     |
# | time/                     |          |
# |    fps                    | 283      |
# |    iterations             | 6        |
# |    time_elapsed           | 43       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 4.29e-06 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00689  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 30       |
# |    policy_objective       | 0.00801  |
# |    std                    | 0.6      |
# |    value_loss             | 2.69e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -838     |
# | time/                     |          |
# |    fps                    | 282      |
# |    iterations             | 7        |
# |    time_elapsed           | 50       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 1.03e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00817  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 31       |
# |    policy_objective       | 0.00776  |
# |    std                    | 0.633    |
# |    value_loss             | 2.76e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -827     |
# | time/                     |          |
# |    fps                    | 282      |
# |    iterations             | 8        |
# |    time_elapsed           | 58       |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 1.03e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00945  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 32       |
# |    policy_objective       | 0.00908  |
# |    std                    | 0.627    |
# |    value_loss             | 2.24e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -847     |
# | time/                     |          |
# |    fps                    | 283      |
# |    iterations             | 9        |
# |    time_elapsed           | 65       |
# |    total_timesteps        | 18432    |
# | train/                    |          |
# |    explained_variance     | 1.05e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00787  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 33       |
# |    policy_objective       | 0.00892  |
# |    std                    | 0.588    |
# |    value_loss             | 2.18e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -856     |
# | time/                     |          |
# |    fps                    | 283      |
# |    iterations             | 10       |
# |    time_elapsed           | 72       |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 2.15e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00786  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 34       |
# |    policy_objective       | 0.014    |
# |    std                    | 0.574    |
# |    value_loss             | 2.43e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -874     |
# | time/                     |          |
# |    fps                    | 283      |
# |    iterations             | 11       |
# |    time_elapsed           | 79       |
# |    total_timesteps        | 22528    |
# | train/                    |          |
# |    explained_variance     | 2.69e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00869  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 35       |
# |    policy_objective       | 0.00619  |
# |    std                    | 0.587    |
# |    value_loss             | 2.34e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -896     |
# | time/                     |          |
# |    fps                    | 283      |
# |    iterations             | 12       |
# |    time_elapsed           | 86       |
# |    total_timesteps        | 24576    |
# | train/                    |          |
# |    explained_variance     | 4.89e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00841  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 36       |
# |    policy_objective       | 0.00922  |
# |    std                    | 0.622    |
# |    value_loss             | 2.01e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -853     |
# | time/                     |          |
# |    fps                    | 284      |
# |    iterations             | 13       |
# |    time_elapsed           | 93       |
# |    total_timesteps        | 26624    |
# | train/                    |          |
# |    explained_variance     | 0.441    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00557  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 37       |
# |    policy_objective       | 0.01     |
# |    std                    | 0.605    |
# |    value_loss             | 1.56e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -832     |
# | time/                     |          |
# |    fps                    | 284      |
# |    iterations             | 14       |
# |    time_elapsed           | 100      |
# |    total_timesteps        | 28672    |
# | train/                    |          |
# |    explained_variance     | 0.668    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00859  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 38       |
# |    policy_objective       | 0.0117   |
# |    std                    | 0.62     |
# |    value_loss             | 1.13e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -821     |
# | time/                     |          |
# |    fps                    | 285      |
# |    iterations             | 15       |
# |    time_elapsed           | 107      |
# |    total_timesteps        | 30720    |
# | train/                    |          |
# |    explained_variance     | 0.768    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00687  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 39       |
# |    policy_objective       | 0.0106   |
# |    std                    | 0.602    |
# |    value_loss             | 1.39e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -807     |
# | time/                     |          |
# |    fps                    | 285      |
# |    iterations             | 16       |
# |    time_elapsed           | 114      |
# |    total_timesteps        | 32768    |
# | train/                    |          |
# |    explained_variance     | 0.828    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00828  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 40       |
# |    policy_objective       | 0.00668  |
# |    std                    | 0.584    |
# |    value_loss             | 1.23e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -819     |
# | time/                     |          |
# |    fps                    | 286      |
# |    iterations             | 17       |
# |    time_elapsed           | 121      |
# |    total_timesteps        | 34816    |
# | train/                    |          |
# |    explained_variance     | 0.858    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00775  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 41       |
# |    policy_objective       | 0.00795  |
# |    std                    | 0.596    |
# |    value_loss             | 1.57e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -815     |
# | time/                     |          |
# |    fps                    | 286      |
# |    iterations             | 18       |
# |    time_elapsed           | 128      |
# |    total_timesteps        | 36864    |
# | train/                    |          |
# |    explained_variance     | 0.898    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00967  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 42       |
# |    policy_objective       | 0.00843  |
# |    std                    | 0.609    |
# |    value_loss             | 1.26e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -800     |
# | time/                     |          |
# |    fps                    | 286      |
# |    iterations             | 19       |
# |    time_elapsed           | 135      |
# |    total_timesteps        | 38912    |
# | train/                    |          |
# |    explained_variance     | 0.913    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00879  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 43       |
# |    policy_objective       | 0.011    |
# |    std                    | 0.595    |
# |    value_loss             | 1.45e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -808     |
# | time/                     |          |
# |    fps                    | 287      |
# |    iterations             | 20       |
# |    time_elapsed           | 142      |
# |    total_timesteps        | 40960    |
# | train/                    |          |
# |    explained_variance     | 0.919    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00763  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 44       |
# |    policy_objective       | 0.0103   |
# |    std                    | 0.568    |
# |    value_loss             | 1.21e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -807     |
# | time/                     |          |
# |    fps                    | 288      |
# |    iterations             | 21       |
# |    time_elapsed           | 149      |
# |    total_timesteps        | 43008    |
# | train/                    |          |
# |    explained_variance     | 0.939    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00665  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 45       |
# |    policy_objective       | 0.00823  |
# |    std                    | 0.555    |
# |    value_loss             | 1.19e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -814     |
# | time/                     |          |
# |    fps                    | 288      |
# |    iterations             | 22       |
# |    time_elapsed           | 156      |
# |    total_timesteps        | 45056    |
# | train/                    |          |
# |    explained_variance     | 0.946    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00893  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 46       |
# |    policy_objective       | 0.0126   |
# |    std                    | 0.552    |
# |    value_loss             | 1.17e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -866     |
# | time/                     |          |
# |    fps                    | 288      |
# |    iterations             | 23       |
# |    time_elapsed           | 163      |
# |    total_timesteps        | 47104    |
# | train/                    |          |
# |    explained_variance     | 0.945    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00611  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 47       |
# |    policy_objective       | 0.0124   |
# |    std                    | 0.571    |
# |    value_loss             | 1.31e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -883     |
# | time/                     |          |
# |    fps                    | 289      |
# |    iterations             | 24       |
# |    time_elapsed           | 169      |
# |    total_timesteps        | 49152    |
# | train/                    |          |
# |    explained_variance     | 0.947    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00457  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 48       |
# |    policy_objective       | 0.00837  |
# |    std                    | 0.585    |
# |    value_loss             | 1.19e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -877     |
# | time/                     |          |
# |    fps                    | 289      |
# |    iterations             | 25       |
# |    time_elapsed           | 177      |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 0.948    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00626  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 49       |
# |    policy_objective       | 0.0108   |
# |    std                    | 0.569    |
# |    value_loss             | 1.01e+03 |
# ----------------------------------------
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward in real env:-1094.7912594552151
# ------------------------------
# round: 2
# ------------------------------
# client: 0
# Avg loss: 0.033766338772644906!
# Avg loss: 0.030559968243857535!
# Avg loss: 0.033423199634004655!
# Avg loss: 0.029654386121989472!
# Avg loss: 0.03173056347581223!
# Avg loss: 0.02945997041138374!
# Avg loss: 0.03053151716919577!
# Avg loss: 0.02938774340194262!
# Avg loss: 0.029964115179245708!
# Avg loss: 0.02928066328295851!
# Avg loss: 0.029629441694317697!
# Avg loss: 0.029365105975224046!
# Avg loss: 0.029405603835354364!
# Avg loss: 0.029327153402044434!
# Avg loss: 0.029420568259890086!
# Avg loss: 0.029476349969130147!
# Avg loss: 0.029341578899369173!
# Avg loss: 0.029411072053189855!
# Avg loss: 0.029317375857626757!
# Avg loss: 0.029263533776017234!
# Avg loss: 0.02933434876402316!
# Avg loss: 0.029229712893223524!
# Avg loss: 0.02922122027639792!
# Avg loss: 0.029311555767256626!
# Avg loss: 0.0292947355325911!
# Avg loss: 0.02923066286132477!
# Avg loss: 0.029239776602945917!
# Avg loss: 0.029147324737861406!
# Avg loss: 0.029234525466341664!
# Avg loss: 0.029194550620194756!
# Avg loss: 0.02924663481880013!
# Avg loss: 0.029160175706921716!
# Avg loss: 0.029160827074623134!
|
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0074   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 93       |
# |    policy_objective       | 0.0189   |
# |    std                    | 0.486    |
# |    value_loss             | 75.1     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -950     |
# | time/                     |          |
# |    fps                    | 290      |
# |    iterations             | 20       |
# |    time_elapsed           | 140      |
# |    total_timesteps        | 40960    |
# | train/                    |          |
# |    explained_variance     | 0.984    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00823  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 94       |
# |    policy_objective       | 0.0114   |
# |    std                    | 0.476    |
# |    value_loss             | 214      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -972     |
# | time/                     |          |
# |    fps                    | 289      |
# |    iterations             | 21       |
# |    time_elapsed           | 148      |
# |    total_timesteps        | 43008    |
# | train/                    |          |
# |    explained_variance     | 0.976    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00701  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 95       |
# |    policy_objective       | 0.0197   |
# |    std                    | 0.465    |
# |    value_loss             | 939      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -963     |
# | time/                     |          |
# |    fps                    | 288      |
# |    iterations             | 22       |
# |    time_elapsed           | 156      |
# |    total_timesteps        | 45056    |
# | train/                    |          |
# |    explained_variance     | 0.959    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00455  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 96       |
# |    policy_objective       | 0.0202   |
# |    std                    | 0.458    |
# |    value_loss             | 518      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -969     |
# | time/                     |          |
# |    fps                    | 289      |
# |    iterations             | 23       |
# |    time_elapsed           | 162      |
# |    total_timesteps        | 47104    |
# | train/                    |          |
# |    explained_variance     | 0.966    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0092   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 97       |
# |    policy_objective       | 0.0128   |
# |    std                    | 0.449    |
# |    value_loss             | 574      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -983     |
# | time/                     |          |
# |    fps                    | 288      |
# |    iterations             | 24       |
# |    time_elapsed           | 170      |
# |    total_timesteps        | 49152    |
# | train/                    |          |
# |    explained_variance     | 0.991    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00385  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 98       |
# |    policy_objective       | 0.0121   |
# |    std                    | 0.449    |
# |    value_loss             | 355      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -955     |
# | time/                     |          |
# |    fps                    | 287      |
# |    iterations             | 25       |
# |    time_elapsed           | 177      |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 0.988    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00778  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 99       |
# |    policy_objective       | 0.0196   |
# |    std                    | 0.445    |
# |    value_loss             | 249      |
# ----------------------------------------
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward in real env:-1217.6081970199943
# ------------------------------
# round: 4
# ------------------------------
# client: 0
# Avg loss: 0.008761812080144106!
# Avg loss: 0.004544322063253882!
# Avg loss: 0.005670311172798393!
# Avg loss: 0.005378784610147704!
# Avg loss: 0.004086957994525922!
# Avg loss: 0.00500138389126126!
# Avg loss: 0.004097453374852194!
# Avg loss: 0.004289067885401891!
# Avg loss: 0.004129986797846262!
# Avg loss: 0.0037957622076343492!
# Avg loss: 0.0039147176196153545!
# Avg loss: 0.0037101274565672308!
# Avg loss: 0.0037687079436849067!
# Avg loss: 0.003739427707417538!
# Avg loss: 0.0037807021504462075!
# Avg loss: 0.003771289653413987!
# Avg loss: 0.0037041135596336972!
# Avg loss: 0.0037449883957985245!
# Avg loss: 0.003725274070056912!
# Avg loss: 0.00372550565948283!
# Avg loss: 0.0037674853363932927!
# Avg loss: 0.0037320260563925936!
# Avg loss: 0.0037265159159748386!
# Avg loss: 0.0036798265869644334!
# Avg loss: 0.003742469105673081!
# Avg loss: 0.0037973542806351663!
# Avg loss: 0.0038609186394751305!
|
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -750     |
# | time/                     |          |
# |    fps                    | 300      |
# |    iterations             | 6        |
# |    time_elapsed           | 40       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 0.985    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00581  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 105      |
# |    policy_objective       | 0.0118   |
# |    std                    | 0.467    |
# |    value_loss             | 680      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -800     |
# | time/                     |          |
# |    fps                    | 293      |
# |    iterations             | 7        |
# |    time_elapsed           | 48       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 0.996    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.006    |
# |    learning_rate          | 0.001    |
# |    n_updates              | 106      |
# |    policy_objective       | 0.00982  |
# |    std                    | 0.471    |
# |    value_loss             | 164      |
# ----------------------------------------

# %%
obs,_ = Clients[0].env.reset()

# %%
obs
# Out:
# array([-0.80263555,  0.5964697 , -0.84910995], dtype=float32)

# %%
Clients[0].agent.act(obs)

# %%
Clients[0].agent.policy_net.predict(obs)[0]
# Out:
# array([-0.30735433], dtype=float32)

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# mean_reward, std_reward = evaluate_policy(Global_RL, real_envs[1], n_eval_episodes=10)
mean_reward, std_reward = evaluate_policy(Global_RL, MB_env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward} +/- {std_reward}")
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward: -93.15121025741101 +/- 109.2765889131137

# %%
from sb3_contrib import TRPO

# %%
TRPO_model = TRPO("MlpPolicy", env=real_envs[0], verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TRPO_model.learn(100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -829     |
# | time/              |          |
# |    fps             | 520      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -847     |
# | time/                     |          |
# |    fps                    | 478      |
# |    iterations             | 2        |
# |    time_elapsed           | 8        |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | 0.715    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00696  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 50       |
# |    policy_objective       | 0.0147   |
# |    std                    | 0.809    |
# |    value_loss             | 433      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -893     |
# | time/                     |          |
# |    fps                    | 481      |
# |    iterations             | 3        |
# |    time_elapsed           | 12       |
# |    total_timesteps        | 6144     |
# | train/                    |          |
# |    explained_variance     | 0.749    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00777  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 51       |
# |    policy_objective       | 0.0188   |
# |    std                    | 0.789    |
# |    value_loss             | 629      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -890     |
# | time/                     |          |
# |    fps                    | 470      |
# |    iterations             | 4        |
# |    time_elapsed           | 17       |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.759    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00865  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 52       |
# |    policy_objective       | 0.0126   |
# |    std                    | 0.762    |
# |    value_loss             | 857      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -875     |
# | time/                     |          |
# |    fps                    | 470      |
# |    iterations             | 5        |
# |    time_elapsed           | 21       |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 0.8      |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00702  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 53       |
# |    policy_objective       | 0.0123   |
# |    std                    | 0.769    |
# |    value_loss             | 679      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -860     |
# | time/                     |          |
# |    fps                    | 465      |
# |    iterations             | 6        |
# |    time_elapsed           | 26       |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 0.825    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00762  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 54       |
# |    policy_objective       | 0.0143   |
# |    std                    | 0.757    |
# |    value_loss             | 660      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -832     |
# | time/                     |          |
# |    fps                    | 467      |
# |    iterations             | 7        |
# |    time_elapsed           | 30       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 0.851    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00773  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 55       |
# |    policy_objective       | 0.0167   |
# |    std                    | 0.743    |
# |    value_loss             | 428      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -808     |
# | time/                     |          |
# |    fps                    | 470      |
# |    iterations             | 8        |
# |    time_elapsed           | 34       |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 0.881    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00726  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 56       |
# |    policy_objective       | 0.0213   |
# |    std                    | 0.72     |
# |    value_loss             | 291      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -794     |
# | time/                     |          |
# |    fps                    | 472      |
# |    iterations             | 9        |
# |    time_elapsed           | 39       |
# |    total_timesteps        | 18432    |
# | train/                    |          |
# |    explained_variance     | 0.876    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00698  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 57       |
# |    policy_objective       | 0.0147   |
# |    std                    | 0.728    |
# |    value_loss             | 506      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -758     |
# | time/                     |          |
# |    fps                    | 471      |
# |    iterations             | 10       |
# |    time_elapsed           | 43       |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 0.914    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00761  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 58       |
# |    policy_objective       | 0.0205   |
# |    std                    | 0.72     |
# |    value_loss             | 376      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -734     |
# | time/                     |          |
# |    fps                    | 472      |
# |    iterations             | 11       |
# |    time_elapsed           | 47       |
# |    total_timesteps        | 22528    |
# | train/                    |          |
# |    explained_variance     | 0.883    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00787  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 59       |
# |    policy_objective       | 0.0231   |
# |    std                    | 0.698    |
# |    value_loss             | 250      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -690     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 12       |
# |    time_elapsed           | 51       |
# |    total_timesteps        | 24576    |
# | train/                    |          |
# |    explained_variance     | 0.927    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00787  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 60       |
# |    policy_objective       | 0.0255   |
# |    std                    | 0.692    |
# |    value_loss             | 283      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -644     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 13       |
# |    time_elapsed           | 56       |
# |    total_timesteps        | 26624    |
# | train/                    |          |
# |    explained_variance     | 0.928    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00833  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 61       |
# |    policy_objective       | 0.0195   |
# |    std                    | 0.681    |
# |    value_loss             | 334      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -604     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 14       |
# |    time_elapsed           | 60       |
# |    total_timesteps        | 28672    |
# | train/                    |          |
# |    explained_variance     | 0.884    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00801  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 62       |
# |    policy_objective       | 0.0296   |
# |    std                    | 0.677    |
# |    value_loss             | 282      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -550     |
# | time/                     |          |
# |    fps                    | 474      |
# |    iterations             | 15       |
# |    time_elapsed           | 64       |
# |    total_timesteps        | 30720    |
# | train/                    |          |
# |    explained_variance     | 0.927    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00836  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 63       |
# |    policy_objective       | 0.0263   |
# |    std                    | 0.654    |
# |    value_loss             | 260      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -499     |
# | time/                     |          |
# |    fps                    | 474      |
# |    iterations             | 16       |
# |    time_elapsed           | 69       |
# |    total_timesteps        | 32768    |
# | train/                    |          |
# |    explained_variance     | 0.926    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00848  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 64       |
# |    policy_objective       | 0.0303   |
# |    std                    | 0.638    |
# |    value_loss             | 274      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -445     |
# | time/                     |          |
# |    fps                    | 473      |
# |    iterations             | 17       |
# |    time_elapsed           | 73       |
# |    total_timesteps        | 34816    |
# | train/                    |          |
# |    explained_variance     | 0.954    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00868  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 65       |
# |    policy_objective       | 0.0229   |
# |    std                    | 0.639    |
# |    value_loss             | 202      |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 TRPO_model.learn(100000)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\sb3_contrib\trpo\trpo.py:412, in TRPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     403 def learn(
#     404     self: SelfTRPO,
#     405     total_timesteps: int,
#    (...)
#     410     progress_bar: bool = False,
#     411 ) -> SelfTRPO:
# --> 412     return super().learn(
#     413         total_timesteps=total_timesteps,
#     414         callback=callback,
#     415         log_interval=log_interval,
#     416         tb_log_name=tb_log_name,
#     417         reset_num_timesteps=reset_num_timesteps,
#     418         progress_bar=progress_bar,
#     419     )
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:169, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     166 with th.no_grad():
#     167     # Convert to pytorch tensor or to TensorDict
#     168     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 169     actions, values, log_probs = self.policy(obs_tensor)
#     170 actions = actions.cpu().numpy()
#     172 # Rescale and perform action
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\policies.py:619, in ActorCriticPolicy.forward(self, obs, deterministic)
#     617 features = self.extract_features(obs)
#     618 if self.share_features_extractor:
# --> 619     latent_pi, latent_vf = self.mlp_extractor(features)
#     620 else:
#     621     pi_features, vf_features = features
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\torch_layers.py:222, in MlpExtractor.forward(self, features)
#     217 def forward(self, features: th.Tensor) -> Tuple[th.Tensor, th.Tensor]:
#     218     """
#     219     :return: latent_policy, latent_value of the specified network.
#     220         If all layers are shared, then ``latent_policy == latent_value``
#     221     """
# --> 222     return self.forward_actor(features), self.forward_critic(features)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\torch_layers.py:225, in MlpExtractor.forward_actor(self, features)
#     224 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 225     return self.policy_net(features)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File D:\Anaconda\envs\py3.8\lib\site-packages\torch\nn\modules\activation.py:356, in Tanh.forward(self, input)
#     355 def forward(self, input: Tensor) -> Tensor:
# --> 356     return torch.tanh(input)
#
# KeyboardInterrupt:
