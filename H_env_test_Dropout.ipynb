# %%
from H_Envs.cartpole import CartPoleEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
gravitys = [9.8, 9.8, 9.8]
lengths = [0.5, 0.2, 0.8]


real_envs = []

for i in range(len(gravitys)):
    gravity = gravitys[i]
    length = lengths[i]
    
    env = TimeLimit(CartPoleEnv(length = length, gravity = gravity), max_episode_steps = 200)
    real_envs.append(env)

# %%
from stable_baselines3 import DQN

DQN_model =DQN("MlpPolicy", env = real_envs[0], learning_starts=1000,verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
DQN_model.learn(total_timesteps=100000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.5     |
# |    ep_rew_mean      | 41.5     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 11860    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 11045    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 254      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.8     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 10733    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 322      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 10821    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11001    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 484      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 10944    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 10884    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 653      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11043    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.9     |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11074    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 897      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11011    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 958      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 6040     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1057     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.512    |
# |    n_updates        | 14       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4472     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1127     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.472    |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3367     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1236     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.414    |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2729     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.333    |
# |    n_updates        | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2487     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1453     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.279    |
# |    n_updates        | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2178     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1604     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.207    |
# |    n_updates        | 150      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.1     |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1977     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1707     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1888     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1766     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 191      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1786     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1842     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 210      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1545     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1946     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0752   |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1509     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2007     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0679   |
# |    n_updates        | 251      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1465     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2090     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 272      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.5     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1440     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 290      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1417     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2227     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 306      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1386     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2293     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 323      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1363     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2381     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 345      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1343     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2476     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1328     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2549     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1311     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 407      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1294     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2704     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00899  |
# |    n_updates        | 425      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1274     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2778     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00873  |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1260     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2896     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00596  |
# |    n_updates        | 473      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1248     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2987     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00856  |
# |    n_updates        | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1238     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3066     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 516      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1222     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3164     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 540      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1204     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3264     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 565      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1195     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3323     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00315  |
# |    n_updates        | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1188     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3391     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00366  |
# |    n_updates        | 597      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1171     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3500     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00771  |
# |    n_updates        | 624      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1164     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3557     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00251  |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1157     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3627     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00265  |
# |    n_updates        | 656      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1148     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3683     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00391  |
# |    n_updates        | 670      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1134     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3792     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 697      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1127     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3859     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00421  |
# |    n_updates        | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1116     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3929     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 732      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1106     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4015     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00247  |
# |    n_updates        | 753      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1100     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4072     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00158  |
# |    n_updates        | 767      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1089     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.001    |
# |    n_updates        | 790      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1079     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4242     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0014   |
# |    n_updates        | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1073     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4310     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00055  |
# |    n_updates        | 827      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1068     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4366     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00163  |
# |    n_updates        | 841      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1058     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4458     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 864      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.569    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1053     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4540     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00066  |
# |    n_updates        | 884      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1049     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4607     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000921 |
# |    n_updates        | 901      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1043     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4686     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1040     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4762     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0018   |
# |    n_updates        | 940      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1037     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4824     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00133  |
# |    n_updates        | 955      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1033     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4890     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000641 |
# |    n_updates        | 972      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.53     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1031     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4947     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000484 |
# |    n_updates        | 986      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1027     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5009     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000543 |
# |    n_updates        | 1002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1021     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5085     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000317 |
# |    n_updates        | 1021     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1018     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5153     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000323 |
# |    n_updates        | 1038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1016     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5213     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000732 |
# |    n_updates        | 1053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1013     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5286     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000243 |
# |    n_updates        | 1071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1010     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5349     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000815 |
# |    n_updates        | 1087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1006     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5404     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000449 |
# |    n_updates        | 1100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1002     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5462     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00251  |
# |    n_updates        | 1115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 994      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5545     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000828 |
# |    n_updates        | 1136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 984      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5609     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000315 |
# |    n_updates        | 1152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 978      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5679     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000792 |
# |    n_updates        | 1169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 971      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5752     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00203  |
# |    n_updates        | 1187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 968      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5821     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000228 |
# |    n_updates        | 1205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 966      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5894     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000813 |
# |    n_updates        | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.432    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 963      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5978     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000726 |
# |    n_updates        | 1244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 959      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6042     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000146 |
# |    n_updates        | 1260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.42     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 957      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6108     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 1276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 955      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00044  |
# |    n_updates        | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 947      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6231     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000995 |
# |    n_updates        | 1307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 942      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6314     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000597 |
# |    n_updates        | 1328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 939      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6386     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00125  |
# |    n_updates        | 1346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 937      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6455     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000384 |
# |    n_updates        | 1363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 933      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6530     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000443 |
# |    n_updates        | 1382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 925      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6606     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000803 |
# |    n_updates        | 1401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 922      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6690     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000281 |
# |    n_updates        | 1422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 920      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6793     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000111 |
# |    n_updates        | 1448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 908      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6886     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000178 |
# |    n_updates        | 1471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 906      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6964     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000181 |
# |    n_updates        | 1490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 904      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7043     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000604 |
# |    n_updates        | 1510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 897      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7124     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000369 |
# |    n_updates        | 1530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 893      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7201     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00037  |
# |    n_updates        | 1550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 892      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7279     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000742 |
# |    n_updates        | 1569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 887      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7366     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000676 |
# |    n_updates        | 1591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 884      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7444     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 1610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.282    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 880      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7553     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000944 |
# |    n_updates        | 1638     |
# ----------------------------------
# ----------------------------------
# ...
# |    time_elapsed     | 125      |
# |    total_timesteps  | 76115    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 18778    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 606      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 76915    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 18978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 605      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 77715    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 19178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 605      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 78500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00584  |
# |    n_updates        | 19374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 603      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 79300    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 19574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 603      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 80100    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0604   |
# |    n_updates        | 19774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 603      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 80883    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00281  |
# |    n_updates        | 19970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 604      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 81683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 20170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 603      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 82475    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00464  |
# |    n_updates        | 20368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 603      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 83269    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 20567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 603      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 84069    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00802  |
# |    n_updates        | 20767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 602      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 84869    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.122    |
# |    n_updates        | 20967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 602      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 85669    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00708  |
# |    n_updates        | 21167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 602      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 86466    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 21366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 602      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 87266    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00469  |
# |    n_updates        | 21566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 603      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 88058    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.144    |
# |    n_updates        | 21764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 603      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 88847    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00162  |
# |    n_updates        | 21961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 603      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 89647    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 22161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2252     |
# |    fps              | 604      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 90447    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 22361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2256     |
# |    fps              | 603      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 91232    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.19     |
# |    n_updates        | 22557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2260     |
# |    fps              | 603      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 92032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.434    |
# |    n_updates        | 22757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2264     |
# |    fps              | 604      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 92827    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00541  |
# |    n_updates        | 22956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2268     |
# |    fps              | 605      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 93604    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 23150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2272     |
# |    fps              | 605      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 94397    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 23349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2276     |
# |    fps              | 605      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 95195    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00357  |
# |    n_updates        | 23548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2280     |
# |    fps              | 606      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 95966    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00786  |
# |    n_updates        | 23741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2284     |
# |    fps              | 607      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 96761    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00402  |
# |    n_updates        | 23940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2288     |
# |    fps              | 607      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 97516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00519  |
# |    n_updates        | 24128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2292     |
# |    fps              | 607      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 98275    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 24318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2296     |
# |    fps              | 607      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 99057    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00994  |
# |    n_updates        | 24514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2300     |
# |    fps              | 608      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 99852    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.191    |
# |    n_updates        | 24712    |
# ----------------------------------

# %%
DQN_model.save("models/CartPole_DQN_Policy")

# %%
from H_Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
gravitys = [8.0, 10.0, 12.0]

real_envs = []
for i in range(len(gravitys)):
    gravity = gravitys[i]
    
    env = TimeLimit(PendulumEnv( g = gravity), max_episode_steps = 200)
    real_envs.append(env)

# %%
real_envs[1].g
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.g to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.g` for environment variables or `env.get_wrapper_attr('g')` that will search the reminding wrappers.
#   logger.warn(
# 10.0

# %%
from sb3_contrib import TRPO

# %%
TRPO_model = TRPO(policy="MlpPolicy",env=real_envs[1],verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TRPO_model.learn(total_timesteps=200000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.4e+03 |
# | time/              |          |
# |    fps             | 486      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.24e+03 |
# | time/                     |           |
# |    fps                    | 461       |
# |    iterations             | 2         |
# |    time_elapsed           | 8         |
# |    total_timesteps        | 4096      |
# | train/                    |           |
# |    explained_variance     | -0.00432  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00712   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 1         |
# |    policy_objective       | 0.0087    |
# |    std                    | 0.97      |
# |    value_loss             | 1.13e+04  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.19e+03 |
# | time/                     |           |
# |    fps                    | 462       |
# |    iterations             | 3         |
# |    time_elapsed           | 13        |
# |    total_timesteps        | 6144      |
# | train/                    |           |
# |    explained_variance     | 0.161     |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00693   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 2         |
# |    policy_objective       | 0.00914   |
# |    std                    | 0.961     |
# |    value_loss             | 5.98e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.17e+03 |
# | time/                     |           |
# |    fps                    | 464       |
# |    iterations             | 4         |
# |    time_elapsed           | 17        |
# |    total_timesteps        | 8192      |
# | train/                    |           |
# |    explained_variance     | 0.00554   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00861   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 3         |
# |    policy_objective       | 0.00672   |
# |    std                    | 0.931     |
# |    value_loss             | 6.66e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.14e+03 |
# | time/                     |           |
# |    fps                    | 463       |
# |    iterations             | 5         |
# |    time_elapsed           | 22        |
# |    total_timesteps        | 10240     |
# | train/                    |           |
# |    explained_variance     | 0.0024    |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00659   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 4         |
# |    policy_objective       | 0.00837   |
# |    std                    | 0.887     |
# |    value_loss             | 5.89e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.13e+03 |
# | time/                     |           |
# |    fps                    | 456       |
# |    iterations             | 6         |
# |    time_elapsed           | 26        |
# |    total_timesteps        | 12288     |
# | train/                    |           |
# |    explained_variance     | 0.00114   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00775   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 5         |
# |    policy_objective       | 0.00767   |
# |    std                    | 0.959     |
# |    value_loss             | 5.19e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.13e+03 |
# | time/                     |           |
# |    fps                    | 457       |
# |    iterations             | 7         |
# |    time_elapsed           | 31        |
# |    total_timesteps        | 14336     |
# | train/                    |           |
# |    explained_variance     | 0.000898  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00712   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 6         |
# |    policy_objective       | 0.0068    |
# |    std                    | 0.951     |
# |    value_loss             | 5.76e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.13e+03 |
# | time/                     |           |
# |    fps                    | 454       |
# |    iterations             | 8         |
# |    time_elapsed           | 36        |
# |    total_timesteps        | 16384     |
# | train/                    |           |
# |    explained_variance     | 0.000485  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00888   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 7         |
# |    policy_objective       | 0.0099    |
# |    std                    | 0.942     |
# |    value_loss             | 5.44e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.11e+03 |
# | time/                     |           |
# |    fps                    | 450       |
# |    iterations             | 9         |
# |    time_elapsed           | 40        |
# |    total_timesteps        | 18432     |
# | train/                    |           |
# |    explained_variance     | 0.00047   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00747   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 8         |
# |    policy_objective       | 0.00887   |
# |    std                    | 0.917     |
# |    value_loss             | 5.14e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -1.1e+03 |
# | time/                     |          |
# |    fps                    | 453      |
# |    iterations             | 10       |
# |    time_elapsed           | 45       |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 0.000317 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00583  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 9        |
# |    policy_objective       | 0.00775  |
# |    std                    | 0.887    |
# |    value_loss             | 4.01e+03 |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.08e+03 |
# | time/                     |           |
# |    fps                    | 454       |
# |    iterations             | 11        |
# |    time_elapsed           | 49        |
# |    total_timesteps        | 22528     |
# | train/                    |           |
# |    explained_variance     | 0.00034   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00574   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 10        |
# |    policy_objective       | 0.00591   |
# |    std                    | 0.921     |
# |    value_loss             | 4.88e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.08e+03 |
# | time/                     |           |
# |    fps                    | 453       |
# |    iterations             | 12        |
# |    time_elapsed           | 54        |
# |    total_timesteps        | 24576     |
# | train/                    |           |
# |    explained_variance     | 0.000224  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00813   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 11        |
# |    policy_objective       | 0.008     |
# |    std                    | 0.922     |
# |    value_loss             | 4.49e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.08e+03 |
# | time/                     |           |
# |    fps                    | 452       |
# |    iterations             | 13        |
# |    time_elapsed           | 58        |
# |    total_timesteps        | 26624     |
# | train/                    |           |
# |    explained_variance     | 0.000133  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00732   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 12        |
# |    policy_objective       | 0.00974   |
# |    std                    | 0.935     |
# |    value_loss             | 3.95e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.07e+03 |
# | time/                     |           |
# |    fps                    | 449       |
# |    iterations             | 14        |
# |    time_elapsed           | 63        |
# |    total_timesteps        | 28672     |
# | train/                    |           |
# |    explained_variance     | 0.000124  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00691   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 13        |
# |    policy_objective       | 0.00961   |
# |    std                    | 0.902     |
# |    value_loss             | 3.73e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.07e+03 |
# | time/                     |           |
# |    fps                    | 446       |
# |    iterations             | 15        |
# |    time_elapsed           | 68        |
# |    total_timesteps        | 30720     |
# | train/                    |           |
# |    explained_variance     | 0.000109  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0079    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 14        |
# |    policy_objective       | 0.00774   |
# |    std                    | 0.914     |
# |    value_loss             | 3.28e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.06e+03 |
# | time/                     |           |
# |    fps                    | 446       |
# |    iterations             | 16        |
# |    time_elapsed           | 73        |
# |    total_timesteps        | 32768     |
# | train/                    |           |
# |    explained_variance     | 9.95e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00639   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 15        |
# |    policy_objective       | 0.00805   |
# |    std                    | 0.88      |
# |    value_loss             | 3.59e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.05e+03 |
# | time/                     |           |
# |    fps                    | 443       |
# |    iterations             | 17        |
# |    time_elapsed           | 78        |
# |    total_timesteps        | 34816     |
# | train/                    |           |
# |    explained_variance     | 0.000101  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00579   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 16        |
# |    policy_objective       | 0.00642   |
# |    std                    | 0.894     |
# |    value_loss             | 3.05e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.05e+03 |
# | time/                     |           |
# |    fps                    | 439       |
# |    iterations             | 18        |
# |    time_elapsed           | 83        |
# |    total_timesteps        | 36864     |
# | train/                    |           |
# |    explained_variance     | 9.13e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00738   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 17        |
# |    policy_objective       | 0.0111    |
# |    std                    | 0.918     |
# |    value_loss             | 3.2e+03   |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.05e+03 |
# | time/                     |           |
# |    fps                    | 431       |
# |    iterations             | 19        |
# |    time_elapsed           | 90        |
# |    total_timesteps        | 38912     |
# | train/                    |           |
# |    explained_variance     | 7.65e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00441   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 18        |
# |    policy_objective       | 0.00795   |
# |    std                    | 0.919     |
# |    value_loss             | 2.48e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.03e+03 |
# | time/                     |           |
# |    fps                    | 425       |
# |    iterations             | 20        |
# |    time_elapsed           | 96        |
# |    total_timesteps        | 40960     |
# | train/                    |           |
# |    explained_variance     | 6.85e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00606   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 19        |
# |    policy_objective       | 0.00687   |
# |    std                    | 0.947     |
# |    value_loss             | 2.62e+03  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.01e+03 |
# | time/                     |           |
# |    fps                    | 419       |
# |    iterations             | 21        |
# |    time_elapsed           | 102       |
# |    total_timesteps        | 43008     |
# | train/                    |           |
# |    explained_variance     | 5.96e-05  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00695   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 20        |
# |    policy_objective       | 0.0114    |
# |    std                    | 0.932     |
# |    value_loss             | 2.39e+03  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -998     |
# | time/                     |          |
# |    fps                    | 413      |
# |    iterations             | 22       |
# |    time_elapsed           | 108      |
# |    total_timesteps        | 45056    |
# | train/                    |          |
# |    explained_variance     | 5.63e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00783  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 21       |
# |    policy_objective       | 0.0115   |
# |    std                    | 0.918    |
# |    value_loss             | 1.75e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -984     |
# | time/                     |          |
# |    fps                    | 410      |
# |    iterations             | 23       |
# |    time_elapsed           | 114      |
# |    total_timesteps        | 47104    |
# | train/                    |          |
# |    explained_variance     | 4.96e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00759  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 22       |
# |    policy_objective       | 0.0102   |
# |    std                    | 0.92     |
# |    value_loss             | 1.62e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -971     |
# | time/                     |          |
# |    fps                    | 405      |
# |    iterations             | 24       |
# |    time_elapsed           | 121      |
# |    total_timesteps        | 49152    |
# | train/                    |          |
# |    explained_variance     | 4.37e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0078   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 23       |
# |    policy_objective       | 0.015    |
# |    std                    | 0.924    |
# |    value_loss             | 1.89e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -954     |
# | time/                     |          |
# |    fps                    | 402      |
# |    iterations             | 25       |
# |    time_elapsed           | 127      |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 4.5e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00926  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 24       |
# |    policy_objective       | 0.0152   |
# |    std                    | 0.909    |
# |    value_loss             | 1.35e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -931     |
# | time/                     |          |
# |    fps                    | 399      |
# |    iterations             | 26       |
# |    time_elapsed           | 133      |
# |    total_timesteps        | 53248    |
# | train/                    |          |
# |    explained_variance     | 4.04e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0086   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 25       |
# |    policy_objective       | 0.0108   |
# |    std                    | 0.874    |
# |    value_loss             | 1.45e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -922     |
# | time/                     |          |
# |    fps                    | 397      |
# |    iterations             | 27       |
# |    time_elapsed           | 138      |
# |    total_timesteps        | 55296    |
# | train/                    |          |
# |    explained_variance     | 4.33e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00799  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 26       |
# |    policy_objective       | 0.0149   |
# |    std                    | 0.849    |
# |    value_loss             | 1.4e+03  |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -909     |
# | time/                     |          |
# |    fps                    | 396      |
# |    iterations             | 28       |
# |    time_elapsed           | 144      |
# |    total_timesteps        | 57344    |
# | train/                    |          |
# |    explained_variance     | 4.08e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00586  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 27       |
# |    policy_objective       | 0.00737  |
# |    std                    | 0.856    |
# |    value_loss             | 1.34e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -895     |
# | time/                     |          |
# |    fps                    | 394      |
# |    iterations             | 29       |
# |    time_elapsed           | 150      |
# |    total_timesteps        | 59392    |
# | train/                    |          |
# |    explained_variance     | 3.86e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00681  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 28       |
# |    policy_objective       | 0.0144   |
# |    std                    | 0.855    |
# |    value_loss             | 1.12e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -888     |
# | time/                     |          |
# |    fps                    | 392      |
# |    iterations             | 30       |
# |    time_elapsed           | 156      |
# |    total_timesteps        | 61440    |
# | train/                    |          |
# |    explained_variance     | 3.95e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00761  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 29       |
# |    policy_objective       | 0.0147   |
# |    std                    | 0.847    |
# |    value_loss             | 1.18e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -880     |
# | time/                     |          |
# |    fps                    | 391      |
# |    iterations             | 31       |
# |    time_elapsed           | 162      |
# |    total_timesteps        | 63488    |
# | train/                    |          |
# |    explained_variance     | 3.6e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00827  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 30       |
# |    policy_objective       | 0.00957  |
# |    std                    | 0.83     |
# |    value_loss             | 1.14e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -875     |
# | time/                     |          |
# |    fps                    | 390      |
# |    iterations             | 32       |
# |    time_elapsed           | 167      |
# |    total_timesteps        | 65536    |
# | train/                    |          |
# |    explained_variance     | 3.36e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0094   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 31       |
# |    policy_objective       | 0.0129   |
# |    std                    | 0.796    |
# |    value_loss             | 846      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -874     |
# | time/                     |          |
# |    fps                    | 389      |
# |    iterations             | 33       |
# |    time_elapsed           | 173      |
# |    total_timesteps        | 67584    |
# | train/                    |          |
# |    explained_variance     | 3.37e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00723  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 32       |
# |    policy_objective       | 0.0157   |
# |    std                    | 0.776    |
# |    value_loss             | 877      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -862     |
# | time/                     |          |
# |    fps                    | 387      |
# |    iterations             | 34       |
# |    time_elapsed           | 179      |
# |    total_timesteps        | 69632    |
# | train/                    |          |
# |    explained_variance     | 3.12e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00746  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 33       |
# |    policy_objective       | 0.0105   |
# |    std                    | 0.743    |
# |    value_loss             | 1.54e+03 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -860     |
# | time/                     |          |
# |    fps                    | 386      |
# |    iterations             | 35       |
# |    time_elapsed           | 185      |
# |    total_timesteps        | 71680    |
# | train/                    |          |
# |    explained_variance     | 3.8e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00891  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 34       |
# |    policy_objective       | 0.0115   |
# |    std                    | 0.758    |
# |    value_loss             | 781      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -843     |
# | time/                     |          |
# |    fps                    | 385      |
# |    iterations             | 36       |
# |    time_elapsed           | 191      |
# |    total_timesteps        | 73728    |
# | train/                    |          |
# |    explained_variance     | 3.8e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00859  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 35       |
# |    policy_objective       | 0.0125   |
# |    std                    | 0.752    |
# |    value_loss             | 837      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -828     |
# | time/                     |          |
# |    fps                    | 384      |
# |    iterations             | 37       |
# |    time_elapsed           | 197      |
# |    total_timesteps        | 75776    |
# | train/                    |          |
# |    explained_variance     | 4.46e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00822  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 36       |
# |    policy_objective       | 0.0148   |
# |    std                    | 0.765    |
# |    value_loss             | 720      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -819     |
# | time/                     |          |
# |    fps                    | 382      |
# |    iterations             | 38       |
# |    time_elapsed           | 203      |
# |    total_timesteps        | 77824    |
# | train/                    |          |
# |    explained_variance     | 5.58e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00868  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 37       |
# |    policy_objective       | 0.0131   |
# |    std                    | 0.77     |
# |    value_loss             | 626      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -810     |
# | time/                     |          |
# |    fps                    | 381      |
# |    iterations             | 39       |
# |    time_elapsed           | 209      |
# |    total_timesteps        | 79872    |
# | train/                    |          |
# |    explained_variance     | 6.5e-05  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00694  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 38       |
# |    policy_objective       | 0.0102   |
# |    std                    | 0.749    |
# |    value_loss             | 883      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -794     |
# | time/                     |          |
# |    fps                    | 380      |
# |    iterations             | 40       |
# |    time_elapsed           | 215      |
# |    total_timesteps        | 81920    |
# | train/                    |          |
# |    explained_variance     | 0.000132 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00822  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 39       |
# |    policy_objective       | 0.0155   |
# |    std                    | 0.746    |
# |    value_loss             | 891      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -791     |
# | time/                     |          |
# |    fps                    | 379      |
# |    iterations             | 41       |
# |    time_elapsed           | 221      |
# |    total_timesteps        | 83968    |
# | train/                    |          |
# |    explained_variance     | 0.355    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00754  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 40       |
# |    policy_objective       | 0.0155   |
# |    std                    | 0.751    |
# |    value_loss             | 707      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -786     |
# | time/                     |          |
# |    fps                    | 378      |
# |    iterations             | 42       |
# |    time_elapsed           | 227      |
# |    total_timesteps        | 86016    |
# | train/                    |          |
# |    explained_variance     | 0.654    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00735  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 41       |
# |    policy_objective       | 0.0172   |
# |    std                    | 0.741    |
# |    value_loss             | 338      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -764     |
# | time/                     |          |
# |    fps                    | 377      |
# |    iterations             | 43       |
# |    time_elapsed           | 233      |
# |    total_timesteps        | 88064    |
# | train/                    |          |
# |    explained_variance     | 0.67     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00809  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 42       |
# |    policy_objective       | 0.015    |
# |    std                    | 0.724    |
# |    value_loss             | 559      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -759     |
# | time/                     |          |
# |    fps                    | 377      |
# |    iterations             | 44       |
# |    time_elapsed           | 238      |
# |    total_timesteps        | 90112    |
# | train/                    |          |
# |    explained_variance     | 0.698    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00694  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 43       |
# |    policy_objective       | 0.0159   |
# |    std                    | 0.728    |
# |    value_loss             | 325      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -743     |
# | time/                     |          |
# |    fps                    | 376      |
# |    iterations             | 45       |
# |    time_elapsed           | 244      |
# |    total_timesteps        | 92160    |
# | train/                    |          |
# |    explained_variance     | 0.709    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00605  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 44       |
# |    policy_objective       | 0.0134   |
# |    std                    | 0.713    |
# |    value_loss             | 499      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -726     |
# | time/                     |          |
# |    fps                    | 375      |
# |    iterations             | 46       |
# |    time_elapsed           | 250      |
# |    total_timesteps        | 94208    |
# | train/                    |          |
# |    explained_variance     | 0.737    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00781  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 45       |
# |    policy_objective       | 0.0194   |
# |    std                    | 0.708    |
# |    value_loss             | 346      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -720     |
# | time/                     |          |
# |    fps                    | 375      |
# |    iterations             | 47       |
# |    time_elapsed           | 256      |
# |    total_timesteps        | 96256    |
# | train/                    |          |
# |    explained_variance     | 0.83     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00779  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 46       |
# |    policy_objective       | 0.0247   |
# |    std                    | 0.697    |
# |    value_loss             | 208      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -683     |
# | time/                     |          |
# |    fps                    | 374      |
# |    iterations             | 48       |
# |    time_elapsed           | 262      |
# |    total_timesteps        | 98304    |
# | train/                    |          |
# |    explained_variance     | 0.799    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00673  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 47       |
# |    policy_objective       | 0.0205   |
# |    std                    | 0.673    |
# |    value_loss             | 279      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -659     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 49       |
# |    time_elapsed           | 268      |
# |    total_timesteps        | 100352   |
# | train/                    |          |
# |    explained_variance     | 0.837    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00771  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 48       |
# |    policy_objective       | 0.0227   |
# |    std                    | 0.666    |
# |    value_loss             | 225      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -639     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 50       |
# |    time_elapsed           | 274      |
# |    total_timesteps        | 102400   |
# | train/                    |          |
# |    explained_variance     | 0.884    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00703  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 49       |
# |    policy_objective       | 0.0202   |
# |    std                    | 0.657    |
# |    value_loss             | 175      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -594     |
# | time/                     |          |
# |    fps                    | 374      |
# |    iterations             | 51       |
# |    time_elapsed           | 278      |
# |    total_timesteps        | 104448   |
# | train/                    |          |
# |    explained_variance     | 0.851    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00773  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 50       |
# |    policy_objective       | 0.0166   |
# |    std                    | 0.639    |
# |    value_loss             | 580      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -540     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 52       |
# |    time_elapsed           | 284      |
# |    total_timesteps        | 106496   |
# | train/                    |          |
# |    explained_variance     | 0.91     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00839  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 51       |
# |    policy_objective       | 0.0277   |
# |    std                    | 0.62     |
# |    value_loss             | 242      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -500     |
# | time/                     |          |
# |    fps                    | 373      |
# |    iterations             | 53       |
# |    time_elapsed           | 290      |
# |    total_timesteps        | 108544   |
# | train/                    |          |
# |    explained_variance     | 0.947    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00792  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 52       |
# |    policy_objective       | 0.0326   |
# |    std                    | 0.614    |
# |    value_loss             | 195      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -469     |
# | time/                     |          |
# |    fps                    | 372      |
# |    iterations             | 54       |
# |    time_elapsed           | 296      |
# |    total_timesteps        | 110592   |
# | train/                    |          |
# |    explained_variance     | 0.939    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00605  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 53       |
# |    policy_objective       | 0.0173   |
# |    std                    | 0.611    |
# |    value_loss             | 204      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -420     |
# | time/                     |          |
# |    fps                    | 372      |
# |    iterations             | 55       |
# |    time_elapsed           | 302      |
# |    total_timesteps        | 112640   |
# | train/                    |          |
# |    explained_variance     | 0.959    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00825  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 54       |
# |    policy_objective       | 0.0158   |
# |    std                    | 0.596    |
# |    value_loss             | 181      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -384     |
# | time/                     |          |
# |    fps                    | 371      |
# |    iterations             | 56       |
# |    time_elapsed           | 308      |
# |    total_timesteps        | 114688   |
# | train/                    |          |
# |    explained_variance     | 0.979    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0073   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 55       |
# |    policy_objective       | 0.0266   |
# |    std                    | 0.585    |
# |    value_loss             | 79.8     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -348     |
# | time/                     |          |
# |    fps                    | 371      |
# |    iterations             | 57       |
# |    time_elapsed           | 314      |
# |    total_timesteps        | 116736   |
# | train/                    |          |
# |    explained_variance     | 0.98     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00908  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 56       |
# |    policy_objective       | 0.0395   |
# |    std                    | 0.578    |
# |    value_loss             | 75.4     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -320     |
# | time/                     |          |
# |    fps                    | 371      |
# |    iterations             | 58       |
# |    time_elapsed           | 320      |
# |    total_timesteps        | 118784   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00804  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 57       |
# |    policy_objective       | 0.0438   |
# |    std                    | 0.581    |
# |    value_loss             | 65.2     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -291     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 59       |
# |    time_elapsed           | 325      |
# |    total_timesteps        | 120832   |
# | train/                    |          |
# |    explained_variance     | 0.93     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00753  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 58       |
# |    policy_objective       | 0.0207   |
# |    std                    | 0.586    |
# |    value_loss             | 91.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -258     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 60       |
# |    time_elapsed           | 331      |
# |    total_timesteps        | 122880   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00718  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 59       |
# |    policy_objective       | 0.0169   |
# |    std                    | 0.588    |
# |    value_loss             | 57.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -253     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 61       |
# |    time_elapsed           | 337      |
# |    total_timesteps        | 124928   |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00799  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 60       |
# |    policy_objective       | 0.0203   |
# |    std                    | 0.571    |
# |    value_loss             | 59.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -246     |
# | time/                     |          |
# |    fps                    | 370      |
# |    iterations             | 62       |
# |    time_elapsed           | 343      |
# |    total_timesteps        | 126976   |
# | train/                    |          |
# |    explained_variance     | 0.977    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00843  |
# ...
# | train/                    |          |
# |    explained_variance     | 0.966    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00735  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 77       |
# |    policy_objective       | 0.028    |
# |    std                    | 0.576    |
# |    value_loss             | 28.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 79       |
# |    time_elapsed           | 440      |
# |    total_timesteps        | 161792   |
# | train/                    |          |
# |    explained_variance     | 0.995    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00667  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 78       |
# |    policy_objective       | 0.0224   |
# |    std                    | 0.571    |
# |    value_loss             | 2.71     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 367      |
# |    iterations             | 80       |
# |    time_elapsed           | 446      |
# |    total_timesteps        | 163840   |
# | train/                    |          |
# |    explained_variance     | 0.889    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00761  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 79       |
# |    policy_objective       | 0.0244   |
# |    std                    | 0.569    |
# |    value_loss             | 91.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 366      |
# |    iterations             | 81       |
# |    time_elapsed           | 452      |
# |    total_timesteps        | 165888   |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00876  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 80       |
# |    policy_objective       | 0.0295   |
# |    std                    | 0.565    |
# |    value_loss             | 25.9     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 366      |
# |    iterations             | 82       |
# |    time_elapsed           | 458      |
# |    total_timesteps        | 167936   |
# | train/                    |          |
# |    explained_variance     | 0.974    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00778  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 81       |
# |    policy_objective       | 0.0191   |
# |    std                    | 0.557    |
# |    value_loss             | 8.86     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -169     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 83       |
# |    time_elapsed           | 464      |
# |    total_timesteps        | 169984   |
# | train/                    |          |
# |    explained_variance     | 0.946    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.007    |
# |    learning_rate          | 0.001    |
# |    n_updates              | 82       |
# |    policy_objective       | 0.022    |
# |    std                    | 0.561    |
# |    value_loss             | 40.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -164     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 84       |
# |    time_elapsed           | 470      |
# |    total_timesteps        | 172032   |
# | train/                    |          |
# |    explained_variance     | 0.991    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00693  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 83       |
# |    policy_objective       | 0.0258   |
# |    std                    | 0.563    |
# |    value_loss             | 5.52     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -165     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 85       |
# |    time_elapsed           | 476      |
# |    total_timesteps        | 174080   |
# | train/                    |          |
# |    explained_variance     | 0.975    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00746  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 84       |
# |    policy_objective       | 0.0311   |
# |    std                    | 0.562    |
# |    value_loss             | 30.3     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -170     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 86       |
# |    time_elapsed           | 482      |
# |    total_timesteps        | 176128   |
# | train/                    |          |
# |    explained_variance     | 0.985    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00843  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 85       |
# |    policy_objective       | 0.0345   |
# |    std                    | 0.573    |
# |    value_loss             | 8.76     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -170     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 87       |
# |    time_elapsed           | 487      |
# |    total_timesteps        | 178176   |
# | train/                    |          |
# |    explained_variance     | 0.99     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00702  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 86       |
# |    policy_objective       | 0.0203   |
# |    std                    | 0.57     |
# |    value_loss             | 9.55     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -180     |
# | time/                     |          |
# |    fps                    | 365      |
# |    iterations             | 88       |
# |    time_elapsed           | 493      |
# |    total_timesteps        | 180224   |
# | train/                    |          |
# |    explained_variance     | 0.99     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00665  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 87       |
# |    policy_objective       | 0.0268   |
# |    std                    | 0.565    |
# |    value_loss             | 12.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -179     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 89       |
# |    time_elapsed           | 499      |
# |    total_timesteps        | 182272   |
# | train/                    |          |
# |    explained_variance     | 0.995    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00957  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 88       |
# |    policy_objective       | 0.0427   |
# |    std                    | 0.576    |
# |    value_loss             | 6.52     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -176     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 90       |
# |    time_elapsed           | 505      |
# |    total_timesteps        | 184320   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00685  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 89       |
# |    policy_objective       | 0.0449   |
# |    std                    | 0.586    |
# |    value_loss             | 6.82     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 91       |
# |    time_elapsed           | 511      |
# |    total_timesteps        | 186368   |
# | train/                    |          |
# |    explained_variance     | 0.973    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00424  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 90       |
# |    policy_objective       | 0.0261   |
# |    std                    | 0.587    |
# |    value_loss             | 25.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -174     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 92       |
# |    time_elapsed           | 516      |
# |    total_timesteps        | 188416   |
# | train/                    |          |
# |    explained_variance     | 0.985    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0057   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 91       |
# |    policy_objective       | 0.0301   |
# |    std                    | 0.586    |
# |    value_loss             | 10.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -177     |
# | time/                     |          |
# |    fps                    | 364      |
# |    iterations             | 93       |
# |    time_elapsed           | 522      |
# |    total_timesteps        | 190464   |
# | train/                    |          |
# |    explained_variance     | 0.984    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00838  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 92       |
# |    policy_objective       | 0.017    |
# |    std                    | 0.586    |
# |    value_loss             | 4.35     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -171     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 94       |
# |    time_elapsed           | 529      |
# |    total_timesteps        | 192512   |
# | train/                    |          |
# |    explained_variance     | 0.982    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00831  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 93       |
# |    policy_objective       | 0.0465   |
# |    std                    | 0.585    |
# |    value_loss             | 17.1     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -173     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 95       |
# |    time_elapsed           | 535      |
# |    total_timesteps        | 194560   |
# | train/                    |          |
# |    explained_variance     | 0.935    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00854  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 94       |
# |    policy_objective       | 0.0242   |
# |    std                    | 0.601    |
# |    value_loss             | 31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -172     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 96       |
# |    time_elapsed           | 540      |
# |    total_timesteps        | 196608   |
# | train/                    |          |
# |    explained_variance     | 0.942    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00848  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 95       |
# |    policy_objective       | 0.0231   |
# |    std                    | 0.601    |
# |    value_loss             | 9.35     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 97       |
# |    time_elapsed           | 546      |
# |    total_timesteps        | 198656   |
# | train/                    |          |
# |    explained_variance     | 0.982    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00834  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 96       |
# |    policy_objective       | 0.0224   |
# |    std                    | 0.595    |
# |    value_loss             | 14.8     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 200      |
# |    ep_rew_mean            | -175     |
# | time/                     |          |
# |    fps                    | 363      |
# |    iterations             | 98       |
# |    time_elapsed           | 552      |
# |    total_timesteps        | 200704   |
# | train/                    |          |
# |    explained_variance     | 0.983    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00981  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 97       |
# |    policy_objective       | 0.0308   |
# |    std                    | 0.602    |
# |    value_loss             | 12.1     |
# ----------------------------------------

# %%
TRPO_model.save("models/Pendulmn_TRPO_Policy")

# %%
from sb3_contrib import TRPO
from Client_diff_Dropout import FRLClient
from Agent import SB3Agent
import copy
from stable_baselines3.common.evaluation import evaluate_policy
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
TRPO_model = TRPO.load("models/Pendulmn_TRPO_Policy")

timesteps_real_per_round = 500
timesteps_fc_per_round = timesteps_real_per_round * 30
epoch_per_round = 100
CLIENTS_NUM = 3
rounds_num = 20
batch_size_env_model = 128

env_models = []

Global_RL = TRPO_model

gravitys = [9.8, 9.8, 9.8]
# lengths = [0.5, 0.2, 0.8]
real_envs = []
Clients = []
for i in range(CLIENTS_NUM):
#     real_envs.append( TimeLimit(PendulumEnv(), max_episode_steps=200) )
    gravity = gravitys[i]
#     length = lengths[i]
    env = TimeLimit(PendulumEnv( g = gravity), max_episode_steps = 200)
    real_envs.append(env)
    
    policy_net = Global_RL
    agent = SB3Agent(policy_net)
    client = FRLClient(real_envs[i], agent, lr = 3e-4, hidden_size = 256,  device = device)
    Clients.append(client)
    env_model = copy.deepcopy(client.model)
    env_models.append(env_model)

    
train_loss_list = []
test_avg_list = []

for client_idx in range(len(Clients)):
    print('------------------------------')
    print("client: " + str(client_idx))
    # update policy
    # train prediction models
    Clients[client_idx].learn(timesteps_real_per_round, epoch_per_round, batch_size_env_model)
     #
    train_loss_list.append(Clients[client_idx].train_loss_list)
    test_avg_list.append(Clients[client_idx].test_avg_list)
# Out:
# ------------------------------
# client: 0
# Avg loss: 0.030008403812535108!
# Avg loss: 0.029424850916063103!
# Avg loss: 0.02952436896623112!
# Avg loss: 0.02612044943574195!
# Avg loss: 0.02121185692192133!
# Avg loss: 0.01722206459317628!
# Avg loss: 0.015365143789870975!
# Avg loss: 0.014433952727073726!
# Avg loss: 0.013832366679989718!
# Avg loss: 0.0134975959977722!
# Avg loss: 0.013284613742080183!
# Avg loss: 0.012859922811112484!
# Avg loss: 0.012388464872165059!
# Avg loss: 0.011881785350997234!
# Avg loss: 0.011352112758953202!
# Avg loss: 0.010832446904775377!
# Avg loss: 0.010360832879669032!
# Avg loss: 0.010176085918186193!
# Avg loss: 0.00977359778470903!
# Avg loss: 0.009479130985370527!
# Avg loss: 0.009340928937405502!
# Avg loss: 0.009239493249333463!
# Avg loss: 0.009067677519051359!
# Avg loss: 0.008746020295948256!
# Avg loss: 0.008458705797287015!
# Avg loss: 0.008264601596796031!
# Avg loss: 0.00808153997369421!
# Avg loss: 0.007956109196529724!
# Avg loss: 0.007805257785948924!
# Avg loss: 0.007624355000152718!
# Avg loss: 0.007384863050732141!
# Avg loss: 0.007272676408756524!
# Avg loss: 0.007297398763087889!
# Avg loss: 0.007405694698099978!
# Avg loss: 0.0073946894740220155!
# Avg loss: 0.007313505499041639!
# Avg loss: 0.00723703257952972!
# Avg loss: 0.0069981181693340964!
# Avg loss: 0.006771969364781399!
# Avg loss: 0.0067641607642872255!
# Avg loss: 0.006833902734118358!
# Avg loss: 0.006913329010712914!
# Avg loss: 0.007038653901545331!
# Avg loss: 0.007104039572489758!
# Avg loss: 0.007108351840094353!
# Avg loss: 0.0071255762186289455!
# Avg loss: 0.0070689667103579264!
# Avg loss: 0.007024836808171434!
# Avg loss: 0.006950125745497644!
# Avg loss: 0.006823570361981789!
# ------------------------------
# client: 1
# Avg loss: 0.0380961307409234!
# Avg loss: 0.03629293166624848!
# Avg loss: 0.03290386858425336!
# Avg loss: 0.028898716007630963!
# Avg loss: 0.026649076679411035!
# Avg loss: 0.025108201670033546!
# Avg loss: 0.023053515150095336!
# Avg loss: 0.021455343289029163!
# Avg loss: 0.020166123780994288!
# Avg loss: 0.019390287433416233!
# Avg loss: 0.018617140778975833!
# Avg loss: 0.017737633128126616!
# Avg loss: 0.016685849962038143!
# Avg loss: 0.015990855107665992!
# Avg loss: 0.015696378307572256!
# Avg loss: 0.015642333727834436!
# Avg loss: 0.015380832091711151!
# Avg loss: 0.014910737387253903!
# Avg loss: 0.014174098795629107!
# Avg loss: 0.013402290713080826!
# Avg loss: 0.012706122293214625!
# Avg loss: 0.012197106070816517!
# Avg loss: 0.012077203616499901!
# Avg loss: 0.012044905196332062!
# Avg loss: 0.011996681409849164!
# Avg loss: 0.011986071250285023!
# Avg loss: 0.011853272301959806!
# Avg loss: 0.011623927140802456!
# Avg loss: 0.011275687814340928!
# Avg loss: 0.011042175201582722!
# Avg loss: 0.01087783948945192!
# Avg loss: 0.010778327431762592!
# Avg loss: 0.010708577415983503!
# Avg loss: 0.010664178709460733!
# Avg loss: 0.010629108461046902!
# Avg loss: 0.010558569816639647!
# Avg loss: 0.010563745961602157!
# Avg loss: 0.010513683156265568!
# Avg loss: 0.010462071100870768!
# Avg loss: 0.01044379063261052!
# Avg loss: 0.010545685652177781!
# Avg loss: 0.010594763874153918!
# Avg loss: 0.010559124153805896!
# Avg loss: 0.010463073246258621!
# Avg loss: 0.010333989452725897!
# Avg loss: 0.010124428916800146!
# Avg loss: 0.009991864807282884!
# Avg loss: 0.009789826943112227!
# Avg loss: 0.009696866715870178!
# Avg loss: 0.009673883693952424!
# Avg loss: 0.009643669787522716!
# Avg loss: 0.009676185106121313!
# Avg loss: 0.009578719472046941!
# Avg loss: 0.0094233241409529!
# Avg loss: 0.009325755391813195!
# Avg loss: 0.009149727414284521!
# Avg loss: 0.009132229028424869!
# Avg loss: 0.009182935423450545!
# Avg loss: 0.00918059867573902!
# Avg loss: 0.009139248285597812!
# Avg loss: 0.009034717234317213!
# Avg loss: 0.008950603725000596!
# Avg loss: 0.008901639902420962!
# Avg loss: 0.008902954489070301!
# Avg loss: 0.008936013876809739!
# Avg loss: 0.008995308517478406!
# Avg loss: 0.008961546677940836!
# Avg loss: 0.008993906150960053!
# Avg loss: 0.008931688772669684!
# Avg loss: 0.008879787831489617!
# Avg loss: 0.00894195348296004!
# Avg loss: 0.009015484931490694!
# Avg loss: 0.009050183052119489!
# Avg loss: 0.009004974710405804!
# Avg loss: 0.00886687452167583!
# Avg loss: 0.00867682311780906!
# Avg loss: 0.00849806326519077!
# Avg loss: 0.008425372876808978!
# Avg loss: 0.008493877866033775!
# Avg loss: 0.00855198791619235!
# Avg loss: 0.008613017053188135!
# Avg loss: 0.008641757867687071!
# Avg loss: 0.008670970705958705!
# Avg loss: 0.008690100494228924!
# Avg loss: 0.008722395848987314!
# Avg loss: 0.008729628758737817!
# Avg loss: 0.008719165910345812!
# Avg loss: 0.008668593373149633!
# ------------------------------
# client: 2
# Avg loss: 0.018228915764096503!
# Avg loss: 0.0195242023988006!
# Avg loss: 0.018900205422930107!
# Avg loss: 0.01720180997484325!
# Avg loss: 0.015523187324870378!
# Avg loss: 0.014339151794362502!
# Avg loss: 0.013568301694176626!
# Avg loss: 0.012785989887246009!
# Avg loss: 0.011958620063669514!
# Avg loss: 0.01140669364314211!
# Avg loss: 0.01106733080032427!
# Avg loss: 0.010928089362757116!
# Avg loss: 0.010787686350525594!
# Avg loss: 0.010846005356931225!
# Avg loss: 0.010843178978466312!
# Avg loss: 0.010542438397969818!
# Avg loss: 0.010124536992128317!
# Avg loss: 0.009686893076626195!
# Avg loss: 0.009360281035624212!
# Avg loss: 0.009138948886296324!
# Avg loss: 0.009047054770441416!
# Avg loss: 0.009056156229247185!
# Avg loss: 0.008983045718196081!
# Avg loss: 0.008820223514727938!
# Avg loss: 0.008680226629173072!
# Avg loss: 0.008541326435806695!
# Avg loss: 0.008412872129410972!
# Avg loss: 0.008338538168851908!
# Avg loss: 0.008277616759296507!
# Avg loss: 0.008136717907715744!
# Avg loss: 0.008016105287339693!
# Avg loss: 0.007798998861787065!
# Avg loss: 0.007644895520449306!
# Avg loss: 0.0075704518961720165!
# Avg loss: 0.007491135217618042!
# Avg loss: 0.007448619149411874!
# Avg loss: 0.007378724735851089!
# Avg loss: 0.007353905740310438!
# Avg loss: 0.007284028705422922!
# Avg loss: 0.0072034778013282145!
# Avg loss: 0.007151619055463622!
# Avg loss: 0.007066318287397735!
# Avg loss: 0.006927042905590497!
# Avg loss: 0.006772158411913551!
# Avg loss: 0.006633623470940317!
# Avg loss: 0.00649547802847034!
# Avg loss: 0.006376645441438692!
# Avg loss: 0.006295963080677514!
# Avg loss: 0.006226874732528813!
# Avg loss: 0.006148124740769465!
# Avg loss: 0.006124074812978506!
# Avg loss: 0.006069857664212274!
# Avg loss: 0.006111254979041405!
# Avg loss: 0.006104020571219735!
# Avg loss: 0.006002208012505434!
# Avg loss: 0.005896481574357798!
# Avg loss: 0.005830574058151494!
# Avg loss: 0.005834669529576786!
# Avg loss: 0.005789615415075483!
# Avg loss: 0.0058259224573460715!
# Avg loss: 0.0058970155987966184!
# Avg loss: 0.005913096788766173!
# Avg loss: 0.005836992840631865!
# Avg loss: 0.0057727449228211!
# Avg loss: 0.005673038956398765!
# Avg loss: 0.005557272403966636!
# Avg loss: 0.005502255116589368!
# Avg loss: 0.005513850773568265!
# Avg loss: 0.005548351481556892!
# Avg loss: 0.00564210837900949!
# Avg loss: 0.005739111378400897!
# Avg loss: 0.00577712907785705!
# Avg loss: 0.005788277381798252!
# Avg loss: 0.005769449613289908!
# Avg loss: 0.005682593600164788!
# Avg loss: 0.005595940255346553!
# Avg loss: 0.0054675286062411035!
# Avg loss: 0.005320606864891791!
# Avg loss: 0.005242788206087426!
# Avg loss: 0.005170430101958725!
# Avg loss: 0.0051585975699708795!
# Avg loss: 0.005179543699002049!
# Avg loss: 0.005219360442715697!
# Avg loss: 0.00524494020161607!
# Avg loss: 0.005251867424619074!
# Avg loss: 0.0052103941675159145!
# Avg loss: 0.005157174162256221!
# Avg loss: 0.005166210606694222!
# Avg loss: 0.005138081982731819!
# Avg loss: 0.005092799348543243!
# Avg loss: 0.005059817734872922!
# Avg loss: 0.005022122834731514!
# Avg loss: 0.0049690397605688!
# Avg loss: 0.00496831593879809!
# Avg loss: 0.00495311314870681!
# Avg loss: 0.005034223333350383!
# Avg loss: 0.005127660365154346!
# Avg loss: 0.0051781925956796235!
# Avg loss: 0.005199677627824712!
# Avg loss: 0.005221159558762641!

# %%
train_log = {}
test_log = {}

# %%
train_log["Droput"] = train_loss_list
test_log["Droput"] = test_avg_list

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_loss_curves_and_statistics(loss_list):
    """
    绘制loss曲线和统计信息图像。

    参数:
    loss_list (list of list of float): 每个元素是一个模型在每个epoch的loss列表。
    """
    # 绘制每个模型的loss曲线
    plt.figure(figsize=(10, 6))
    for idx, loss in enumerate(loss_list):
        plt.plot(loss, label=f'Model {idx+1}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss Curves')
    plt.legend()
    plt.grid(True)
    plt.show()

    # 计算每个模型最后一个epoch的loss值
    last_epoch_losses = [loss[-1] for loss in loss_list]

    # 计算最后一个epoch的平均值和方差
    mean_last_epoch_loss = np.mean(last_epoch_losses)
    std_last_epoch_loss = np.std(last_epoch_losses)

    # 绘制最后一个epoch的loss值，平均值和方差
    plt.figure(figsize=(10, 6))
    plt.plot(last_epoch_losses, 'o-', label='Last Epoch Loss')
    plt.axhline(mean_last_epoch_loss, color='r', linestyle='--', label=f'Mean: {mean_last_epoch_loss:.2f}')
    plt.fill_between(range(len(last_epoch_losses)), mean_last_epoch_loss - std_last_epoch_loss, mean_last_epoch_loss + std_last_epoch_loss, color='r', alpha=0.2, label=f'Std Dev: {std_last_epoch_loss:.2f}')
    plt.xlabel('Model Index')
    plt.ylabel('Loss')
    plt.title('Last Epoch Losses with Mean and Std Dev')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_loss_curves_and_statistics(train_loss_list)

# %%
plot_loss_curves_and_statistics(test_avg_list)
