# %%
from H_Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit

# %%
gravitys = [7.0, 10.0, 13.0]

real_envs = []
for i in range(len(gravitys)):
    gravity = gravitys[i]
    
    env = TimeLimit(PendulumEnv( g = gravity), max_episode_steps = 200)
    real_envs.append(env)

# %%
real_envs[1].g
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.g to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.g` for environment variables or `env.get_wrapper_attr('g')` that will search the reminding wrappers.
#   logger.warn(
# 10.0

# %%
from sb3_contrib import TRPO

# %%
from sb3_contrib import TRPO
from Client_diff import FRLClient
from Agent import SB3Agent
import copy
from stable_baselines3.common.evaluation import evaluate_policy
import torch
from H_Envs.pendulum import PendulumEnv
import gymnasium as gym
from gymnasium.wrappers import TimeLimit
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
TRPO_model = TRPO.load("models/Pendulmn_TRPO_Policy")

# %%
from stable_baselines3.common.evaluation import evaluate_policy
evaluate_policy(TRPO_model, real_envs[0], n_eval_episodes= 100)
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-120.64923663330191, 82.67587631875843)

# %%
evaluate_policy(TRPO_model, real_envs[1], n_eval_episodes= 100)
# Out:
# (-169.7152943935768, 108.14667480772944)

# %%
evaluate_policy(TRPO_model, real_envs[2], n_eval_episodes= 100)
# Out:
# (-246.82998230859863, 154.03477037681895)

# %%
TRPO_model_0 = TRPO(policy="MlpPolicy",env=real_envs[0],verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TRPO_model_0.learn(total_timesteps=300000)
# Out:
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.12e+03 |
# | time/              |           |
# |    fps             | 524       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.12e+03 |
# | time/                     |           |
# |    fps                    | 505       |
# |    iterations             | 2         |
# |    time_elapsed           | 8         |
# |    total_timesteps        | 4096      |
# | train/                    |           |
# |    explained_variance     | 0.000901  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00842   |
# |    learning_rate          | 0.001     |
# ...

# %%
evaluate_policy(TRPO_model_0, real_envs[0], n_eval_episodes= 100)
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-115.95065069536416, 77.39149516245567)

# %%
evaluate_policy(TRPO_model_0, real_envs[1], n_eval_episodes= 100)
# Out:
# (-229.44504348080983, 144.67864389760828)

# %%
evaluate_policy(TRPO_model_0, real_envs[2], n_eval_episodes= 100)
# Out:
# D:\Anaconda\envs\py3.8\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-1010.9027988747121, 275.2621553322457)

# %%
TRPO_model_0.save("models/Pendulmn_TRPO_Policy_G=7")

# %%
TRPO_model_2 = TRPO(policy="MlpPolicy",env=real_envs[2],verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
TRPO_model_2.learn(total_timesteps=300000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    fps             | 435      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 200       |
# |    ep_rew_mean            | -1.32e+03 |
# | time/                     |           |
# |    fps                    | 410       |
# |    iterations             | 2         |
# |    time_elapsed           | 9         |
# |    total_timesteps        | 4096      |
# | train/                    |           |
# |    explained_variance     | 0.00249   |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00926   |
# |    learning_rate          | 0.001     |
# ...

# %%
evaluate_policy(TRPO_model_2, real_envs[0], n_eval_episodes= 100)
# Out:
# (-834.8568129378916, 628.3652103467022)

# %%
evaluate_policy(TRPO_model_2, real_envs[1], n_eval_episodes= 100)
# Out:
# (-755.1614913455882, 502.2036960809164)

# %%
evaluate_policy(TRPO_model_2, real_envs[2], n_eval_episodes= 100)
# Out:
# (-168.3423317191142, 105.54962637768924)

# %%
TRPO_model_2.save("models/Pendulmn_TRPO_Policy_G=13")
